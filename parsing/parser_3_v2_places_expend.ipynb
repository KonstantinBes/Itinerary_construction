# %%
"""Parser API KudaGo (parser_3, v.2.0, 19_04_2020)."""

"""Changes:"""
"""v.0 - unstructured, page of places/events collectedd"""
"""v.1.0 - places/events collected individually"""
"""v.2.0 - function get_data returns 'dict' (not 'str')"""

"""Add information to list of places given by parser_1"""
"""API information at 'https://docs.kudago.com/api'."""

"""Input: .json file with list structured as:"""
"""[{'id': id_1,'name': name_1}, {*place_2},...]"""
"""Output: .json file consisting full information"""
"""on places available from API KudaGom."""
"""If data on some of places could not be collected their"""
""" 'id'`s will be placed in another (error).json file"""


from urllib.request import urlopen
from urllib.error import HTTPError
from bs4 import BeautifulSoup
import json


"""'get_data' input: API KudaGo page url to parce."""
"""'get_data' output: data from url in 'dict' type."""

def get_data(url):
    try:
        html = urlopen(url)
    except HTTPError:
        return HTTPError
    try:
        data = json.loads(html.read())
        #print(type(data), data)
    except AttributeError:
        return AttributeError
    return data

location = "spb"    # Choose city here (spb, msk, ...)

source_url = "https://kudago.com/public-api/v1.4/places/"
expand_url = "/?expand=images"

directory = "D:/Work/Data_files/working_dir/"
in_file = "places_1_" + location
res_file = "places_2_expand_" + location
error_file = "places_2_error_" + location

with open (directory + in_file + ".json",
           'r', encoding = "utf-8") as inf:
    places_base = json.load(inf)
    with open (directory + res_file + ".json",
           'w', encoding = "utf-8") as ouf,\
    open (directory + error_file + ".json",
           'w', encoding = "utf-8") as errf: 
        place_data = {}
        places_list = []
        err_list = []
        for place in places_base: 
            place_url = (source_url + str(place['id'])
                         + expand_url)
            #print("Source:\n", place_url)
            try:
                place_data = get_data(place_url)
                #print(type(place_data), place_data)
                places_list.append(place_data)
            except:
                err_list.append(place)
                print("Invalid place data, id: ", place['id'])
        json.dump(places_list, ouf)
        json.dump(err_list, errf)
print("Saved in file:\n",
      directory + res_file + ".json")
print("Error file:\n",
      directory + error_file + ".json")

with open (directory + res_file + ".json",
           'r', encoding = "utf-8") as inf,\
open (directory + error_file + ".json",
           'r', encoding = "utf-8") as errf:
    data = json.load(inf)
    print("Number of elements in output file:", len(data))
    if(len(data) != 0):
        print("First element:\n", data[0])
        print("Last element:\n", data[-1])
    err_list = json.load(errf)
    print("Number of elements in error file:", len(err_list))
    if(len(err_list) != 0):
        print("First element:\n", err_list[0])
        print("Last element:\n", err_list[-1])
# Out:
# Saved in file:
#  D:/Work/Data_files/working_dir/places_2_expand_spb.json
# Error file:
#  D:/Work/Data_files/working_dir/places_2_error_spb.json
# Number of elements in output file: 3732
# First element:
#  {'id': 1, 'title': 'Эрмитаж (Зимний дворец, Главный музейный комплекс)', 'slug': 'ermitazh', 'address': 'пл. Дворцовая, д. 2', 'timetable': 'вт–вс 12:00–21:00', 'phone': '+7 812 571-34-65', 'is_stub': False, 'body_text': '<p>В 1754 году архитектор Растрелли начал строительство Зимнего дворца — новой царской резиденции. При Екатерине II возвели Малый и Большой Эрмитаж, Эрмитажный театр.</p>\n<p>Годом основания музея считается 1764-й: именно тогда императрица приобрела коллекцию, собранную купцом Иоганном Эрнстом Гоцковским. В неё входили полотна Рембрандта, Питера Пауля Рубенса, Антониса ван Дейка, Якоба Йорданса, Яна Стена и других мэтров живописи. Шли годы, менялись правители, росло эрмитажное собрание. В 1814 году оно пополнилось полотнами из коллекции императрицы Жозефины. В 1826 году открылась Военная галерея 1812 года, стены которой украсили портреты генералов кисти Джорджа Доу. В 1850 году в музей поступили пять работ Тициана, в числе которых — «Даная». К концу XIX века в сокровищнице мирового искусства уже хранились творения Джорджоне, Никола Пуссена, Микеланджело, Караваджо, Сандро Боттичелли. В 1914 году была приобретена «Мадонна Бенуа» Леонардо да Винчи.</p>\n<p>На сегодняшний день эрмитажное собрание содержит более 3 000 0000 экспонатов — живописные полотна, графические листы, скульптуры, произведения декоративно-прикладного искусства, оружие, памятники нумизматики, археологические находки, книги, фотографии, документы и многое другое. «Возвращение блудного сына» и «Даная» Рембрандта, «Мадонна Литта» и «Мадонна Бенуа» Леонардо да Винчи, «Дама в голубом» Томаса Гейнсборо, «Юдифь» Джорджоне, «Завтрак» Диего Веласкеса, «Апостолы Пётр и Павел» Эль Греко, «Юноша с лютней» Караваджо, «Три грации» Антонио Кановы, часы «Павлин» — лишь некоторые жемчужины коллекции.</p>\n<p>Главный музейный комплекс включает в себя шесть связанных между собой зданий — Зимний дворец, Запасной дом Зимнего дворца, Малый Эрмитаж, Большой (Старый) Эрмитаж, Новый Эрмитаж и <a href="https://kudago.com/spb/place/ermitazhnyj-teatr/">Эрмитажный театр</a>. В них открыты для посещения 365 залов. Также в распоряжении музея находятся <a href="https://kudago.com/spb/place/glavnyj-shtab-ermitazh/">Главный штаб</a>, <a href="https://kudago.com/spb/place/muzej-pri-farforovom-zavode/">Музей Императорского фарфорового завода</a>, реставрационно-хранительский центр <a href="https://kudago.com/spb/place/fondohranilishe-gosudarstvennogo-ermitazha/">«Старая Деревня»</a> и <a href="https://kudago.com/spb/place/dvorec-menshikova/">Меншиковский дворец</a>.</p>\n', 'description': '<p>Эрмитаж — один из крупнейших художественных и культурно-исторических музеев в мире. Чтобы осмотреть все его экспонаты, затрачивая хотя бы по одной минуте на каждый, понадобится более 11 лет.</p>\n', 'site_url': 'https://kudago.com/spb/place/ermitazh/', 'foreign_url': 'http://www.hermitagemuseum.org/', 'coords': {'lat': 59.94027033888366, 'lon': 30.31377455155894}, 'subway': 'Адмиралтейская, Гостиный Двор', 'favorites_count': 620, 'images': [{'image': 'https://kudago.com/media/images/place/2a/65/2a653c4db8213b437405614d70ec28c7.jpg', 'thumbnails': {'640x384': 'https://kudago.com/media/thumbs/640x384/images/place/2a/65/2a653c4db8213b437405614d70ec28c7.jpg', '144x96': 'https://kudago.com/media/thumbs/144x96/images/place/2a/65/2a653c4db8213b437405614d70ec28c7.jpg'}, 'source': {'name': 'culture.ru', 'link': 'http://www.culture.ru/institutes/1485/gosudarstvenniy-ermitazh'}}, {'image': 'https://kudago.com/media/images/place/16/06/1606aca52cae36f9ee05d0efb2cdb704.jpg', 'thumbnails': {'640x384': 'https://kudago.com/media/thumbs/640x384/images/place/16/06/1606aca52cae36f9ee05d0efb2cdb704.jpg', '144x96': 'https://kudago.com/media/thumbs/144x96/images/place/16/06/1606aca52cae36f9ee05d0efb2cdb704.jpg'}, 'source': {'name': 'culture.ru', 'link': 'http://www.culture.ru/institutes/1485/gosudarstvenniy-ermitazh'}}, {'image': 'https://kudago.com/media/images/place/2d/9c/2d9cac8d01f4ce4eca7648269729f336.jpg' ...
# Last element:
#  {'id': 33334, 'title': 'пушка Петропавловской крепости', 'slug': 'dostoprimechatelnost-pushka-petropavlovskoj-kreposti', 'address': 'Петропавловская крепость', 'timetable': '', 'phone': '', 'is_stub': False, 'body_text': '<p>  </p><p>Первые залпы в <a href="https://kudago.com/spb/place/petropavlovskaya-krepost/">Петропавловской крепости</a> стали звучать с момента основания в 1703 году. Когда часов повсеместно не было, ими обозначали начало и конец рабочего дня, предупреждали об угрозе наводнений. </p><p>Традиция полуденного выстрела существует чуть более 150 лет. Впервые его произвели во дворе <a href="https://kudago.com/spb/place/admiraltejstvo/">Адмиралтейства</a> в 1865 году, а в 1873 году перенесли действо в Петропавловскую крепость. В советское время этот ритуал упразднили, но в 1957 году вернули назад в обиход. Сегодня традиция даже закреплена в Уставе Санкт-Петербурга.</p><p>Когда стреляет пушка в Петропавловской крепости, звук разносится на несколько километров вокруг. По сигналу можно сверять часы, потому что звучит он ровно в полдень. Залп производят канониры <a href="https://kudago.com/spb/place/gosudarstvennyj-muzej-istorii-sankt-peterburga/">Музея истории Санкт-Петербурга</a>. </p><p>В значимые даты в церемонии участвуют чиновники, почётные граждане города и другие известные люди. На Нарышкин бастион, где стреляет пушка в Петропавловской крепости, в это время попасть нельзя.</p>', 'description': '<p>  </p><p>Многим кажется, что традицию полуденного залпа создал ещё Пётр Первый. В крепости действительно начали стрелять при нём, но в обычай это оформилось гораздо позже.</p>', 'site_url': 'https://kudago.com/spb/place/dostoprimechatelnost-pushka-petropavlovskoj-kreposti/', 'foreign_url': '', 'coords': {'lat': 59.94851367744564, 'lon': 30.31658596931169}, 'subway': 'Горьковская', 'favorites_count': 0, 'images': [{'image': 'https://kudago.com/media/images/place/42/63/4263bf18aa5b4074a74f0cccb89e37ea.jpg', 'thumbnails': {'640x384': 'https://kudago.com/media/thumbs/640x384/images/place/42/63/4263bf18aa5b4074a74f0cccb89e37ea.jpg', '144x96': 'https://kudago.com/media/thumbs/144x96/images/place/42/63/4263bf18aa5b4074a74f0cccb89e37ea.jpg'}, 'source': {'name': 'spbdnevnik.ru', 'link': 'https://spbdnevnik.ru/news/2018-07-06/poludennyy-vystrel-s-petropavlovki-posvyatili-pogibshim-morpeham#!'}}, {'image': 'https://kudago.com/media/images/place/16/de/16de2c8da3843dd23b287588b9585c0d.jpg', 'thumbnails': {'640x384': 'https://kudago.com/media/thumbs/640x384/images/place/16/de/16de2c8da3843dd23b287588b9585c0d.jpg', '144x96': 'https://kudago.com/media/thumbs/144x96/images/place/16/de/16de2c8da3843dd23b287588b9585c0d.jpg'}, 'source': {'name': 'vk.com', 'link': 'https://vk.com/club81419567?z=photo-81419567_457243097%2Falbum-81419567_00%2Frev'}}, {'image': 'https://kudago.com/media/images/place/d2/fa/d2fafdb5006212807afacc3c0979d781.jpg', 'thumbnails': {'640x384': 'https://kudago.com/media/thumbs/640x384/images/place/d2/fa/d2fafdb5006212807afacc3c0979d781.jpg', '144x96': 'https://kudago.com/media/thumbs/144x96/images/place/d2/fa/d2fafdb5006212807afacc3c0979d781.jpg'}, 'source': {'name': 'spbdnevnik.ru', 'link': 'https://spbdnevnik.ru/news/2018-08-10/v-petropavlovskoy-kreposti-rasskazali-kak-rabotayut-znamenitye-pushki'}}], 'comments_count': 0, 'is_closed': False, 'categories': ['attractions'], 'short_title': 'Пушка Петропавловской крепости', 'tags': ['городские', 'городские прогулки', 'достопримечательности', 'где побывать в санкт-петербурге'], 'location': 'spb', 'age_restriction': 0, 'disable_comments': False, 'has_parking_lot': False}
# Number of elements in error file: 0
