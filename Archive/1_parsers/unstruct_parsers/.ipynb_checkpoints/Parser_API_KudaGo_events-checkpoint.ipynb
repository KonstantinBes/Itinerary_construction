# %%
"""Parser API KudaGo. Full list of events in city (spb,msk,...)."""
"""Input: site`s API url. Output: .json file with class 'list' sorted by category[0]:"""
"""[{'id':...,'publication_date':...,'categories':[...]},...]"""


from urllib.request import urlopen
from urllib.error import HTTPError
from bs4 import BeautifulSoup
import json


url_base = "https://kudago.com/public-api/v1.4/events/?"
url_fields = "&fields=id,publication_date,dates,title,short_title,slug,place,description,body_text,location,categories,tagline,age_restriction,price,is_free,images,favorites_count,comments_count,site_url,tags,participants"
url_expand = "&expand=images,place,location,dates,participants"
url_location_time = "&location=msk"
url_text_form = "&text_format=html"
url_pages = "&page_size=20&page="
url_full = url_base+url_fields+url_expand+url_location_time+url_text_form+url_pages
print(url_full)
start_page = 1
# max_pages: spb=528, msk=? found manually for page_size=20


def get_data(url):
    try:
        html = urlopen(url)
    except HTTPError as e:
        return e
    try:
        data = str(BeautifulSoup(html.read()))
    except AttributeError as e:
        return None
    return data


page_data = ''
data = []
failed_objects = ''
temp_data = ''
temp_obj = {}

with open ('A:\Information\Kostya\Master\Science\Events_msk.json',
           'w', encoding="utf-8") as ouf:
    while (page_data!=None):
        page_data = get_data(url_full+str(start_page))
        if(type(page_data)!=str):
            break
        try:
            data+=json.loads(page_data[page_data.find('"results":[')+10:-1])
            print(type(data[-1]), page)
            print(data[-1]["id"])
        except:
            print("Page error")
            temp_data = page_data[page_data.find('"results":[')+11:-1]
            #print(temp_data)
            while(temp_data.find('"id"')!=-1):
                try:
                    if(temp_data.find('},{"id"')!=-1):
                        temp_obj = temp_data[temp_data.find('{"id"'):temp_data.find('},{"id"')+1]    #! Magic constant
                    else:
                        temp_obj = temp_data[temp_data.find('{"id"'):-1]
                    #print(temp_data)
                    #print('\n')
                    #print(temp_obj)
                    temp_data = temp_data[temp_data.find('{"id"')+len(temp_obj)+1:]
                    data.append(json.loads(temp_obj))
                    print(type(data[-1]), data[-1]["id"])
                    #print('\n\n')
                except:
                    print("Obj error:\n")
                    failed_objects+=temp_obj
                    failed_objects+='SEPARATION_LINE'
        page+=1
    category_sorted=sorted(data, key=lambda x: x['categories'][0])
    json.dump(category_sorted, ouf)
    #print(page)
"""with open ('A:\Information\Kostya\Master\Science\Events_msk.json',
           'r', encoding="utf-8") as inf:
    data=json.load(inf)
    print(type(data), data[0], data[-1], len(data))"""
# Out:
# https://kudago.com/public-api/v1.4/events/?&fields=id,publication_date,dates,title,short_title,slug,place,description,body_text,location,categories,tagline,age_restriction,price,is_free,images,favorites_count,comments_count,site_url,tags,participants&expand=images,place,location,dates,participants&location=msk&text_format=html&page_size=20&page=1
# <class 'dict'> 1
# 142775
# <class 'dict'> 2
# 128134
# <class 'dict'> 3
# 119164
# <class 'dict'> 4
# 115880
# <class 'dict'> 5
# 109114
# <class 'dict'> 6
# 98305
# <class 'dict'> 7
# 88108
# <class 'dict'> 8
# 84560
# <class 'dict'> 9
# 79276
# Page error
# <class 'dict'> 161880
# <class 'dict'> 175510
# <class 'dict'> 170455
# Obj error:
#
# <class 'dict'> 173805
# <class 'dict'> 186155
# <class 'dict'> 168596
# <class 'dict'> 184965
# Obj error:
#
# <class 'dict'> 164140
# <class 'dict'> 158049
# Obj error:
#
# <class 'dict'> 176823
# <class 'dict'> 164138
# <class 'dict'> 175365
# <class 'dict'> 165552
# <class 'dict'> 181875
# ...
