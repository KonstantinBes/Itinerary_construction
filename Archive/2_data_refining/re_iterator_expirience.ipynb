# %%
"""Transforms 'timetable' in KudaGo dataset (str):"""
""" 'timetable': 'вт, чт 10:30–18:00, ср 10:30–21:00' """
"""to the format of FIFA (ITMO) dataset:"""
"""dict of lists[int_1(opening time), int_2(closing time)]"""
""" 'open_hours': {"1":[1030,1800],"2":[1030,1800], ...}"""


# 1 - Get original KudaGo timetable from dataset
import json
from json import JSONDecodeError

# 2 - Digitalisation of KudaGo timetable
import re
import string
from itertools import tee
from collections import Counter    # for testing


# In / out files and directorires:
direct = "D:/Work/Data_files/working_dir/"
in_file_1 = "Saint+Petersburg-finalized"
in_file_2 = "Moscow-finalized"
out_file = "all_timetables"

# %%
# 1

"""Get original tametable from KudaGo datasets

with open(direct + in_file_1 + ".json",
           'r', encoding = "utf-8") as inf_1, \
     open(direct + in_file_2 + ".json",
           'r', encoding = "utf-8") as inf_2, \
     open(direct + out_file + ".json",
           'w', encoding = "utf-8") as ouf:
    timetables = []
    try:
        places = json.load(inf_1)
        for place in places:
            timetable = place["open_hours"]
            if timetable not in timetables:
                timetables.append(timetable)
        places = json.load(inf_2)
        for place in places:
            timetable = place["open_hours"]
            if timetable not in timetables:
                timetables.append(timetable)
    except JSONDecodeError:
        print("Input file cannot be read")
    try:
        json.dump(timetables, ouf)
    except JSONDecodeError:
        print("Out file writing error")"""
# Out:
# 'Get original tametable from KudaGo datasets\n\nwith open(direct + in_file_1 + ".json",\n           \'r\', encoding = "utf-8") as inf_1,      open(direct + in_file_2 + ".json",\n           \'r\', encoding = "utf-8") as inf_2,      open(direct + out_file + ".json",\n           \'w\', encoding = "utf-8") as ouf:\n    timetables = []\n    try:\n        places = json.load(inf_1)\n        for place in places:\n            timetable = place["open_hours"]\n            if timetable not in timetables:\n                timetables.append(timetable)\n        places = json.load(inf_2)\n        for place in places:\n            timetable = place["open_hours"]\n            if timetable not in timetables:\n                timetables.append(timetable)\n    except JSONDecodeError:\n        print("Input file cannot be read")\n    try:\n        json.dump(timetables, ouf)\n    except JSONDecodeError:\n        print("Out file writing error")'

# %%
# 2
# Finds all (considered) time-defining notations in text
def find_patterns(text):
    
    # Considered regular expressions:
    
    # Time range, example: "10:00-0:10"
    time_reg = r'\d{1,2}:\d\d[^,]\d{1,2}:\d\d'    #! [^,] \W

    # Week days, example: "пн"
    mon = r'\bпн\b'
    tue = r'\bвт\b'
    wed = r'\bср\b'
    thu = r'\bчт\b'
    fri = r'\bпт\b'
    sat = r'\bсб\b'
    sun = r'\bвс\b'
    week_day_reg = [mon, tue, wed, thu, fri, sat, sun]

    # Other notations
    notation_1 = "IMPOSSIBLE"
    
    timetable.replace(' ', '')
    time_ranges = re.finditer(time_reg, timetable)
    days = [re.finditer(day, timetable) for day in week_day_reg]
    notations = re.finditer(notation_1, timetable)
    text_patterns = {'time_ranges': time_ranges, 'days': days,
                     'notations': notations}
    return text_patterns

# %%
# 3
# Digitalise time-patterns in text:

# Check for empty iterator
def next_element(my_iter):
    try:
        element = next(my_iter)
    except StopIteration:
        return None
    return element

# Convert time from 'str' to 'list[int_1, int_2]'
# Example: ('9:00-18:00') to [900, 1800]
def convert_time(time_str):
    time_range = re.split(r'[^\d, :]', time_str[0])
    open_time = re.split(r'[^\d]', time_range[0])
    close_time = re.split(r'[^\d]', time_range[1])
    return [int(open_time[0] + open_time[1]),\
            int(close_time[0] + close_time[1])]

# Convert days in the form: 'пн' - '1', 'вт' - '2', ...
def convert_day(day):
    before = ['пн', 'вт', 'ср', 'чт', 'пт', 'сб', 'вс']
    after = ['1', '2', '3', '4', '5', '6', '7']
    converted = None
    for i in range(len(before)):
        if day[0] == before[i]:
            converted = after[i]
    return converted

# Defines working hours if there is time_range in text
def time_case(text_patterns):
    days = []
    for day in text_patterns['days']:
        day, isDay = tee(day)
        if next_element(isDay):
            days.append(next_element(day))
    for day in days:
        convert_day(day)
    for time_patt in text_patterns['time_ranges']:
        time_range = convert_time(time_patt)
    open_hours = {day[0]: time_range for day in days}
            #if day.end() < time_patt.start():
                
    return open_hours


def notation_case(text_patterns):   
    pass

# Returns timetable in final format
def find_open_hours(text_patterns):
    
    # Final format of timetable:
    # keys = days of week, values = open hours
    open_hours = {'1', '2', '3', '4', '5', '6', '7'}
    
    text_patterns['time_ranges'], \
                time_range = tee(text_patterns['time_ranges'])
    text_patterns['notations'], \
                notation = tee(text_patterns['notations'])
    if next_element(time_range):
        open_hours = time_case(text_patterns)
    if next_element(notation):
        open_hours = notation_case(text_patterns)
    
    return open_hours

def digitalise(text):
    text_patterns = find_patterns(text)
    open_hours = find_open_hours(text_patterns)
    return open_hours

# %%
# 4
# "main", writes new file with digitalised time
counter = Counter()
with open(direct + out_file + ".json",
          'r', encoding = "utf-8") as inf:
    timetables = json.load(inf)
    for timetable in timetables:
        open_hours = digitalise(timetable)
        print(open_hours)
        #print(timetable)
        
        
        #counter.update(open_hours, timetable)
    #for entity in counter.most_common():
        #print (entity)
# Out:
# {'вт': [1030, 2100], 'ср': [1030, 2100], 'чт': [1030, 2100], 'пт': [1030, 2100], 'сб': [1030, 2100], 'вс': [1030, 2100]}
# {'вт': [1000, 1630], 'вс': [1000, 1630]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1000, 2230], 'вт': [1000, 2230], 'вс': [1000, 2230]}
# {}
# {}
# {}
# {'ср': [1100, 1700], 'вс': [1100, 1700]}
# {'пн': [1000, 2200], 'ср': [1000, 2200], 'вс': [1000, 2200]}
# {}
# {'пн': [1100, 1800], 'сб': [1100, 1800], 'вс': [1100, 1800]}
# {}
# {'вт': [1100, 1630], 'сб': [1100, 1630]}
# {'пн': [1100, 1900], 'пт': [1100, 1900], 'сб': [1100, 1900], 'вс': [1100, 1900]}
# {}
# {'3', '7', '5', '2', '1', '6', '4'}
# {}
# {'пн': [2200, 600], 'сб': [2200, 600]}
# {}
# {'пн': [1000, 1800], 'пт': [1000, 1800], 'сб': [1000, 1800]}
# {}
# {}
# {'пн': [1100, 2130], 'сб': [1100, 2130]}
# {}
# {}
# {}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1000, 2000], 'вт': [1000, 2000], 'чт': [1000, 2000], 'вс': [1000, 2000]}
# {}
# {'ср': [1200, 1900], 'вс': [1200, 1900]}
# {'пн': [1100, 1900], 'пт': [1100, 1900], 'сб': [1100, 1900], 'вс': [1100, 1900]}
# {'вт': [1100, 1900], 'сб': [1100, 1900]}
# {'вт': [1200, 1900], 'вс': [1200, 1900]}
# {'вт': [930, 1630], 'пт': [930, 1630], 'сб': [930, 1630]}
# {'вт': [1200, 1700], 'сб': [1200, 1700], 'вс': [1200, 1700]}
# {'вт': [1100, 1800], 'пт': [1100, 1800], 'сб': [1100, 1800], 'вс': [1100, 1800]}
# {'ср': [1200, 2000], 'вс': [1200, 2000]}
# {}
# {'пн': [1300, 2000], 'пт': [1300, 2000], 'вс': [1300, 2000]}
# {}
# {'пн': [900, 1900], 'пт': [900, 1900]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {}
# {'вт': [1300, 2000], 'ср': [1300, 2000], 'чт': [1300, 2000], 'вс': [1300, 2000]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {}
# {}
# {'вт': [1300, 1700], 'сб': [1300, 1700]}
# {}
# {'пн': [1300, 2100], 'ср': [1300, 2100], 'чт': [1300, 2100], 'пт': [1300, 2100], 'вс': [1300, 2100]}
# {'пн': [1030, 1800], 'вт': [1030, 1800], 'чт': [1030, 1800], 'вс': [1030, 1800]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1100, 1730], 'вт': [1100, 1730], 'чт': [1100, 1730], 'вс': [1100, 1730]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1200, 2100], 'пт': [1200, 2100], 'сб': [1200, 2100], 'вс': [1200, 2100]}
# {'пн': [600, 2200], 'вс': [600, 2200]}
# {'пн': [1200, 0], 'чт': [1200, 0], 'пт': [1200, 0], 'сб': [1200, 0], 'вс': [1200, 0]}
# {'пн': [1000, 1600], 'вт': [1000, 1600], 'чт': [1000, 1600], 'вс': [1000, 1600]}
# {}
# {}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1130, 1830], 'пт': [1130, 1830], 'сб': [1130, 1830], 'вс': [1130, 1830]}
# {}
# {'пн': [900, 2000], 'пт': [900, 2000]}
# {'вт': [1200, 2000], 'сб': [1200, 2000]}
# {'пн': [1200, 2100], 'вт': [1200, 2100], 'ср': [1200, 2100], 'чт': [1200, 2100], 'пт': [1200, 2100], 'сб': [1200, 2100], 'вс': [1200, 2100]}
# {}
# {'пн': [1200, 2100], 'сб': [1200, 2100]}
# {'пн': [1000, 2000], 'ср': [1000, 2000], 'вс': [1000, 2000]}
# {}
# {'пн': [1100, 2200], 'пт': [1100, 2200], 'сб': [1100, 2200], 'вс': [1100, 2200]}
# {}
# {'пт': [2300, 600], 'сб': [2300, 600]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'вт': [1000, 1700], 'вс': [1000, 1700]}
# {}
# {}
# {'пн': [1400, 600], 'чт': [1400, 600], 'пт': [1400, 600], 'сб': [1400, 600], 'вс': [1400, 600]}
# {'пн': [800, 530], 'вт': [800, 530], 'вс': [800, 530]}
# {'ср': [2300, 600], 'пт': [2300, 600], 'сб': [2300, 600]}
# {}
# {}
# {'пн': [1200, 600], 'чт': [1200, 600], 'пт': [1200, 600], 'сб': [1200, 600], 'вс': [1200, 600]}
# {'пн': [900, 1600], 'чт': [900, 1600], 'пт': [900, 1600]}
# {'пн': [900, 2300], 'пт': [900, 2300], 'сб': [900, 2300], 'вс': [900, 2300]}
# {'пн': [830, 2130], 'пт': [830, 2130], 'сб': [830, 2130], 'вс': [830, 2130]}
# {'пт': [1000, 1815], 'сб': [1000, 1815], 'вс': [1000, 1815]}
# {'пн': [1000, 2200], 'чт': [1000, 2200], 'пт': [1000, 2200], 'сб': [1000, 2200], 'вс': [1000, 2200]}
# {'ср': [1000, 2100], 'чт': [1000, 2100], 'пт': [1000, 2100], 'сб': [1000, 2100], 'вс': [1000, 2100]}
# {'пн': [900, 2100], 'вт': [900, 2100], 'ср': [900, 2100], 'чт': [900, 2100], 'пт': [900, 2100], 'сб': [900, 2100], 'вс': [900, 2100]}
# {'пн': [1000, 2300], 'пт': [1000, 2300], 'сб': [1000, 2300], 'вс': [1000, 2300]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {}
# {'сб': [1200, 1900], 'вс': [1200, 1900]}
# {'пн': [1200, 2000], 'ср': [1200, 2000], 'чт': [1200, 2000], 'пт': [1200, 2000], 'вс': [1200, 2000]}
# {'ср': [1100, 1700], 'чт': [1100, 1700], 'вс': [1100, 1700]}
# {}
# {}
# {'пн': [1100, 1700], 'вт': [1100, 1700], 'чт': [1100, 1700], 'вс': [1100, 1700]}
# {'пн': [1300, 2100], 'вт': [1300, 2100], 'чт': [1300, 2100], 'вс': [1300, 2100]}
# {'вт': [1100, 1700], 'сб': [1100, 1700]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1200, 2200], 'пт': [1200, 2200], 'сб': [1200, 2200], 'вс': [1200, 2200]}
# {}
# {}
# {}
# {'вт': [1100, 1745], 'сб': [1100, 1745]}
# {'пн': [1200, 2000], 'ср': [1200, 2000], 'чт': [1200, 2000], 'вс': [1200, 2000]}
# {'пн': [1030, 2100], 'вт': [1030, 2100], 'ср': [1030, 2100], 'пт': [1030, 2100], 'вс': [1030, 2100]}
# {'пн': [900, 2100], 'пт': [900, 2100], 'сб': [900, 2100], 'вс': [900, 2100]}
# {'вт': [1030, 1700], 'вс': [1030, 1700]}
# {}
# {}
# {}
# {'пн': [1800, 600], 'чт': [1800, 600], 'пт': [1800, 600], 'сб': [1800, 600], 'вс': [1800, 600]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1400, 2100], 'пт': [1400, 2100]}
# {'вт': [1100, 2000], 'ср': [1100, 2000], 'чт': [1100, 2000], 'вс': [1100, 2000]}
# {}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'вт': [1800, 100], 'чт': [1800, 100], 'пт': [1800, 100], 'сб': [1800, 100]}
# {'пн': [1100, 2200], 'пт': [1100, 2200], 'сб': [1100, 2200], 'вс': [1100, 2200]}
# {'пн': [1400, 100], 'пт': [1400, 100], 'сб': [1400, 100], 'вс': [1400, 100]}
# {'пн': [1200, 100], 'чт': [1200, 100], 'пт': [1200, 100], 'сб': [1200, 100], 'вс': [1200, 100]}
# {'ср': [1200, 1700], 'пт': [1200, 1700], 'сб': [1200, 1700]}
# {'пн': [1100, 300], 'чт': [1100, 300], 'пт': [1100, 300], 'сб': [1100, 300], 'вс': [1100, 300]}
# {}
# {'пн': [1000, 1600], 'чт': [1000, 1600], 'пт': [1000, 1600], 'сб': [1000, 1600], 'вс': [1000, 1600]}
# {}
# {'пн': [1200, 600], 'чт': [1200, 600], 'пт': [1200, 600], 'сб': [1200, 600], 'вс': [1200, 600]}
# {'пн': [1100, 1700], 'пт': [1100, 1700]}
# {'пн': [1000, 1700], 'пт': [1000, 1700]}
# {}
# {'пн': [1100, 1650], 'ср': [1100, 1650], 'вс': [1100, 1650]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {}
# {'пн': [1300, 0], 'чт': [1300, 0], 'пт': [1300, 0], 'сб': [1300, 0], 'вс': [1300, 0]}
# {'пн': [900, 1600], 'чт': [900, 1600], 'пт': [900, 1600]}
# {'пн': [1100, 1700], 'чт': [1100, 1700], 'пт': [1100, 1700], 'сб': [1100, 1700]}
# {'ср': [1000, 1715], 'вс': [1000, 1715]}
# {'ср': [1000, 1800], 'вс': [1000, 1800]}
# {'ср': [1100, 1900], 'вс': [1100, 1900]}
# {'ср': [1100, 1800], 'вс': [1100, 1800]}
# {}
# {'пн': [1000, 1630], 'чт': [1000, 1630], 'пт': [1000, 1630], 'сб': [1000, 1630]}
# {'пн': [1000, 1700], 'чт': [1000, 1700], 'пт': [1000, 1700], 'сб': [1000, 1700]}
# {'вт': [1200, 2000], 'вс': [1200, 2000]}
# {'пн': [1100, 1800], 'вт': [1100, 1800], 'чт': [1100, 1800], 'вс': [1100, 1800]}
# {'ср': [1030, 1700], 'вс': [1030, 1700]}
# {'вт': [1100, 1900], 'вс': [1100, 1900]}
# {'пн': [1000, 1700], 'пт': [1000, 1700]}
# {'пн': [1000, 1700], 'вт': [1000, 1700], 'чт': [1000, 1700], 'пт': [1000, 1700], 'сб': [1000, 1700], 'вс': [1000, 1700]}
# {'вт': [1000, 1830], 'чт': [1000, 1830], 'вс': [1000, 1830]}
# {'пн': [1300, 2100], 'ср': [1300, 2100], 'чт': [1300, 2100], 'пт': [1300, 2100], 'вс': [1300, 2100]}
# {'пн': [1000, 2000], 'вт': [1000, 2000], 'ср': [1000, 2000], 'пт': [1000, 2000], 'сб': [1000, 2000], 'вс': [1000, 2000]}
# {}
# {'пн': [1100, 1700], 'вт': [1100, 1700]}
# {'пн': [1100, 1630], 'пт': [1100, 1630]}
# {'ср': [1100, 2000], 'чт': [1100, 2000], 'вс': [1100, 2000]}
# {}
# {'пн': [1100, 1800], 'вт': [1100, 1800], 'чт': [1100, 1800], 'вс': [1100, 1800]}
# {'вт': [1030, 2000], 'ср': [1030, 2000], 'чт': [1030, 2000], 'пт': [1030, 2000], 'сб': [1030, 2000], 'вс': [1030, 2000]}
# {'вт': [1400, 2000], 'чт': [1400, 2000], 'пт': [1400, 2000], 'сб': [1400, 2000]}
# {}
# {'вт': [1000, 1700], 'вс': [1000, 1700]}
# {'ср': [1000, 1700], 'сб': [1000, 1700]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'ср': [1030, 1800], 'вс': [1030, 1800]}
# {'ср': [1100, 1900], 'чт': [1100, 1900], 'пт': [1100, 1900], 'вс': [1100, 1900]}
# {'пн': [1000, 1800], 'сб': [1000, 1800]}
# {}
# {'пн': [1300, 2100], 'ср': [1300, 2100], 'чт': [1300, 2100], 'пт': [1300, 2100], 'вс': [1300, 2100]}
# {'пн': [1300, 2100], 'ср': [1300, 2100], 'чт': [1300, 2100], 'вс': [1300, 2100]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1130, 1930], 'сб': [1130, 1930]}
# {'вт': [1000, 1800], 'вс': [1000, 1800]}
# {}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'вт': [1100, 1900], 'ср': [1100, 1900], 'сб': [1100, 1900], 'вс': [1100, 1900]}
# {'пн': [1230, 1930], 'ср': [1230, 1930], 'чт': [1230, 1930], 'вс': [1230, 1930]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {}
# {}
# {}
# {}
# {'пн': [1000, 1900], 'пт': [1000, 1900]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'вт': [1100, 2000], 'вс': [1100, 2000]}
# {'вт': [1000, 1500], 'пт': [1000, 1500], 'сб': [1000, 1500]}
# {'пн': [1000, 2200], 'пт': [1000, 2200], 'сб': [1000, 2200], 'вс': [1000, 2200]}
# {'ср': [1800, 2300], 'вс': [1800, 2300]}
# {'пн': [1100, 400], 'чт': [1100, 400], 'пт': [1100, 400], 'сб': [1100, 400], 'вс': [1100, 400]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1800, 500], 'чт': [1800, 500], 'пт': [1800, 500], 'сб': [1800, 500], 'вс': [1800, 500]}
# {'пн': [1700, 2300], 'чт': [1700, 2300], 'пт': [1700, 2300], 'сб': [1700, 2300]}
# {'пн': [900, 2300], 'чт': [900, 2300], 'пт': [900, 2300], 'вс': [900, 2300]}
# {'ср': [1200, 2000], 'пт': [1200, 2000], 'сб': [1200, 2000], 'вс': [1200, 2000]}
# {'пн': [1000, 1800], 'пт': [1000, 1800], 'сб': [1000, 1800]}
# {'сб': [700, 1700], 'вс': [700, 1700]}
# {'пн': [1000, 2300], 'пт': [1000, 2300], 'сб': [1000, 2300], 'вс': [1000, 2300]}
# {'пн': [1100, 2200], 'пт': [1100, 2200], 'сб': [1100, 2200], 'вс': [1100, 2200]}
# {'пн': [1000, 2300], 'пт': [1000, 2300], 'сб': [1000, 2300], 'вс': [1000, 2300]}
# {'пн': [900, 2230], 'пт': [900, 2230], 'сб': [900, 2230], 'вс': [900, 2230]}
# {}
# {'пн': [1200, 1900], 'пт': [1200, 1900], 'сб': [1200, 1900], 'вс': [1200, 1900]}
# {}
# {'пн': [1300, 2330], 'чт': [1300, 2330], 'пт': [1300, 2330], 'сб': [1300, 2330], 'вс': [1300, 2330]}
# {'ср': [1100, 1700], 'сб': [1100, 1700], 'вс': [1100, 1700]}
# {'пн': [900, 1800], 'пт': [900, 1800]}
# {'пн': [1300, 1700], 'сб': [1300, 1700], 'вс': [1300, 1700]}
# {}
# {}
# {}
# {'пн': [1900, 2300], 'пт': [1900, 2300]}
# {}
# {}
# {'пн': [1100, 1800], 'пт': [1100, 1800], 'сб': [1100, 1800]}
# {'пн': [1100, 100], 'вт': [1100, 100], 'вс': [1100, 100]}
# {}
# {}
# {}
# {'пн': [1600, 1900], 'вт': [1600, 1900], 'сб': [1600, 1900]}
# {}
# {}
# {}
# {}
# {}
# {'пн': [1000, 2300], 'пт': [1000, 2300], 'сб': [1000, 2300], 'вс': [1000, 2300]}
# {}
# {}
# {}
# {'пн': [1000, 2200], 'ср': [1000, 2200], 'чт': [1000, 2200], 'вс': [1000, 2200]}
# {'пн': [1000, 2], 'пт': [1000, 2], 'сб': [1000, 2], 'вс': [1000, 2]}
# {'пн': [1100, 0], 'чт': [1100, 0], 'пт': [1100, 0], 'сб': [1100, 0], 'вс': [1100, 0]}
# {'пн': [1630, 1900], 'вт': [1630, 1900], 'чт': [1630, 1900], 'пт': [1630, 1900], 'вс': [1630, 1900]}
# {'пн': [900, 2300], 'чт': [900, 2300], 'сб': [900, 2300], 'вс': [900, 2300]}
# {'сб': [1200, 2200], 'вс': [1200, 2200]}
# {'пн': [1930, 2130], 'чт': [1930, 2130]}
# {'пн': [800, 1930], 'сб': [800, 1930]}
# {'пн': [900, 2330], 'вт': [900, 2330], 'ср': [900, 2330], 'чт': [900, 2330], 'пт': [900, 2330], 'вс': [900, 2330]}
# {}
# {'пн': [1600, 100], 'чт': [1600, 100], 'пт': [1600, 100], 'сб': [1600, 100], 'вс': [1600, 100]}
# {'чт': [1100, 200], 'пт': [1100, 200], 'сб': [1100, 200], 'вс': [1100, 200]}
# {}
# {}
# {}
# {}
# {'вт': [1200, 100], 'вс': [1200, 100]}
# {'пт': [1200, 2215], 'сб': [1200, 2215], 'вс': [1200, 2215]}
# {'чт': [1300, 2100], 'сб': [1300, 2100], 'вс': [1300, 2100]}
# {'пн': [1100, 2200], 'пт': [1100, 2200], 'сб': [1100, 2200], 'вс': [1100, 2200]}
# {}
# {'пт': [2230, 500], 'сб': [2230, 500]}
# {}
# {}
# {}
# {'пн': [1100, 2100], 'сб': [1100, 2100], 'вс': [1100, 2100]}
# {}
# {'пн': [1000, 2230], 'пт': [1000, 2230]}
# {'пн': [1000, 1800], 'ср': [1000, 1800], 'вс': [1000, 1800]}
# {'пн': [900, 0], 'чт': [900, 0], 'пт': [900, 0], 'сб': [900, 0], 'вс': [900, 0]}
# {'пн': [1200, 200], 'чт': [1200, 200], 'пт': [1200, 200], 'сб': [1200, 200], 'вс': [1200, 200]}
# {'пн': [1200, 100], 'пт': [1200, 100], 'сб': [1200, 100], 'вс': [1200, 100]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {}
# {'пн': [1000, 200], 'чт': [1000, 200], 'пт': [1000, 200], 'сб': [1000, 200], 'вс': [1000, 200]}
# {'чт': [2000, 600], 'пт': [2000, 600], 'сб': [2000, 600]}
# {'вт': [1030, 1800], 'вс': [1030, 1800]}
# {'пн': [1100, 100], 'чт': [1100, 100], 'пт': [1100, 100], 'сб': [1100, 100], 'вс': [1100, 100]}
# {'ср': [1000, 1900], 'вс': [1000, 1900]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'ср': [1100, 1900], 'чт': [1100, 1900], 'вс': [1100, 1900]}
# {}
# {'пн': [1000, 1900], 'пт': [1000, 1900], 'сб': [1000, 1900], 'вс': [1000, 1900]}
# {}
# {}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1100, 1600], 'пт': [1100, 1600]}
# {}
# {'пн': [1100, 2200], 'пт': [1100, 2200], 'сб': [1100, 2200], 'вс': [1100, 2200]}
# {'вт': [1200, 2200], 'вс': [1200, 2200]}
# {'пн': [1000, 600], 'чт': [1000, 600], 'пт': [1000, 600], 'вс': [1000, 600]}
# {'пн': [1200, 100], 'чт': [1200, 100], 'пт': [1200, 100], 'сб': [1200, 100], 'вс': [1200, 100]}
# {'пн': [1400, 200], 'чт': [1400, 200], 'пт': [1400, 200], 'сб': [1400, 200], 'вс': [1400, 200]}
# {'пн': [1200, 200], 'чт': [1200, 200], 'пт': [1200, 200], 'сб': [1200, 200], 'вс': [1200, 200]}
# {}
# {}
# {}
# {}
# {}
# {}
# {'3', '7', '5', '2', '1', '6', '4'}
# {}
# {}
# {}
# {'пн': [1200, 100], 'чт': [1200, 100], 'пт': [1200, 100], 'сб': [1200, 100], 'вс': [1200, 100]}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'3', '7', '5', '2', '1', '6', '4'}
# {}
# {}
# {}
# {'пн': [730, 2200], 'вс': [730, 2200]}
# {}
# {}
# {}
# {}
# {'3', '7', '5', '2', '1', '6', '4'}
# {}
# {'пн': [1200, 600], 'ср': [1200, 600], 'чт': [1200, 600], 'сб': [1200, 600], 'вс': [1200, 600]}
# {'ср': [1200, 30], 'вс': [1200, 30]}
# {}
# {}
# {}
# {}
# {}
# {'сб': [1030, 1800], 'вс': [1030, 1800]}
# {}
# {}
# {'пт': [100, 300], 'сб': [100, 300]}
# {'пн': [1200, 600], 'вт': [1200, 600], 'ср': [1200, 600], 'чт': [1200, 600], 'пт': [1200, 600], 'сб': [1200, 600], 'вс': [1200, 600]}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'пн': [1300, 1900], 'пт': [1300, 1900]}
# {'пн': [1000, 2300], 'пт': [1000, 2300], 'сб': [1000, 2300], 'вс': [1000, 2300]}
# {'пн': [1500, 1800], 'чт': [1500, 1800], 'пт': [1500, 1800]}
# {'ср': [1000, 1600], 'вс': [1000, 1600]}
# {'ср': [1200, 2000], 'чт': [1200, 2000], 'пт': [1200, 2000], 'вс': [1200, 2000]}
# {'ср': [1100, 1730], 'чт': [1100, 1730], 'вс': [1100, 1730]}
# {'пн': [1100, 1900], 'вс': [1100, 1900]}
# {'пн': [1000, 1700], 'чт': [1000, 1700], 'пт': [1000, 1700], 'сб': [1000, 1700], 'вс': [1000, 1700]}
# {'пн': [1200, 2000], 'пт': [1200, 2000]}
# {'ср': [1400, 2100], 'вс': [1400, 2100]}
# {'пн': [1100, 2300], 'ср': [1100, 2300], 'чт': [1100, 2300], 'сб': [1100, 2300], 'вс': [1100, 2300]}
# {'пн': [1100, 2200], 'пт': [1100, 2200], 'сб': [1100, 2200], 'вс': [1100, 2200]}
# {'пн': [1100, 2100], 'пт': [1100, 2100], 'сб': [1100, 2100], 'вс': [1100, 2100]}
# {'пн': [900, 2300], 'пт': [900, 2300], 'сб': [900, 2300], 'вс': [900, 2300]}
# {'пн': [1200, 1900], 'ср': [1200, 1900], 'сб': [1200, 1900], 'вс': [1200, 1900]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'вт': [1200, 1800], 'вс': [1200, 1800]}
# {}
# {}
# {'пн': [1200, 2200], 'вс': [1200, 2200]}
# {'вт': [1200, 1500], 'чт': [1200, 1500], 'пт': [1200, 1500], 'сб': [1200, 1500], 'вс': [1200, 1500]}
# {'вт': [1000, 1730], 'вс': [1000, 1730]}
# {'сб': [1100, 2300], 'вс': [1100, 2300]}
# {'пн': [1000, 2300], 'чт': [1000, 2300], 'пт': [1000, 2300], 'сб': [1000, 2300], 'вс': [1000, 2300]}
# {'пн': [1200, 600], 'чт': [1200, 600], 'пт': [1200, 600], 'сб': [1200, 600], 'вс': [1200, 600]}
# {'пн': [1100, 2300], 'пт': [1100, 2300]}
# {'пн': [1400, 600], 'пт': [1400, 600], 'сб': [1400, 600], 'вс': [1400, 600]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'ср': [1000, 2000], 'чт': [1000, 2000], 'вс': [1000, 2000]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {}
# {'пн': [1800, 600], 'чт': [1800, 600], 'пт': [1800, 600], 'сб': [1800, 600], 'вс': [1800, 600]}
# {'пн': [2000, 1000], 'чт': [2000, 1000], 'пт': [2000, 1000], 'сб': [2000, 1000], 'вс': [2000, 1000]}
# {'пн': [1000, 2100], 'пт': [1000, 2100], 'сб': [1000, 2100], 'вс': [1000, 2100]}
# {'пн': [1000, 1630], 'вт': [1000, 1630], 'ср': [1000, 1630], 'вс': [1000, 1630]}
# {'пн': [1200, 2200], 'сб': [1200, 2200]}
# {}
# {'пн': [1000, 100], 'чт': [1000, 100], 'пт': [1000, 100], 'сб': [1000, 100], 'вс': [1000, 100]}
# {'чт': [1900, 400], 'пт': [1900, 400], 'сб': [1900, 400]}
# {'пн': [900, 2300], 'чт': [900, 2300], 'пт': [900, 2300], 'сб': [900, 2300], 'вс': [900, 2300]}
# {}
# {'пн': [900, 100], 'чт': [900, 100], 'пт': [900, 100], 'сб': [900, 100], 'вс': [900, 100]}
# {}
# {}
# {'пн': [1100, 2000]}
# {'пн': [1100, 2000], 'пт': [1100, 2000], 'сб': [1100, 2000], 'вс': [1100, 2000]}
# {'пт': [1000, 1700]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1100, 1700], 'ср': [1100, 1700], 'чт': [1100, 1700], 'пт': [1100, 1700], 'сб': [1100, 1700]}
# {}
# {'пн': [1000, 1800], 'чт': [1000, 1800], 'пт': [1000, 1800]}
# {'пн': [1000, 1700], 'чт': [1000, 1700], 'вс': [1000, 1700]}
# {'вт': [1300, 2100], 'ср': [1300, 2100], 'чт': [1300, 2100], 'вс': [1300, 2100]}
# {'ср': [1000, 1800], 'чт': [1000, 1800], 'сб': [1000, 1800]}
# {'пн': [900, 2300], 'пт': [900, 2300], 'сб': [900, 2300], 'вс': [900, 2300]}
# {'пн': [900, 600], 'чт': [900, 600], 'пт': [900, 600], 'сб': [900, 600], 'вс': [900, 600]}
# {'пн': [1000, 2200], 'пт': [1000, 2200]}
# {'пн': [1000, 0], 'пт': [1000, 0], 'сб': [1000, 0], 'вс': [1000, 0]}
# {}
# {'пн': [1500, 1000], 'чт': [1500, 1000], 'пт': [1500, 1000], 'сб': [1500, 1000]}
# {}
# {'пн': [1500, 600], 'вт': [1500, 600], 'пт': [1500, 600], 'сб': [1500, 600], 'вс': [1500, 600]}
# {'пн': [1500, 500], 'пт': [1500, 500], 'сб': [1500, 500], 'вс': [1500, 500]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1200, 600], 'чт': [1200, 600], 'пт': [1200, 600], 'сб': [1200, 600], 'вс': [1200, 600]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пт': [1230, 2100], 'вс': [1230, 2100]}
# {'пн': [1000, 2100], 'пт': [1000, 2100], 'сб': [1000, 2100], 'вс': [1000, 2100]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1200, 2300], 'чт': [1200, 2300], 'пт': [1200, 2300], 'сб': [1200, 2300], 'вс': [1200, 2300]}
# {'пн': [1000, 1900], 'вт': [1000, 1900], 'чт': [1000, 1900], 'вс': [1000, 1900]}
# {}
# {}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1000, 1700], 'вт': [1000, 1700], 'чт': [1000, 1700], 'вс': [1000, 1700]}
# {'вт': [1000, 1800], 'вс': [1000, 1800]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'3', '7', '5', '2', '1', '6', '4'}
# {}
# {'ср': [1000, 1700], 'пт': [1000, 1700]}
# {'ср': [1100, 1700], 'вс': [1100, 1700]}
# {'ср': [1000, 1600], 'вс': [1000, 1600]}
# {'вс': [1100, 1700]}
# {'ср': [1030, 1730], 'вс': [1030, 1730]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1200, 500], 'чт': [1200, 500], 'пт': [1200, 500], 'сб': [1200, 500], 'вс': [1200, 500]}
# {}
# {'чт': [1000, 2300], 'пт': [1000, 2300], 'сб': [1000, 2300], 'вс': [1000, 2300]}
# {'пт': [2000, 600], 'сб': [2000, 600]}
# {'пн': [830, 1700], 'пт': [830, 1700]}
# {'пн': [900, 2200], 'пт': [900, 2200], 'сб': [900, 2200], 'вс': [900, 2200]}
# {'пн': [1200, 300], 'чт': [1200, 300], 'пт': [1200, 300], 'сб': [1200, 300], 'вс': [1200, 300]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1900, 2100], 'ср': [1900, 2100]}
# {}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1100, 1800], 'сб': [1100, 1800], 'вс': [1100, 1800]}
# {'пн': [1200, 2000], 'сб': [1200, 2000], 'вс': [1200, 2000]}
# {'пн': [1200, 1900], 'сб': [1200, 1900], 'вс': [1200, 1900]}
# {'пн': [1800, 600], 'вс': [1800, 600]}
# {'пн': [1000, 2300], 'пт': [1000, 2300], 'сб': [1000, 2300], 'вс': [1000, 2300]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1200, 0], 'чт': [1200, 0], 'пт': [1200, 0], 'сб': [1200, 0], 'вс': [1200, 0]}
# {}
# {'вт': [1100, 600], 'пт': [1100, 600], 'сб': [1100, 600], 'вс': [1100, 600]}
# {'сб': [1030, 1700], 'вс': [1030, 1700]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'ср': [1400, 2000], 'вс': [1400, 2000]}
# {}
# {}
# {'пн': [1100, 1700], 'пт': [1100, 1700]}
# {'пн': [1200, 600], 'чт': [1200, 600], 'пт': [1200, 600], 'сб': [1200, 600], 'вс': [1200, 600]}
# {'пн': [1100, 1800], 'пт': [1100, 1800], 'сб': [1100, 1800]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1000, 2000], 'пт': [1000, 2000], 'сб': [1000, 2000], 'вс': [1000, 2000]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1000, 1700], 'пт': [1000, 1700]}
# {'пн': [1500, 1630], 'вт': [1500, 1630], 'чт': [1500, 1630]}
# {}
# {'пн': [1200, 400], 'вт': [1200, 400], 'чт': [1200, 400], 'пт': [1200, 400], 'сб': [1200, 400], 'вс': [1200, 400]}
# {}
# {'пн': [1200, 100], 'чт': [1200, 100], 'пт': [1200, 100], 'вс': [1200, 100]}
# {'пн': [1000, 2300], 'чт': [1000, 2300], 'пт': [1000, 2300], 'сб': [1000, 2300], 'вс': [1000, 2300]}
# {'пн': [1000, 100], 'вт': [1000, 100], 'ср': [1000, 100], 'сб': [1000, 100], 'вс': [1000, 100]}
# {'пн': [1100, 2300], 'пт': [1100, 2300], 'сб': [1100, 2300], 'вс': [1100, 2300]}
# {}
# {'пн': [1100, 2200], 'вт': [1100, 2200], 'чт': [1100, 2200], 'пт': [1100, 2200], 'сб': [1100, 2200], 'вс': [1100, 2200]}
# {}
# {}
# {'пн': [1200, 2000], 'вт': [1200, 2000], 'вс': [1200, 2000]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {}
# {'3', '7', '5', '2', '1', '6', '4'}
# {}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'ср': [1100, 1715], 'вс': [1100, 1715]}
# {'пн': [1000, 2100], 'чт': [1000, 2100], 'пт': [1000, 2100], 'сб': [1000, 2100], 'вс': [1000, 2100]}
# {'пн': [1500, 1900], 'пт': [1500, 1900], 'сб': [1500, 1900], 'вс': [1500, 1900]}
# {'вт': [1200, 2000], 'ср': [1200, 2000], 'чт': [1200, 2000], 'вс': [1200, 2000]}
# {'пн': [1000, 1700], 'ср': [1000, 1700], 'пт': [1000, 1700], 'вс': [1000, 1700]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {}
# {'пн': [1900, 600], 'чт': [1900, 600], 'пт': [1900, 600], 'сб': [1900, 600], 'вс': [1900, 600]}
# {}
# {}
# {}
# {}
# {'пн': [700, 1900], 'пт': [700, 1900]}
# {'ср': [1000, 1700], 'сб': [1000, 1700], 'вс': [1000, 1700]}
# {'пн': [800, 2000], 'пт': [800, 2000]}
# {'пн': [830, 2100], 'пт': [830, 2100]}
# {'сб': [1200, 1800], 'вс': [1200, 1800]}
# {'пн': [1430, 2200], 'ср': [1430, 2200], 'пт': [1430, 2200], 'вс': [1430, 2200]}
# {'пн': [1100, 1800], 'вт': [1100, 1800], 'чт': [1100, 1800], 'вс': [1100, 1800]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'вт': [1000, 1900], 'ср': [1000, 1900], 'пт': [1000, 1900], 'сб': [1000, 1900], 'вс': [1000, 1900]}
# {'пн': [1030, 1700], 'ср': [1030, 1700], 'вс': [1030, 1700]}
# {'вт': [1000, 1800], 'пт': [1000, 1800]}
# {'чт': [2359, 1000], 'вс': [2359, 1000]}
# {}
# {}
# {}
# {'пн': [1500, 1700], 'сб': [1500, 1700], 'вс': [1500, 1700]}
# {'пн': [1100, 600], 'чт': [1100, 600], 'пт': [1100, 600], 'сб': [1100, 600], 'вс': [1100, 600]}
# {'пн': [1000, 1800], 'пт': [1000, 1800], 'сб': [1000, 1800], 'вс': [1000, 1800]}
# {'чт': [1000, 1600], 'пт': [1000, 1600], 'сб': [1000, 1600], 'вс': [1000, 1600]}
# {'ср': [1700, 100], 'чт': [1700, 100], 'пт': [1700, 100], 'сб': [1700, 100], 'вс': [1700, 100]}
# {'вт': [1100, 1600], 'пт': [1100, 1600], 'сб': [1100, 1600], 'вс': [1100, 1600]}
# {'пн': [1200, 1900], 'вс': [1200, 1900]}
# {'вт': [1030, 2100], 'ср': [1030, 2100], 'чт': [1030, 2100], 'вс': [1030, 2100]}
# {'вт': [1500, 1900], 'вс': [1500, 1900]}
# {}
# {}
# {'ср': [1400, 1900], 'вс': [1400, 1900]}
# {'пн': [900, 1700], 'пт': [900, 1700]}
# {'вт': [1600, 2200], 'вс': [1600, 2200]}
# {'вт': [1000, 1900], 'сб': [1000, 1900]}
# {}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'вт': [1100, 1700], 'пт': [1100, 1700], 'сб': [1100, 1700]}
# {'вт': [1100, 2100], 'чт': [1100, 2100], 'пт': [1100, 2100], 'вс': [1100, 2100]}
# {'пн': [1540, 2000], 'пт': [1540, 2000], 'сб': [1540, 2000], 'вс': [1540, 2000]}
# {'пн': [1100, 1900], 'пт': [1100, 1900], 'сб': [1100, 1900], 'вс': [1100, 1900]}
# {'пн': [1200, 2100], 'пт': [1200, 2100], 'сб': [1200, 2100], 'вс': [1200, 2100]}
# {'пн': [1100, 1900], 'пт': [1100, 1900], 'сб': [1100, 1900], 'вс': [1100, 1900]}
# {'пн': [1100, 1800], 'пт': [1100, 1800], 'сб': [1100, 1800]}
# {'вт': [1500, 2000], 'чт': [1500, 2000]}
# {'пн': [1000, 2100], 'пт': [1000, 2100], 'сб': [1000, 2100], 'вс': [1000, 2100]}
# {'вт': [1100, 1700], 'чт': [1100, 1700], 'сб': [1100, 1700], 'вс': [1100, 1700]}
# {}
# {}
# {'пн': [1200, 1800], 'пт': [1200, 1800], 'сб': [1200, 1800]}
# {}
# {'пн': [1200, 1900], 'пт': [1200, 1900]}
# {'пт': [2200, 200], 'сб': [2200, 200]}
# {'вт': [900, 1700], 'вс': [900, 1700]}
# {'вт': [1400, 2100], 'ср': [1400, 2100], 'чт': [1400, 2100], 'вс': [1400, 2100]}
# {'пн': [1200, 2000], 'сб': [1200, 2000]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'вт': [1200, 1900], 'сб': [1200, 1900]}
# {'вт': [1100, 1800], 'вс': [1100, 1800]}
# {'сб': [1600, 2000]}
# {'пн': [1000, 2100], 'пт': [1000, 2100], 'сб': [1000, 2100], 'вс': [1000, 2100]}
# {'пн': [1100, 1900], 'сб': [1100, 1900], 'вс': [1100, 1900]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1300, 1800], 'пт': [1300, 1800], 'сб': [1300, 1800], 'вс': [1300, 1800]}
# {'пн': [1100, 1900], 'пт': [1100, 1900], 'сб': [1100, 1900], 'вс': [1100, 1900]}
# {}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'3', '7', '5', '2', '1', '6', '4'}
# {}
# {'пт': [0, 600], 'сб': [0, 600]}
# {}
# {'3', '7', '5', '2', '1', '6', '4'}
# {}
# {'пн': [2200, 800], 'чт': [2200, 800], 'пт': [2200, 800], 'сб': [2200, 800], 'вс': [2200, 800]}
# {'пн': [1100, 1500], 'пт': [1100, 1500], 'сб': [1100, 1500]}
# {'пн': [1800, 400], 'чт': [1800, 400], 'пт': [1800, 400], 'сб': [1800, 400], 'вс': [1800, 400]}
# {'пн': [930, 2100], 'пт': [930, 2100], 'сб': [930, 2100], 'вс': [930, 2100]}
# {'пн': [2100, 600], 'чт': [2100, 600], 'пт': [2100, 600], 'вс': [2100, 600]}
# {}
# {'пн': [930, 1800], 'вт': [930, 1800], 'ср': [930, 1800], 'чт': [930, 1800], 'сб': [930, 1800], 'вс': [930, 1800]}
# {'пн': [1400, 2200], 'вт': [1400, 2200], 'ср': [1400, 2200], 'чт': [1400, 2200], 'пт': [1400, 2200], 'сб': [1400, 2200], 'вс': [1400, 2200]}
# {'ср': [1900, 600], 'вс': [1900, 600]}
# {'чт': [1000, 1700], 'пт': [1000, 1700], 'сб': [1000, 1700], 'вс': [1000, 1700]}
# {}
# {}
# {'ср': [2200, 600], 'сб': [2200, 600]}
# {'пн': [1000, 1800], 'пт': [1000, 1800]}
# {'пн': [1400, 500], 'чт': [1400, 500], 'пт': [1400, 500], 'сб': [1400, 500], 'вс': [1400, 500]}
# {'чт': [2000, 445], 'пт': [2000, 445], 'сб': [2000, 445], 'вс': [2000, 445]}
# {'пн': [1800, 700], 'ср': [1800, 700], 'чт': [1800, 700], 'пт': [1800, 700], 'сб': [1800, 700]}
# {'пн': [1000, 2200], 'вс': [1000, 2200]}
# {'чт': [2200, 700], 'вс': [2200, 700]}
# {'пн': [1000, 1700], 'пт': [1000, 1700], 'сб': [1000, 1700], 'вс': [1000, 1700]}
# {'пн': [1100, 1800], 'пт': [1100, 1800]}
# {'сб': [1815, 1930], 'вс': [1815, 1930]}
# {'пн': [1000, 2000], 'вт': [1000, 2000], 'пт': [1000, 2000], 'сб': [1000, 2000]}
# {'сб': [1100, 1700], 'вс': [1100, 1700]}
# {'пн': [1200, 2100], 'пт': [1200, 2100], 'сб': [1200, 2100], 'вс': [1200, 2100]}
# {'чт': [1800, 2100]}
# {'вт': [1200, 1700], 'сб': [1200, 1700], 'вс': [1200, 1700]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1000, 1800], 'сб': [1000, 1800], 'вс': [1000, 1800]}
# {'пн': [1100, 1900]}
# {'пн': [1100, 2200], 'вт': [1100, 2200]}
# {}
# {'пн': [1600, 1900], 'вс': [1600, 1900]}
# {'пн': [1500, 1730], 'вт': [1500, 1730], 'ср': [1500, 1730], 'чт': [1500, 1730], 'пт': [1500, 1730], 'сб': [1500, 1730], 'вс': [1500, 1730]}
# {'вт': [900, 1200], 'ср': [900, 1200], 'сб': [900, 1200]}
# {'пн': [1300, 1800], 'пт': [1300, 1800], 'сб': [1300, 1800], 'вс': [1300, 1800]}
# {'вт': [1030, 1800], 'ср': [1030, 1800], 'чт': [1030, 1800], 'вс': [1030, 1800]}
# {'пн': [1400, 2200]}
# {}
# {'ср': [1000, 1700], 'вс': [1000, 1700]}
# {'пн': [1300, 1700], 'чт': [1300, 1700]}
# {'ср': [1200, 1800], 'чт': [1200, 1800], 'вс': [1200, 1800]}
# {'пн': [1000, 1700], 'пт': [1000, 1700]}
# {'пн': [1100, 1700], 'пт': [1100, 1700], 'сб': [1100, 1700]}
# {}
# {'ср': [1100, 1800], 'чт': [1100, 1800], 'вс': [1100, 1800]}
# {'пн': [1100, 1700], 'пт': [1100, 1700], 'сб': [1100, 1700]}
# {'пн': [1000, 2000], 'вс': [1000, 2000]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1300, 1400], 'пт': [1300, 1400]}
# {}
# {'пн': [1100, 1600], 'пт': [1100, 1600], 'сб': [1100, 1600]}
# {'пн': [1200, 1500], 'пт': [1200, 1500], 'сб': [1200, 1500]}
# {'пн': [1000, 2000], 'пт': [1000, 2000]}
# {'пн': [1400, 2000], 'пт': [1400, 2000]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1000, 1400], 'пт': [1000, 1400]}
# {'пн': [930, 1800], 'пт': [930, 1800]}
# {}
# {'ср': [1200, 1800], 'пт': [1200, 1800]}
# {'пн': [1100, 1900], 'ср': [1100, 1900], 'вс': [1100, 1900]}
# {'пн': [1500, 1900], 'сб': [1500, 1900]}
# {'пн': [1000, 2000], 'сб': [1000, 2000]}
# {'пн': [1200, 1900], 'пт': [1200, 1900], 'сб': [1200, 1900], 'вс': [1200, 1900]}
# {}
# {}
# {'вт': [1300, 2100], 'ср': [1300, 2100], 'чт': [1300, 2100], 'вс': [1300, 2100]}
# {}
# {'пн': [1200, 2100]}
# {'пн': [1100, 2100]}
# {'пн': [1200, 300], 'чт': [1200, 300], 'пт': [1200, 300], 'сб': [1200, 300], 'вс': [1200, 300]}
# {}
# {'пн': [1400, 800], 'чт': [1400, 800], 'пт': [1400, 800], 'сб': [1400, 800], 'вс': [1400, 800]}
# {'пн': [1600, 2300], 'чт': [1600, 2300], 'пт': [1600, 2300], 'сб': [1600, 2300], 'вс': [1600, 2300]}
# {'вт': [1000, 2000], 'ср': [1000, 2000], 'пт': [1000, 2000], 'сб': [1000, 2000], 'вс': [1000, 2000]}
# {'пн': [1200, 1800], 'пт': [1200, 1800], 'сб': [1200, 1800]}
# {}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'вт': [1000, 1700], 'сб': [1000, 1700]}
# {'вт': [900, 2100], 'вс': [900, 2100]}
# {'пн': [900, 2100], 'чт': [900, 2100]}
# {'пн': [1600, 600], 'чт': [1600, 600], 'пт': [1600, 600], 'сб': [1600, 600]}
# {}
# {'пн': [1100, 2000], 'пт': [1100, 2000], 'сб': [1100, 2000], 'вс': [1100, 2000]}
# {'вт': [1100, 1800], 'сб': [1100, 1800]}
# {'пн': [1000, 1500], 'сб': [1000, 1500]}
# {}
# {'3', '7', '5', '2', '1', '6', '4'}
# {}
# {'пн': [1700, 1900], 'пт': [1700, 1900]}
# {'пн': [1400, 1900], 'пт': [1400, 1900]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пт': [1200, 1800], 'вс': [1200, 1800]}
# {}
# {'пн': [1500, 2100], 'пт': [1500, 2100], 'сб': [1500, 2100]}
# {'пн': [1000, 1900], 'пт': [1000, 1900], 'сб': [1000, 1900], 'вс': [1000, 1900]}
# {'пн': [900, 2000], 'сб': [900, 2000]}
# {'пн': [1100, 2100], 'сб': [1100, 2100], 'вс': [1100, 2100]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1300, 2100], 'пт': [1300, 2100]}
# {'пн': [1000, 2100], 'сб': [1000, 2100]}
# {'пн': [800, 1900], 'пт': [800, 1900]}
# {'пн': [1400, 2100], 'сб': [1400, 2100]}
# {'пн': [900, 2100], 'пт': [900, 2100]}
# {'пн': [1500, 2100], 'пт': [1500, 2100]}
# {'пн': [1100, 2100], 'сб': [1100, 2100]}
# {'пн': [1100, 1930], 'пт': [1100, 1930], 'сб': [1100, 1930], 'вс': [1100, 1930]}
# {'пн': [1200, 2100], 'вт': [1200, 2100], 'сб': [1200, 2100]}
# {'пн': [1100, 2000], 'пт': [1100, 2000], 'сб': [1100, 2000]}
# {}
# {}
# {}
# {'пн': [1000, 2200], 'пт': [1000, 2200], 'сб': [1000, 2200], 'вс': [1000, 2200]}
# {}
# {'пн': [1100, 2000], 'пт': [1100, 2000]}
# {'ср': [1930, 2300]}
# {'пн': [1200, 2200], 'пт': [1200, 2200], 'сб': [1200, 2200], 'вс': [1200, 2200]}
# {'пн': [1500, 600], 'чт': [1500, 600], 'пт': [1500, 600], 'сб': [1500, 600], 'вс': [1500, 600]}
# {}
# {'пн': [1100, 1400], 'пт': [1100, 1400], 'сб': [1100, 1400]}
# {'пн': [1630, 1800], 'ср': [1630, 1800], 'пт': [1630, 1800]}
# {'пн': [1000, 2100], 'пт': [1000, 2100]}
# {'ср': [1400, 2100], 'чт': [1400, 2100], 'вс': [1400, 2100]}
# {'пн': [1100, 1800], 'пт': [1100, 1800], 'сб': [1100, 1800], 'вс': [1100, 1800]}
# {'пн': [1000, 2100], 'пт': [1000, 2100], 'сб': [1000, 2100], 'вс': [1000, 2100]}
# {'пн': [900, 1800], 'пт': [900, 1800], 'сб': [900, 1800], 'вс': [900, 1800]}
# {}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1000, 600], 'пт': [1000, 600], 'сб': [1000, 600], 'вс': [1000, 600]}
# {'пн': [1200, 600], 'пт': [1200, 600], 'сб': [1200, 600], 'вс': [1200, 600]}
# {}
# {'пт': [1300, 2100], 'сб': [1300, 2100], 'вс': [1300, 2100]}
# {'ср': [1200, 2200], 'пт': [1200, 2200], 'сб': [1200, 2200], 'вс': [1200, 2200]}
# {'пн': [1100, 400], 'чт': [1100, 400], 'пт': [1100, 400], 'сб': [1100, 400], 'вс': [1100, 400]}
# {'пн': [1100, 400], 'чт': [1100, 400], 'пт': [1100, 400], 'вс': [1100, 400]}
# {'пн': [1400, 200], 'чт': [1400, 200], 'пт': [1400, 200], 'сб': [1400, 200], 'вс': [1400, 200]}
# {'пн': [1600, 2000], 'пт': [1600, 2000], 'вс': [1600, 2000]}
# {'пн': [1100, 2300], 'сб': [1100, 2300]}
# {'пн': [900, 2100], 'сб': [900, 2100]}
# {'пн': [1000, 2200], 'вт': [1000, 2200]}
# {'пн': [1000, 2000], 'вт': [1000, 2000]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1130, 1900], 'пт': [1130, 1900], 'сб': [1130, 1900], 'вс': [1130, 1900]}
# {'пн': [1100, 2000], 'сб': [1100, 2000]}
# {'пн': [1100, 2000], 'пт': [1100, 2000], 'сб': [1100, 2000]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'вс': [1130, 1330]}
# {'пн': [1100, 1900], 'пт': [1100, 1900]}
# {'ср': [1000, 1900], 'пт': [1000, 1900], 'сб': [1000, 1900], 'вс': [1000, 1900]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'вт': [1000, 1800], 'пт': [1000, 1800], 'сб': [1000, 1800], 'вс': [1000, 1800]}
# {'пн': [1400, 0], 'пт': [1400, 0], 'сб': [1400, 0], 'вс': [1400, 0]}
# {}
# {'пн': [1100, 1700], 'пт': [1100, 1700], 'сб': [1100, 1700], 'вс': [1100, 1700]}
# {}
# {'пн': [900, 2200], 'пт': [900, 2200], 'сб': [900, 2200], 'вс': [900, 2200]}
# {'вт': [1000, 1730], 'вс': [1000, 1730]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [900, 230], 'пт': [900, 230], 'сб': [900, 230], 'вс': [900, 230]}
# {'пн': [1200, 500], 'ср': [1200, 500], 'чт': [1200, 500], 'пт': [1200, 500], 'сб': [1200, 500], 'вс': [1200, 500]}
# {'пн': [1000, 300], 'чт': [1000, 300], 'пт': [1000, 300], 'сб': [1000, 300], 'вс': [1000, 300]}
# {}
# {'пн': [100, 0], 'ср': [100, 0], 'чт': [100, 0], 'сб': [100, 0], 'вс': [100, 0]}
# {}
# {'пн': [1200, 200], 'чт': [1200, 200], 'пт': [1200, 200], 'сб': [1200, 200], 'вс': [1200, 200]}
# {'пн': [1100, 2300], 'чт': [1100, 2300], 'пт': [1100, 2300], 'сб': [1100, 2300], 'вс': [1100, 2300]}
# {'пн': [1200, 100], 'чт': [1200, 100], 'пт': [1200, 100], 'сб': [1200, 100]}
# {'вт': [1200, 600], 'чт': [1200, 600], 'пт': [1200, 600], 'сб': [1200, 600]}
# {}
# {'пн': [1100, 300], 'пт': [1100, 300], 'сб': [1100, 300], 'вс': [1100, 300]}
# {'пн': [1200, 100], 'чт': [1200, 100], 'пт': [1200, 100], 'сб': [1200, 100], 'вс': [1200, 100]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1200, 300], 'чт': [1200, 300], 'пт': [1200, 300], 'сб': [1200, 300], 'вс': [1200, 300]}
# {'пн': [1200, 200], 'чт': [1200, 200], 'пт': [1200, 200], 'сб': [1200, 200], 'вс': [1200, 200]}
# {'пн': [1300, 100], 'чт': [1300, 100], 'пт': [1300, 100], 'сб': [1300, 100], 'вс': [1300, 100]}
# {}
# {}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'чт': [800, 0], 'пт': [800, 0], 'сб': [800, 0], 'вс': [800, 0]}
# {'пн': [1200, 0], 'чт': [1200, 0], 'пт': [1200, 0], 'сб': [1200, 0], 'вс': [1200, 0]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [900, 300], 'чт': [900, 300], 'пт': [900, 300], 'сб': [900, 300], 'вс': [900, 300]}
# {'пн': [1200, 200], 'вс': [1200, 200]}
# {}
# {'пн': [1200, 100], 'чт': [1200, 100], 'пт': [1200, 100], 'сб': [1200, 100], 'вс': [1200, 100]}
# {'пн': [1200, 0], 'пт': [1200, 0], 'сб': [1200, 0], 'вс': [1200, 0]}
# {'пн': [1000, 400], 'чт': [1000, 400], 'пт': [1000, 400], 'сб': [1000, 400], 'вс': [1000, 400]}
# {'пн': [1300, 2330], 'вс': [1300, 2330]}
# {'пн': [1100, 600], 'чт': [1100, 600], 'пт': [1100, 600], 'сб': [1100, 600], 'вс': [1100, 600]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1200, 0], 'чт': [1200, 0], 'пт': [1200, 0], 'сб': [1200, 0], 'вс': [1200, 0]}
# {'пн': [1100, 200], 'чт': [1100, 200], 'пт': [1100, 200], 'сб': [1100, 200], 'вс': [1100, 200]}
# {'пн': [1200, 200], 'чт': [1200, 200], 'пт': [1200, 200], 'сб': [1200, 200], 'вс': [1200, 200]}
# {'пн': [1200, 2200], 'вт': [1200, 2200], 'ср': [1200, 2200], 'чт': [1200, 2200], 'пт': [1200, 2200], 'сб': [1200, 2200], 'вс': [1200, 2200]}
# {'пн': [2000, 500], 'чт': [2000, 500], 'пт': [2000, 500], 'сб': [2000, 500], 'вс': [2000, 500]}
# {'пн': [1300, 100], 'чт': [1300, 100], 'пт': [1300, 100], 'сб': [1300, 100], 'вс': [1300, 100]}
# {'пн': [1130, 300], 'чт': [1130, 300], 'пт': [1130, 300], 'сб': [1130, 300], 'вс': [1130, 300]}
# {'пн': [1500, 600], 'чт': [1500, 600], 'пт': [1500, 600], 'сб': [1500, 600], 'вс': [1500, 600]}
# {'пн': [1200, 100], 'чт': [1200, 100], 'пт': [1200, 100], 'сб': [1200, 100], 'вс': [1200, 100]}
# {'пн': [1200, 200], 'сб': [1200, 200], 'вс': [1200, 200]}
# {'пн': [1000, 2200], 'пт': [1000, 2200], 'сб': [1000, 2200], 'вс': [1000, 2200]}
# {'пн': [1200, 2300], 'вс': [1200, 2300]}
# {'пн': [1200, 200], 'чт': [1200, 200], 'пт': [1200, 200], 'вс': [1200, 200]}
# {'пн': [1200, 2300], 'чт': [1200, 2300], 'пт': [1200, 2300], 'сб': [1200, 2300], 'вс': [1200, 2300]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1200, 2400], 'вс': [1200, 2400]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1000, 0], 'пт': [1000, 0]}
# {'пн': [1200, 0], 'вс': [1200, 0]}
# {'пн': [1100, 2300], 'пт': [1100, 2300], 'сб': [1100, 2300], 'вс': [1100, 2300]}
# {'пн': [1100, 100], 'чт': [1100, 100], 'пт': [1100, 100], 'сб': [1100, 100], 'вс': [1100, 100]}
# {'пн': [2000, 600], 'чт': [2000, 600], 'пт': [2000, 600], 'сб': [2000, 600], 'вс': [2000, 600]}
# {'пн': [1100, 600], 'чт': [1100, 600], 'пт': [1100, 600], 'сб': [1100, 600], 'вс': [1100, 600]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1200, 200], 'чт': [1200, 200], 'пт': [1200, 200], 'сб': [1200, 200], 'вс': [1200, 200]}
# {'чт': [1300, 300], 'пт': [1300, 300], 'сб': [1300, 300], 'вс': [1300, 300]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1300, 200], 'чт': [1300, 200], 'пт': [1300, 200], 'сб': [1300, 200], 'вс': [1300, 200]}
# {'пн': [1100, 2300], 'чт': [1100, 2300], 'пт': [1100, 2300], 'сб': [1100, 2300], 'вс': [1100, 2300]}
# {'пт': [1200, 30], 'вс': [1200, 30]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1200, 100], 'чт': [1200, 100], 'пт': [1200, 100], 'сб': [1200, 100], 'вс': [1200, 100]}
# {'пн': [1400, 600], 'чт': [1400, 600], 'пт': [1400, 600], 'сб': [1400, 600], 'вс': [1400, 600]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1300, 100], 'чт': [1300, 100], 'пт': [1300, 100], 'сб': [1300, 100], 'вс': [1300, 100]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [730, 400], 'чт': [730, 400], 'пт': [730, 400], 'сб': [730, 400], 'вс': [730, 400]}
# {'пн': [1100, 0], 'чт': [1100, 0], 'пт': [1100, 0], 'сб': [1100, 0], 'вс': [1100, 0]}
# {'пн': [1200, 2300], 'вс': [1200, 2300]}
# {'пн': [1100, 130], 'чт': [1100, 130], 'пт': [1100, 130], 'сб': [1100, 130], 'вс': [1100, 130]}
# {}
# {'пн': [1300, 0], 'чт': [1300, 0], 'пт': [1300, 0], 'сб': [1300, 0], 'вс': [1300, 0]}
# {'пн': [1600, 600], 'чт': [1600, 600], 'пт': [1600, 600], 'сб': [1600, 600], 'вс': [1600, 600]}
# {}
# {'3', '7', '5', '2', '1', '6', '4'}
# {}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1200, 500], 'чт': [1200, 500], 'пт': [1200, 500], 'сб': [1200, 500], 'вс': [1200, 500]}
# {'пн': [1100, 2300], 'вс': [1100, 2300]}
# {'пн': [1200, 0], 'вс': [1200, 0]}
# {}
# {'пн': [1200, 230], 'чт': [1200, 230], 'пт': [1200, 230], 'сб': [1200, 230], 'вс': [1200, 230]}
# {'пн': [1200, 2330], 'чт': [1200, 2330], 'пт': [1200, 2330], 'сб': [1200, 2330], 'вс': [1200, 2330]}
# {'пн': [1200, 0], 'вс': [1200, 0]}
# {}
# {'пн': [1000, 1800], 'вс': [1000, 1800]}
# {}
# {}
# {'пн': [900, 500], 'чт': [900, 500], 'пт': [900, 500], 'сб': [900, 500], 'вс': [900, 500]}
# {}
# {'пн': [1000, 100], 'чт': [1000, 100], 'пт': [1000, 100], 'сб': [1000, 100], 'вс': [1000, 100]}
# {'пн': [800, 200], 'чт': [800, 200], 'пт': [800, 200], 'сб': [800, 200], 'вс': [800, 200]}
# {}
# {'пн': [1200, 2400], 'вс': [1200, 2400]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1200, 0], 'вс': [1200, 0]}
# {}
# {'пн': [1100, 2300], 'вс': [1100, 2300]}
# {'пн': [2000, 600], 'чт': [2000, 600], 'пт': [2000, 600], 'сб': [2000, 600], 'вс': [2000, 600]}
# {'пн': [700, 1030], 'сб': [700, 1030], 'вс': [700, 1030]}
# {}
# {'чт': [1100, 100], 'пт': [1100, 100], 'сб': [1100, 100], 'вс': [1100, 100]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1100, 2300], 'пт': [1100, 2300], 'сб': [1100, 2300], 'вс': [1100, 2300]}
# {'пн': [1200, 200], 'пт': [1200, 200], 'сб': [1200, 200], 'вс': [1200, 200]}
# {'пн': [1200, 2300], 'чт': [1200, 2300], 'пт': [1200, 2300], 'сб': [1200, 2300], 'вс': [1200, 2300]}
# {'пн': [1200, 2400], 'вс': [1200, 2400]}
# {}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [800, 2400], 'вс': [800, 2400]}
# {'пн': [1000, 2300], 'пт': [1000, 2300], 'сб': [1000, 2300], 'вс': [1000, 2300]}
# {'пн': [1400, 500], 'чт': [1400, 500], 'пт': [1400, 500], 'сб': [1400, 500], 'вс': [1400, 500]}
# {'пн': [1000, 1900], 'пт': [1000, 1900], 'сб': [1000, 1900], 'вс': [1000, 1900]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1200, 100], 'чт': [1200, 100], 'пт': [1200, 100], 'сб': [1200, 100], 'вс': [1200, 100]}
# {'пн': [1100, 230], 'чт': [1100, 230], 'пт': [1100, 230], 'сб': [1100, 230]}
# {'пн': [1200, 2300], 'пт': [1200, 2300], 'сб': [1200, 2300], 'вс': [1200, 2300]}
# {'пн': [900, 0], 'пт': [900, 0], 'сб': [900, 0], 'вс': [900, 0]}
# {'пн': [1200, 0], 'чт': [1200, 0], 'пт': [1200, 0], 'сб': [1200, 0], 'вс': [1200, 0]}
# {'пн': [1100, 2400], 'вс': [1100, 2400]}
# {'пн': [1100, 0], 'чт': [1100, 0], 'пт': [1100, 0], 'сб': [1100, 0], 'вс': [1100, 0]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1200, 2400], 'вс': [1200, 2400]}
# {'вт': [1100, 600], 'ср': [1100, 600], 'чт': [1100, 600], 'пт': [1100, 600], 'сб': [1100, 600], 'вс': [1100, 600]}
# {'пн': [1100, 300], 'чт': [1100, 300], 'пт': [1100, 300], 'сб': [1100, 300], 'вс': [1100, 300]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1300, 2330], 'пт': [1300, 2330], 'сб': [1300, 2330], 'вс': [1300, 2330]}
# {'пн': [730, 1100], 'вс': [730, 1100]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1300, 2300], 'чт': [1300, 2300], 'пт': [1300, 2300], 'сб': [1300, 2300], 'вс': [1300, 2300]}
# {'пн': [1200, 200], 'вс': [1200, 200]}
# {'пн': [1200, 2400], 'вс': [1200, 2400]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1200, 0], 'вс': [1200, 0]}
# {'пн': [930, 1730], 'пт': [930, 1730]}
# {'пт': [1800, 300], 'вс': [1800, 300]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1800, 500], 'чт': [1800, 500], 'пт': [1800, 500], 'сб': [1800, 500], 'вс': [1800, 500]}
# {'вт': [1000, 1800], 'чт': [1000, 1800]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [900, 345], 'пт': [900, 345], 'сб': [900, 345], 'вс': [900, 345]}
# {}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пт': [2300, 0], 'сб': [2300, 0]}
# {'пн': [1200, 100], 'ср': [1200, 100], 'чт': [1200, 100], 'сб': [1200, 100], 'вс': [1200, 100]}
# {}
# {'пн': [1000, 2200], 'пт': [1000, 2200], 'сб': [1000, 2200], 'вс': [1000, 2200]}
# {'пн': [1100, 2200], 'чт': [1100, 2200], 'пт': [1100, 2200], 'сб': [1100, 2200], 'вс': [1100, 2200]}
# {'пн': [1000, 0], 'пт': [1000, 0], 'сб': [1000, 0], 'вс': [1000, 0]}
# {'пн': [1030, 130], 'пт': [1030, 130], 'сб': [1030, 130], 'вс': [1030, 130]}
# {'пн': [1200, 2000], 'пт': [1200, 2000], 'сб': [1200, 2000]}
# {'пн': [1100, 2100], 'чт': [1100, 2100], 'пт': [1100, 2100], 'сб': [1100, 2100], 'вс': [1100, 2100]}
# {'пн': [1200, 200], 'ср': [1200, 200], 'чт': [1200, 200], 'пт': [1200, 200], 'сб': [1200, 200], 'вс': [1200, 200]}
# {'пн': [1300, 100], 'вт': [1300, 100], 'чт': [1300, 100], 'пт': [1300, 100], 'сб': [1300, 100], 'вс': [1300, 100]}
# {'пн': [1200, 0], 'вт': [1200, 0], 'чт': [1200, 0], 'пт': [1200, 0], 'сб': [1200, 0], 'вс': [1200, 0]}
# {'пн': [1200, 0], 'пт': [1200, 0], 'сб': [1200, 0], 'вс': [1200, 0]}
# {'пн': [1300, 0], 'чт': [1300, 0], 'пт': [1300, 0], 'сб': [1300, 0], 'вс': [1300, 0]}
# {'пн': [1200, 0], 'чт': [1200, 0], 'пт': [1200, 0], 'сб': [1200, 0], 'вс': [1200, 0]}
# {'пн': [1230, 0], 'чт': [1230, 0], 'пт': [1230, 0], 'сб': [1230, 0], 'вс': [1230, 0]}
# {'пн': [1000, 250], 'пт': [1000, 250], 'сб': [1000, 250], 'вс': [1000, 250]}
# {}
# {'пн': [900, 2200], 'пт': [900, 2200], 'сб': [900, 2200], 'вс': [900, 2200]}
# {'пн': [1300, 2300], 'чт': [1300, 2300], 'пт': [1300, 2300], 'сб': [1300, 2300], 'вс': [1300, 2300]}
# {'пн': [900, 2000], 'пт': [900, 2000], 'сб': [900, 2000], 'вс': [900, 2000]}
# {'ср': [1000, 2100], 'пт': [1000, 2100], 'сб': [1000, 2100], 'вс': [1000, 2100]}
# {}
# {'пн': [1200, 600], 'чт': [1200, 600], 'пт': [1200, 600], 'сб': [1200, 600], 'вс': [1200, 600]}
# {'пн': [1700, 400], 'чт': [1700, 400], 'пт': [1700, 400], 'сб': [1700, 400], 'вс': [1700, 400]}
# {'пн': [1200, 2030], 'пт': [1200, 2030], 'сб': [1200, 2030], 'вс': [1200, 2030]}
# {}
# {'пн': [800, 2300], 'пт': [800, 2300], 'сб': [800, 2300], 'вс': [800, 2300]}
# {'пн': [1200, 100], 'вт': [1200, 100], 'пт': [1200, 100], 'сб': [1200, 100], 'вс': [1200, 100]}
# {'пн': [1500, 30], 'чт': [1500, 30], 'пт': [1500, 30], 'сб': [1500, 30], 'вс': [1500, 30]}
# {'пн': [1400, 100], 'чт': [1400, 100], 'пт': [1400, 100], 'сб': [1400, 100], 'вс': [1400, 100]}
# {}
# {'пн': [1000, 1900], 'пт': [1000, 1900], 'сб': [1000, 1900], 'вс': [1000, 1900]}
# {}
# {'ср': [1200, 2300], 'вс': [1200, 2300]}
# {'пн': [1100, 2000], 'пт': [1100, 2000], 'сб': [1100, 2000], 'вс': [1100, 2000]}
# {'пн': [1300, 200], 'чт': [1300, 200], 'пт': [1300, 200], 'сб': [1300, 200], 'вс': [1300, 200]}
# {'пн': [1200, 0], 'пт': [1200, 0], 'сб': [1200, 0], 'вс': [1200, 0]}
# {'пн': [1100, 600], 'чт': [1100, 600], 'пт': [1100, 600], 'сб': [1100, 600], 'вс': [1100, 600]}
# {}
# {}
# {'пн': [1200, 2300], 'пт': [1200, 2300], 'сб': [1200, 2300], 'вс': [1200, 2300]}
# {'пн': [1100, 500], 'чт': [1100, 500], 'пт': [1100, 500], 'сб': [1100, 500], 'вс': [1100, 500]}
# {}
# {}
# {'пн': [2300, 700], 'чт': [2300, 700], 'пт': [2300, 700], 'сб': [2300, 700]}
# {'пн': [1100, 2200], 'сб': [1100, 2200], 'вс': [1100, 2200]}
# {'пн': [1130, 300], 'ср': [1130, 300], 'чт': [1130, 300], 'сб': [1130, 300], 'вс': [1130, 300]}
# {'пн': [1400, 2100], 'вт': [1400, 2100], 'чт': [1400, 2100], 'пт': [1400, 2100], 'сб': [1400, 2100]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {}
# {}
# {}
# {'пн': [900, 2000], 'пт': [900, 2000], 'сб': [900, 2000], 'вс': [900, 2000]}
# {}
# {'пн': [830, 0], 'чт': [830, 0], 'пт': [830, 0], 'сб': [830, 0], 'вс': [830, 0]}
# {'пн': [1130, 230], 'чт': [1130, 230], 'пт': [1130, 230], 'сб': [1130, 230], 'вс': [1130, 230]}
# {'пн': [1100, 2100], 'пт': [1100, 2100], 'сб': [1100, 2100], 'вс': [1100, 2100]}
# {'пн': [1130, 300], 'чт': [1130, 300], 'пт': [1130, 300], 'сб': [1130, 300], 'вс': [1130, 300]}
# {}
# {'пн': [1200, 100], 'чт': [1200, 100], 'пт': [1200, 100], 'сб': [1200, 100], 'вс': [1200, 100]}
# {'пн': [900, 1400], 'чт': [900, 1400], 'пт': [900, 1400], 'сб': [900, 1400], 'вс': [900, 1400]}
# {'пн': [1200, 0], 'чт': [1200, 0], 'пт': [1200, 0], 'сб': [1200, 0], 'вс': [1200, 0]}
# {'пн': [1200, 2300], 'пт': [1200, 2300], 'сб': [1200, 2300], 'вс': [1200, 2300]}
# {'пн': [1400, 2330], 'чт': [1400, 2330], 'пт': [1400, 2330], 'сб': [1400, 2330], 'вс': [1400, 2330]}
# {'пн': [1000, 100], 'чт': [1000, 100], 'пт': [1000, 100], 'сб': [1000, 100], 'вс': [1000, 100]}
# {'пн': [1000, 1900], 'сб': [1000, 1900]}
# {}
# {'пн': [1000, 2300], 'пт': [1000, 2300], 'сб': [1000, 2300], 'вс': [1000, 2300]}
# {'пн': [1100, 2200], 'чт': [1100, 2200], 'пт': [1100, 2200], 'сб': [1100, 2200], 'вс': [1100, 2200]}
# {'пн': [1600, 400], 'пт': [1600, 400], 'сб': [1600, 400], 'вс': [1600, 400]}
# {'пн': [1200, 2300], 'пт': [1200, 2300], 'сб': [1200, 2300], 'вс': [1200, 2300]}
# {}
# {'пн': [1300, 100], 'чт': [1300, 100], 'пт': [1300, 100], 'сб': [1300, 100], 'вс': [1300, 100]}
# {'пн': [1100, 300], 'ср': [1100, 300], 'чт': [1100, 300], 'сб': [1100, 300], 'вс': [1100, 300]}
# {'пн': [1100, 2300], 'чт': [1100, 2300], 'пт': [1100, 2300], 'сб': [1100, 2300], 'вс': [1100, 2300]}
# {'пн': [930, 1800], 'пт': [930, 1800]}
# {'пн': [1300, 0], 'чт': [1300, 0], 'пт': [1300, 0], 'сб': [1300, 0], 'вс': [1300, 0]}
# {'пн': [1200, 1830], 'пт': [1200, 1830], 'сб': [1200, 1830], 'вс': [1200, 1830]}
# {'пн': [1400, 100], 'чт': [1400, 100], 'пт': [1400, 100], 'сб': [1400, 100], 'вс': [1400, 100]}
# {'вт': [1100, 1900], 'пт': [1100, 1900], 'сб': [1100, 1900]}
# {'пн': [1000, 1815], 'сб': [1000, 1815]}
# {}
# {'пн': [1500, 2300], 'чт': [1500, 2300], 'пт': [1500, 2300], 'сб': [1500, 2300], 'вс': [1500, 2300]}
# {'пн': [930, 2200], 'пт': [930, 2200], 'сб': [930, 2200], 'вс': [930, 2200]}
# {'пн': [900, 2200], 'пт': [900, 2200], 'сб': [900, 2200], 'вс': [900, 2200]}
# {'пн': [1200, 2300], 'чт': [1200, 2300], 'пт': [1200, 2300], 'сб': [1200, 2300], 'вс': [1200, 2300]}
# {'пн': [1000, 2000], 'сб': [1000, 2000], 'вс': [1000, 2000]}
# {}
# {'пн': [1200, 2200], 'пт': [1200, 2200], 'сб': [1200, 2200], 'вс': [1200, 2200]}
# {'пн': [1000, 2000], 'пт': [1000, 2000], 'сб': [1000, 2000], 'вс': [1000, 2000]}
# {'пн': [1100, 2000], 'пт': [1100, 2000], 'сб': [1100, 2000], 'вс': [1100, 2000]}
# {'пн': [1000, 2000], 'ср': [1000, 2000], 'пт': [1000, 2000], 'вс': [1000, 2000]}
# {'пн': [1200, 700], 'чт': [1200, 700], 'пт': [1200, 700], 'сб': [1200, 700], 'вс': [1200, 700]}
# {}
# {'пн': [1400, 200], 'чт': [1400, 200], 'пт': [1400, 200], 'вс': [1400, 200]}
# {'пн': [1000, 2320], 'пт': [1000, 2320], 'сб': [1000, 2320], 'вс': [1000, 2320]}
# {'пн': [1000, 2330], 'пт': [1000, 2330], 'сб': [1000, 2330], 'вс': [1000, 2330]}
# {}
# {}
# {'пн': [1020, 2340], 'пт': [1020, 2340], 'сб': [1020, 2340], 'вс': [1020, 2340]}
# {}
# {'пн': [1000, 2320], 'пт': [1000, 2320], 'сб': [1000, 2320], 'вс': [1000, 2320]}
# {'пн': [1000, 2300], 'чт': [1000, 2300], 'пт': [1000, 2300], 'сб': [1000, 2300], 'вс': [1000, 2300]}
# {'пн': [1700, 2100], 'чт': [1700, 2100]}
# {}
# {'пн': [1200, 2359], 'пт': [1200, 2359], 'сб': [1200, 2359], 'вс': [1200, 2359]}
# {'пн': [1300, 100], 'чт': [1300, 100], 'пт': [1300, 100], 'сб': [1300, 100], 'вс': [1300, 100]}
# {'пн': [1400, 1800], 'пт': [1400, 1800], 'сб': [1400, 1800], 'вс': [1400, 1800]}
# {'пн': [1200, 500], 'чт': [1200, 500], 'пт': [1200, 500], 'сб': [1200, 500], 'вс': [1200, 500]}
# {'пн': [1500, 0], 'чт': [1500, 0], 'пт': [1500, 0], 'сб': [1500, 0], 'вс': [1500, 0]}
# {}
# {'пн': [1300, 400], 'чт': [1300, 400], 'пт': [1300, 400], 'сб': [1300, 400], 'вс': [1300, 400]}
# {'пн': [1100, 600], 'чт': [1100, 600], 'пт': [1100, 600], 'сб': [1100, 600]}
# {'ср': [2100, 600], 'вс': [2100, 600]}
# {'пн': [1000, 2200], 'чт': [1000, 2200], 'пт': [1000, 2200], 'сб': [1000, 2200], 'вс': [1000, 2200]}
# {'пн': [1200, 1800], 'пт': [1200, 1800], 'сб': [1200, 1800], 'вс': [1200, 1800]}
# {'вт': [1100, 1400], 'пт': [1100, 1400], 'вс': [1100, 1400]}
# {'пн': [1200, 600], 'ср': [1200, 600], 'чт': [1200, 600], 'сб': [1200, 600], 'вс': [1200, 600]}
# {'пт': [1200, 2300], 'сб': [1200, 2300], 'вс': [1200, 2300]}
# {'пн': [1100, 2100], 'пт': [1100, 2100], 'сб': [1100, 2100], 'вс': [1100, 2100]}
# {'пн': [900, 1800], 'сб': [900, 1800]}
# {'пн': [1100, 1900], 'пт': [1100, 1900], 'сб': [1100, 1900], 'вс': [1100, 1900]}
# {'пн': [1800, 2100], 'сб': [1800, 2100]}
# {'пн': [1200, 400], 'чт': [1200, 400], 'пт': [1200, 400], 'сб': [1200, 400], 'вс': [1200, 400]}
# {}
# {}
# {'пн': [1100, 2300], 'чт': [1100, 2300], 'пт': [1100, 2300], 'сб': [1100, 2300], 'вс': [1100, 2300]}
# {'пн': [1000, 0], 'пт': [1000, 0], 'сб': [1000, 0], 'вс': [1000, 0]}
# {'пн': [1000, 1700], 'пт': [1000, 1700], 'вс': [1000, 1700]}
# {}
# {'пн': [1100, 2300], 'чт': [1100, 2300], 'вс': [1100, 2300]}
# {'пн': [1200, 0], 'пт': [1200, 0], 'сб': [1200, 0], 'вс': [1200, 0]}
# {'пн': [1000, 2000], 'пт': [1000, 2000], 'сб': [1000, 2000], 'вс': [1000, 2000]}
# {'пт': [1800, 2100]}
# {}
# {'вт': [1200, 0], 'чт': [1200, 0], 'пт': [1200, 0], 'сб': [1200, 0]}
# {'пн': [1100, 1600], 'чт': [1100, 1600], 'пт': [1100, 1600], 'сб': [1100, 1600], 'вс': [1100, 1600]}
# {'вт': [1200, 1800], 'чт': [1200, 1800], 'сб': [1200, 1800]}
# {'пн': [1200, 2200], 'чт': [1200, 2200], 'пт': [1200, 2200], 'сб': [1200, 2200], 'вс': [1200, 2200]}
# {}
# {}
# {}
# {}
# {'пн': [1200, 2300], 'чт': [1200, 2300], 'пт': [1200, 2300], 'сб': [1200, 2300], 'вс': [1200, 2300]}
# {'пн': [1200, 200], 'чт': [1200, 200], 'пт': [1200, 200], 'вс': [1200, 200]}
# {'пн': [1000, 200], 'пт': [1000, 200], 'сб': [1000, 200], 'вс': [1000, 200]}
# {'вт': [1100, 600], 'чт': [1100, 600], 'пт': [1100, 600], 'сб': [1100, 600]}
# {'пн': [1000, 1900], 'пт': [1000, 1900], 'сб': [1000, 1900], 'вс': [1000, 1900]}
# {'пн': [1200, 1745], 'ср': [1200, 1745], 'вс': [1200, 1745]}
# {'пн': [1700, 600], 'чт': [1700, 600], 'пт': [1700, 600], 'сб': [1700, 600], 'вс': [1700, 600]}
# {'ср': [1300, 0], 'чт': [1300, 0], 'пт': [1300, 0], 'сб': [1300, 0], 'вс': [1300, 0]}
# {'пн': [1000, 0], 'чт': [1000, 0], 'пт': [1000, 0], 'сб': [1000, 0], 'вс': [1000, 0]}
# {'пн': [1200, 2359], 'чт': [1200, 2359], 'пт': [1200, 2359], 'сб': [1200, 2359], 'вс': [1200, 2359]}
# {'пн': [1200, 2300], 'чт': [1200, 2300], 'пт': [1200, 2300], 'сб': [1200, 2300], 'вс': [1200, 2300]}
# {'пн': [1100, 200], 'чт': [1100, 200], 'пт': [1100, 200], 'сб': [1100, 200], 'вс': [1100, 200]}
# {'пн': [1000, 2100], 'пт': [1000, 2100], 'сб': [1000, 2100], 'вс': [1000, 2100]}
# {'пн': [1100, 2300], 'чт': [1100, 2300], 'пт': [1100, 2300], 'сб': [1100, 2300], 'вс': [1100, 2300]}
# {'пн': [1200, 0], 'чт': [1200, 0], 'пт': [1200, 0], 'сб': [1200, 0], 'вс': [1200, 0]}
# {'пн': [1100, 0], 'чт': [1100, 0], 'пт': [1100, 0], 'сб': [1100, 0], 'вс': [1100, 0]}
# {}
# {'пн': [1000, 2200], 'чт': [1000, 2200], 'пт': [1000, 2200], 'вс': [1000, 2200]}
# {}
# {}
# {'пн': [1120, 2000], 'пт': [1120, 2000], 'сб': [1120, 2000], 'вс': [1120, 2000]}
# {}
# {'пн': [1200, 600], 'чт': [1200, 600], 'пт': [1200, 600], 'вс': [1200, 600]}
# {}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1030, 100], 'чт': [1030, 100], 'пт': [1030, 100], 'сб': [1030, 100], 'вс': [1030, 100]}
# {'пн': [1100, 1900], 'пт': [1100, 1900], 'сб': [1100, 1900], 'вс': [1100, 1900]}
# {'ср': [1900, 2300], 'вс': [1900, 2300]}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'3', '7', '5', '2', '1', '6', '4'}
# {'пн': [1000, 2100], 'пт': [1000, 2100], 'сб': [1000, 2100], 'вс': [1000, 2100]}
# {'пн': [1200, 2300], 'пт': [1200, 2300], 'сб': [1200, 2300], 'вс': [1200, 2300]}
# {'пн': [1300, 2300], 'чт': [1300, 2300], 'пт': [1300, 2300], 'сб': [1300, 2300], 'вс': [1300, 2300]}
# {'ср': [1800, 600], 'чт': [1800, 600], 'пт': [1800, 600], 'сб': [1800, 600], 'вс': [1800, 600]}
# {'пн': [1200, 200], 'ср': [1200, 200], 'чт': [1200, 200], 'сб': [1200, 200], 'вс': [1200, 200]}
# {'пн': [1400, 100], 'пт': [1400, 100], 'сб': [1400, 100], 'вс': [1400, 100]}
# {'пн': [1100, 2300], 'пт': [1100, 2300], 'сб': [1100, 2300], 'вс': [1100, 2300]}
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-92208d123ac2> in <module>
#       6     timetables = json.load(inf)
#       7     for timetable in timetables:
# ----> 8         open_hours = digitalise(timetable)
#       9         print(open_hours)
#      10         #print(timetable)
#
# <ipython-input-16-5e9c402b4797> in digitalise(text)
#      69 def digitalise(text):
#      70     text_patterns = find_patterns(text)
# ---> 71     open_hours = find_open_hours(text_patterns)
#      72     return open_hours
#
# <ipython-input-16-5e9c402b4797> in find_open_hours(text_patterns)
#      61                 notation = tee(text_patterns['notations'])
#      62     if next_element(time_range):
# ---> 63         open_hours = time_case(text_patterns)
#      64     if next_element(notation):
#      65         open_hours = notation_case(text_patterns)
#
# <ipython-input-16-5e9c402b4797> in time_case(text_patterns)
#      39         convert_day(day)
#      40     for time_patt in text_patterns['time_ranges']:
# ---> 41         time_range = convert_time(time_patt)
#      42     open_hours = {day[0]: time_range for day in days}
#      43             #if day.end() < time_patt.start():
#
# <ipython-input-16-5e9c402b4797> in convert_time(time_str)
#      15     time_range = re.split(r'[^\d, :]', time_str[0])
#      16     open_time = re.split(r'[^\d]', time_range[0])
# ---> 17     close_time = re.split(r'[^\d]', time_range[1])
#      18     return [int(open_time[0] + open_time[1]),\
#      19             int(close_time[0] + close_time[1])]
#
# IndexError: list index out of range

# %%
# Time range, example: "10:00-0:10"
time_patt = r'\d{1,2}:\d\d[^,]\d{1,2}:\d\d'    #! [^,] \W

# Week days, example: "пн"
mon = r'\bпн\b'
tue = r'\bвт\b'
wed = r'\bср\b'
thu = r'\bчт\b'
fri = r'\bпт\b'
sat = r'\bсб\b'
sun = r'\bвс\b'
week_days = [mon, tue, wed, thu, fri, sat, sun]

# Convert time from 'str' to 'list[int_1, int_2]'
# Example: ('9:00-18:00') to [900, 1800]
def convert_time_1(time_str):
    time_range = re.split(r'[^\d, :]', time_str[0])
    open_time = re.split(r'[^\d]', time_range[0])
    close_time = re.split(r'[^\d]', time_range[1])
    if open_time and close_time:
        time = [int(open_time[0] + open_time[1]),\
            int(close_time[0] + close_time[1])]
    else:
        time = None
    return time

def define_days():
    pass

def digitalise_1(text):
    timetable = {}
    shift = 0
    time = re.search(time_patt, text[shift:-1])
    while time:
        hours = convert_time_1(time)
        for day in range(7):    # represents week days
            if re.search(week_days[day], text[0:shift]):
                # monday == 1 when day == 0
                timetable[str(day+1)] = hours    
        days = define_days()
        shift += time.end()
        time = re.search(time_patt, text[shift:-1])
    return timetable

with open(direct + out_file + ".json",
          'r', encoding = "utf-8") as inf:
    timetables = json.load(inf)
    for text in timetables:
        open_hours = digitalise_1(text)
        print(text)
        print(open_hours)
# Out:
# вт, чт, сб, вс 10:30–18:00, ср, пт 10:30–21:00
# {}
# вт–вс 10:00–18:00 (касса: вт–вс 10:00–16:30)
# {'2': [1000, 1630], '7': [1000, 1630]}
#
# {}
# ежедневно 11:00–22:00
# {}
# Расписание событий текущего месяца – на официальном сайте.
# {}
# пн 15:00–22:30, вт–вс 10:00–22:30
# {}
# ежедневно 9:00–21:00
# {}
# касса: ежедневно 11:00–19:00
# {}
# касса: ежедневно 12:00–21:00
# {}
# ср–вс 11:00–18:00 (касса: ср–вс 11:00–17:00)
# {'3': [1100, 1700], '7': [1100, 1700]}
# пн, ср–вс 10:00–22:00
# {}
# ежедневно 11:00–21:00 (касса: ежедневно 11:00–20:30)
# {}
# пн–сб 11:00–20:00, вс 11:00–18:00
# {}
# ежедневно 8:00–0:00
# {}
# вт–сб 11:00–17:00 (касса: вт–сб 11:00–16:30)
# {'2': [1100, 1630], '6': [1100, 1630]}
# касса: пн–пт 11:00–20:00, сб, вс 11:00–19:00
# {}
# касса: ежедневно 11:00–20:00
# {}
# ежедневно весь день
# {}
# ежедневно 16:00–21:00 (касса: ежедневно 11:00–15:00)
# {}
# пн–сб 22:00–6:00
# {}
# ежедневно 10:00–22:00
# {}
# пн–пт 9:00–20:00, сб 10:00–18:00
# {}
# касса: ежедневно 10:00–21:00
# {}
# ежедневно 11:30–23:30
# {}
# пн–сб 11:00–21:30
# {}
# ежедневно 18:00–6:00
# {}
# ежедневно 11:00–20:00
# {}
# ежедневно 19:00 (касса: ежедневно 12:00–22:30)
# {}
# ежедневно 18:00
# {}
# пн, вт, чт–вс 10:00–20:00
# {}
# ежедневно 9:00–18:00
# {}
# ср–вс 12:00–19:00
# {}
# пн–пт 11:00–20:00, сб, вс 11:00–19:00
# {}
# вт–сб 11:00–19:00
# {}
# вт–вс 12:00–19:00
# {}
# вт–пт 9:30–17:30, сб 9:30–16:30
# {}
# вт, сб, вс 12:00–17:00
# {}
# вт–пт 12:00–20:00, сб, вс 11:00–18:00
# {}
# ср–вс 12:00–20:00
# {}
# ежедневно 19:00–23:00 (касса: ежедневно 10:00–22:00)
# {}
# вс 11:00–18:00, пн–пт 13:00–20:00
# {}
# ежедневно 7:00–21:00 (касса: ежедневно 9:00–19:00)
# {}
# пн–пт 9:00–19:00
# {}
# уточнять на сайте или по телефону
# {}
# касса: ежедневно 11:00–15:00 16:00–21:00
# {}
# вт, чт–вс 11:00–18:00, ср 13:00–20:00
# {}
# круглосуточно
# {}
# ежедневно 10:00–23:00
# {}
# касса: ежедневно 11:00–14:00 15:00–20:00
# {}
# вт–сб 13:00–17:00
# {}
# ежедневно 10:00–18:00
# {}
# пн 10:00–20:00, ср, пт–вс 10:00–18:00, чт 13:00–21:00
# {'1': [1000, 1800]}
# пн, вт, чт–вс 10:30–18:00
# {}
# уточняйте на сайте или по телефону
# {}
# пн, чт–вс 11:00–18:00, вт 11:00–17:30
# {}
# пн-вс, с 11:00 до 21:00
# {}
# пн–пт 9:00–21:00, сб, вс 12:00–21:00
# {}
# пн–вс 06:00–22:00
# {}
# пн–чт, вс 12:00–23:00, пт, сб 12:00–0:00
# {}
# пн, вт, чт–вс 10:00–16:00
# {}
# ежедневно 10:00–18:00 (касса: ежедневно 10:00–17:00)
# {}
# ежедневно 11:00–23:00
# {}
# по предварительной договоренности
# {}
# пн.- пт. с 11:00 до 19:00, сб.,вс. – выходной
# {}
# пн–пт 11:00–19:30, сб, вс 11:30–18:30
# {}
# ежедневно 8:00–6:00
# {}
# пн–пт 9:00–20:00
# {}
# вт–сб 12:00–20:00
# {}
# пн, ср, сб, вс 11:00–19:00, вт, чт, пт 12:00–21:00
# {}
# ежедневно 11:00–0:00
# {}
# пн–сб 12:00–21:00
# {}
# пн, ср–вс 10:00–20:00
# {}
# ежедневно 11:00–21:00
# {}
# пн–пт 8:00–22:00, сб, вс 11:00–22:00
# {}
# 8:00–22:00; 22:00–05:00
# {}
# пт, сб 23:00–6:00
# {}
# уточнять на сайте дворца или по телефону
# {}
# вт–вс 10:00–18:00 (касса: вт–вс 10:00–17:00)
# {'2': [1000, 1700], '7': [1000, 1700]}
# ежедневно 9:00–20:00
# {}
# ежедневно 9:00–0:00
# {}
# пн–чт 12:00–2:00, пт 12:00–6:00, сб, вс 14:00–6:00
# {'1': [1200, 600], '4': [1200, 600]}
# пн 8:00–1:00, вт–вс 8:00–5:30
# {}
# ср, пт, сб 23:00–6:00
# {}
# ежедневно 11:00–17:00
# {}
# ежедневно 11:00–1:00
# {}
# пн–чт, вс 12:00–2:00, пт, сб 12:00–6:00
# {}
# пн–чт 09:00–17:00; пт 09:00–16:00
# {}
# пн–пт 10:00–23:00, сб, вс 9:00–23:00
# {}
# пн–пт 7:30–21:30, сб, вс 8:30–21:30
# {}
# пт, сб 0:30–5:45, сб 13:30–20:45, вс 10:00–18:15
# {'5': [1330, 2045], '6': [1330, 2045]}
# пн–чт 12:00–22:00, пт 12:00–23:00, сб 10:00–23:00, вс 10:00–22:00
# {'1': [1000, 2300], '4': [1000, 2300], '5': [1000, 2300]}
# ср, чт 15:00–21:00, пт 15:00–22:00, сб 10:00–22:00, вс 10:00–21:00
# {'3': [1000, 2200], '4': [1000, 2200], '5': [1000, 2200]}
# пн, вт, чт 12:00–21:00, ср 12:00–22:00, пт 10:00–22:00, сб 9:00–23:00, вс 9:00–21:00
# {'1': [900, 2300], '2': [900, 2300], '4': [900, 2300], '3': [900, 2300], '5': [900, 2300]}
# пн–пт 12:00–22:00, сб, вс 10:00–23:00
# {}
# Расписание уточняйте на сайте комплекса
# {}
# ежедневно 7:00–22:00
# {}
# сб, вс 12:00–19:00
# {}
# пн–ср, пт–вс 10:30–18:00, чт 12:00–20:00
# {}
# ср 14:00–20:00, чт–вс 11:00–17:00
# {}
# ежедневно 11:00–18:00 (касса: ежедневно 10:30–17:00)
# {}
# ежедневно 19:00–6:00
# {}
# пн, чт–вс 11:00–18:00, вт 11:00–17:00
# {}
# пн, чт–вс 10:00–18:00, вт 13:00–21:00
# {}
# вт–сб 11:00–17:00
# {}
# по предварительной записи
# {}
# пн–пт 10:00–23:30, сб, вс 12:00–22:00
# {}
# ежедневно 8:00–23:00
# {}
# ежедневно 12:00–2:30
# {}
# ежедневно 12:00–23:30
# {}
# вт–сб 11:00–17:45
# {}
# пн, чт–вс 11:00–18:00, ср 12:00–20:00
# {}
# пн, вт, пт–вс 10:30–18:00, ср 10:30–21:00
# {}
# пн–пт 11:00–21:00, сб, вс 9:00–21:00
# {}
# вт–вс 10:30–18:00 (касса: вт–вс 10:30–17:00)
# {'2': [1030, 1700], '7': [1030, 1700]}
# касса: ежедневно 10:30–20:00
# {}
# ежедневно 12:00–1:00
# {}
# ежедневно 10:00–20:00 (касса: ежедневно 10:00–19:15)
# {}
# пн–чт, вс 18:00–2:00, пт, сб 18:00–6:00
# {}
# Не является постоянно действующим музеем, поэтому посещение только по предварительной договоренности.
# {}
# пн–пт 14:00–21:00
# {}
# вт, чт–вс 11:00–19:00, ср 11:00–20:00
# {}
# ежедневно 13:00–0:00
# {}
# Режим работы Костюмерной: будни — с 10:00 до 18:00, суббота: по договоренности. Творческие мероприятия — по своему графику.
# {}
# Начало спектаклей в 19.30.
# {}
# уточняйте на сайте
# {}
# вт–чт 12:00–0:00, пт 12:00–1:00, сб 18:00–1:00
# {'2': [1200, 100], '4': [1200, 100]}
# пн–пт 18:00–22:00, сб, вс 11:00–22:00
# {}
# пн–пт 7:00–11:00 14:00–1:00, сб, вс 7:00–12:00 14:00–1:00
# {'1': [700, 1200], '5': [700, 1200]}
# пн–чт 11:00–1:00, пт 11:00–3:00, сб 12:00–3:00, вс 12:00–1:00
# {'1': [1200, 300], '4': [1200, 300], '5': [1200, 300]}
# ср, пт, сб 12:00–17:00
# {}
# пн–чт, вс 11:00–1:00, пт, сб 11:00–3:00
# {}
# ежедневно 19:30–23:00
# {}
# пн–чт 10:00–17:00, пт– 10:00–16:00, сб и вс– только по предварительным заявкам.
# {'1': [1000, 1600], '4': [1000, 1600]}
# ежедневно 12:00–21:00
# {}
# пн–чт, вс 12:00–1:00, пт, сб 12:00–6:00
# {}
# пн–пт 11:00–17:00 (по предварительным заявкам)
# {}
# пн–пт 10:00–17:00
# {}
# ежедневно 12:00–6:00
# {}
# пн, ср–вс 11:00–18:00 (касса: пн, ср–вс 11:00–16:50)
# {'1': [1100, 1650], '3': [1100, 1650], '7': [1100, 1650]}
# пн–вс 11:00 – до поледнего гостя
# {}
# ежедневно 19:00–3:00
# {}
# пн–чт 12:00–0:00, пт, сб 12:00–2:30, вс 13:00–0:00
# {'1': [1200, 230], '4': [1200, 230]}
# пн–чт 9:00–17:00, пт 9:00–16:00
# {}
# пн–чт 10:00–17:00, пт 13:00–17:00, сб 11:00–17:00
# {'1': [1300, 1700], '4': [1300, 1700]}
# ср–вс 10:00–18:00 (касса: ср–вс 10:00–17:15)
# {'3': [1000, 1715], '7': [1000, 1715]}
# ср–вс 10:00–18:00
# {}
# ср–вс 11:00–19:00 (вход посетителей до 18:00)
# {}
# ср–вс 11:00–18:00
# {}
# ежедневно 8:00–19:00
# {}
# пн–чт 10:00–18:00, пт 10:00–17:00, сб 10:00–16:30
# {'1': [1000, 1700], '4': [1000, 1700]}
# пн–чт 10:00–17:00, пт 10:00–16:00, сб 10:00–17:00
# {'1': [1000, 1600], '4': [1000, 1600]}
# вт–вс 12:00–20:00
# {}
# пн, вт, чт–вс 11:00–18:00
# {}
# ср–вс 10:30–17:00
# {}
# вт–вс 11:00–19:00
# {}
# пн–пт 10:00–17:00 (по предварительной записи)
# {}
# пн, чт, сб, вс 10:00–18:00, вт, пт 10:00–17:00
# {}
# вт, чт–вс 10:00–18:30 (кассы закрываются за 30 минут  до закрытия музея)
# {}
# пн, ср, пт–вс 10:00–18:00, чт 13:00–21:00
# {}
# пн, вт, сб, вс 10:00–18:00, ср, пт 10:00–20:00
# {}
# ежедневно 10:00–19:00
# {}
# пн–вт 11:00–17:00 (только экскурсионное обслуживание по предварительной договоренности)
# {}
# пн–пт 11:00–16:30
# {}
# ср 13:00–21:00, чт–вс 11:00–19:00 (касса: ср 13:00–20:00, чт–вс 11:00–20:00)
# {'3': [1100, 2000], '4': [1100, 2000], '7': [1100, 2000]}
# ежедневно 10:00–17:00 (касса: ежедневно 10:00–16:00)
# {}
# пн, чт–вс 11:00–19:00, вт 11:00–18:00
# {}
# вт, чт, сб, вс 10:30–17:00, ср, пт 10:30–20:00
# {}
# вт–чт, сб 11:00–18:00, пт 14:00–20:00
# {}
# ежедневно 10:30–17:00
# {}
# вт–вс 10:00–17:00
# {}
# ср–сб 10:00–17:00
# {}
# Ежедневно c 10.30 до 18.00 (касса до 17.00), кроме вторника и последней пятницы месяца
# {}
# ср–вс 10:30–18:00
# {}
# ср, пт–вс 11:00–17:00, чт 11:00–19:00
# {}
# пн–сб 10:00–18:00
# {}
# ежедневно 11:00–19:00
# {}
# пн, ср, пт–вс 10:00–20:00, чт 13:00–21:00
# {}
# пн, чт–вс 11:00–19:00, ср 13:00–21:00
# {}
# перед началом спектакля и во время антракта, экскурсии по предварительной договоренности
# {}
# пн–сб 11:30–19:30
# {}
# вт–вс 10:00–18:00
# {}
# ежедневно 7:00–20:00
# {}
# Понедельник с 14.00-20.00, Вт-Вс с 11.00-20.00
# {}
# вт 10:00–21:00, ср–сб 10:00–18:00, вс 11:00–19:00
# {'2': [1000, 1800]}
# пн, чт–вс 10:00–18:00, ср 12:30–20:30 (касса: пн, чт–вс 10:00–17:00, ср 12:30–19:30)
# {'1': [1230, 1930], '4': [1230, 1930], '7': [1230, 1930], '3': [1230, 1930]}
# Ежедневно  с 10.00 до 23.00
# {}
# ежедневно 12:00–22:00
# {}
# ежедневно 8:30–23:00
# {}
# ежедневно 10:00–21:00
# {}
# ежедневно 12:00–20:00
# {}
# пн–пт 10:00–19:00
# {}
# ежедневно 10:00 — 22:00
# {}
# вт–вс 11:00–20:00
# {}
# вт–пт 9:00–18:00, сб 10:00–15:00
# {}
# пн–пт 9:00–22:00, сб, вс 10:00–22:00
# {}
# ср–вс 18:00–23:00
# {}
# пн–чт, вс 11:00–2:00, пт, сб 11:00–4:00
# {}
# 1 мая – 30 сентября: 10.00—22.00, 1 октября – 31 марта: 10.00—20.00
# {}
# ежедневно, 9.00- 23.00
# {}
# пн–чт, вс 18:00–2:00, пт, сб 18:00–5:00
# {}
# пн–чт 17:00–23:00, пт–сб  17:00–до последнего посетителя
# {}
# пн–чт 9:00–22:00, пт–вс 9:00–23:00
# {}
# ср–пт 16:00–20:00, сб, вс 12:00–20:00
# {}
# пн–пт 12:00–20:00, сб 10:00–18:00
# {}
# сб, вс 7:00–17:00
# {}
# пн–пт 14:00–23:00, сб, вс 10:00–23:00
# {}
# пн–пт 12:00–22:00, сб, вс 11:00–22:00
# {}
# пн–пт 13:00–23:00, сб, вс 10:00–23:00
# {}
# пн–пт 11:00–22:30, сб, вс 9:00–22:30
# {}
# ежедневно 9:30–22:00
# {}
# пн–пт 12:00–20:00, сб, вс 12:00–19:00
# {}
# ежедневно 6:00–0:00
# {}
# пн–чт 12:00–23:30, пт 12–до последнего гостя, сб 13:00−до последнего гостя, вс 13:00–23:30
# {}
# ср–сб 11:00–19:00, вс 11:00–17:00
# {}
# пн–пт 9:00–18:00
# {}
# пн–сб 18:00–23:00, вс 13:00–17:00
# {}
# ежедневно 14:00–22:00
# {}
# ежедневно 9:00–22:00 (касса: ежедневно 9:00–21:30)
# {}
# ежедневно 12:00–23:00
# {}
# пн–пт 19:00–23:00
# {}
# ежедневно 10:00–20:00
# {}
# ежедневно 15:00–22:30
# {}
# пн–пт 11:00–20:00, сб 11:00–18:00
# {}
# пн 13:00–1:00, вт–вс 11:00–1:00
# {}
# ежедневно 10:00–6:00
# {}
# ежедневно 13:00–5:00
# {}
# ежедневно 9:00–23:00
# {}
# пн–вт:  13:00–16:00, сб: 16:00-19:00
# {}
# ежедневно 5:45–0:00
# {}
# ежедневно 5:40–0:41
# {}
# ежедневно 5:43–0:38
# {}
# ежедневно 5:45–0:35
# {}
# ежедневно 5:45–0:32
# {}
# пн–пт 9:00–23:00, сб, вс 10:00–23:00
# {}
# ежедневно 5:35–0:28
# {}
# ежедневно 5:37–0:26
# {}
# ежедневно 11:00–2:00
# {}
# пн–ср 9:00–23:30, чт–вс 10:00–22:00
# {}
# пн–пт 9:02–0:02, сб, вс 10:00–0:02
# {}
# пн–чт, вс 11:00–0:00, пт, сб 11:00–1:00 (кухня: пн–чт, вс 11:00–23:00, пт, сб 11:00–0:00)
# {'1': [1100, 0], '4': [1100, 0], '7': [1100, 0], '5': [1100, 0], '6': [1100, 0]}
# пн 20:00–22:00, вт–чт 20:00–22:30, пт 20:00–22:00, вс 16:30–19:00
# {'1': [2000, 2200], '2': [2000, 2200], '4': [2000, 2200]}
# пн–чт, сб, вс 9:00–23:00
# {}
# сб 18:00–22:00, вс 12:00–22:00
# {}
# пн, чт 19:30–21:30
# {}
# пн–сб 08:00–19:30 (занятия по скалолазанию)
# {}
# пн, ср, пт–вс 10:00–23:30, вт, чт 9:00–23:30
# {}
# ежедневно 5:36–0:28
# {}
# пн–чт 12:00–1:00, пт 12:00–3:00, сб 16:00–3:00, вс 16:00–1:00
# {'1': [1600, 300], '4': [1600, 300], '5': [1600, 300]}
# вс–чт 10:00–24:00 пт–сб 11:00–02:00
# {}
# ежедневно 12:00–0:00
# {}
# ежедневно 5:36–0:36
# {}
# ежедневно 9:00–1:00
# {}
# ежедневно 5:40–0:28
# {}
# вт–вс 12:00–1:00
# {}
# пт 22:00–0:15, сб 20:00–0:45, вс 12:00–22:15
# {'5': [2000, 45]}
# чт 13:00-20:00, сб-вс 13:00-21:00
# {}
# пн–пт 15:00–21:00, сб, вс 11:00–22:00
# {}
# ежедневно 10:00–21:45
# {}
# пт 22:45–5:00, сб 22:30–5:00
# {}
# ежедневно 5:45–0:30
# {}
# ежедневно 5:43–0:33
# {}
# ежедневно 5:40–0:35
# {}
# пн–сб 10:00–21:00, вс 11:00–21:00
# {}
# ежедневно 7:00–23:00
# {}
# пн–пт 10:00–22:30
# {}
# Музей ср–вс 10:00–18:00, Крепость пн–вс 10:00–18:00
# {}
# пн–чт, вс 9:00–23:00, пт, сб 9:00–0:00
# {}
# пн–чт, вс 12:00–0:00, пт, сб 12:00–2:00
# {}
# пн–пт 11:00–1:00, сб, вс 12:00–1:00
# {}
# http://artozerki.com/
# {}
# ежедневно 10:30–18:00
# {}
# пн–чт, вс 10:00–0:00, пт, сб 10:00–2:00
# {}
# чт 20:00–5:00, пт, сб 20:00–6:00
# {}
# вт–вс 10:30–18:00
# {}
# пн–чт, вс 11:00–23:00, пт, сб 11:00–1:00
# {}
# ср–вс 10:00–19:00
# {}
# пн–чт: 12:00 до 00:00, пт, сб, вс: с 11:00 до последнего посетителя
# {}
# ср 13:00–21:00, чт–вс 11:00–19:00
# {}
# ежедневно 15:30–19:00 (касса: ежедневно 12:00–15:00)
# {}
# пн–пт 10:00–18:00, сб, вс 10:00–19:00
# {}
# ежедневно 9:00–17:00
# {}
# касса: ежедневно 12:00–15:00 16:00–19:30
# {}
# http://sc384.spb.ru
# {}
# пн–пт 11:00–16:00
# {}
# касса: ежедневно 12:00–19:00
# {}
# вс 11:00–15:15, сб 11:00–18:00, пн–пт 11:00–22:00
# {'7': [1100, 1800]}
# вт–вс 12:00–22:00
# {}
# пн–чт 10:00–23:30, пт–вс 10:00–6:00
# {}
# пн–чт, вс 12:00–0:00, пт, сб 12:00–1:00
# {}
# пн–чт 16:00–2:00, пт, сб 16:00–4:00, вс 14:00–2:00
# {'1': [1600, 400], '4': [1600, 400]}
# пн–чт, вс 12:00–1:00, пт, сб 12:00–2:00
# {}
# ежедневно 5:37–0:37
# {}
# ежедневно 5:31–0:45
# {}
# ежедневно 5:30–0:00
# {}
# ежедневно 5:37–0:00
# {}
# ежедневно 5:35–0:44
# {}
# ежедневно 5:34–0:40
# {}
# с 10-00 до 22-00
# {}
# ежедневно 5:36–0:39
# {}
# ежедневно 5:38–0:37
# {}
# ежедневно 5:40–0:33
# {}
# пн–чт, вс 12:00–23:00, пт, сб 12:00–1:00
# {}
# ежедневно 5:44–0:30
# {}
# ежедневно 5:38–0:25
# {}
# ежедневно 5:40–0:25
# {}
# ежедневно 5:38–0:26
# {}
# ежедневно 5:38–0:28
# {}
# ежедневно 5:36–0:33
# {}
# ежедневно 15:00–0:00
# {}
# ежедневно 5:30–0:40
# {}
# ежедневно 5:30–0:42
# {}
# С 12:00 до последнего клиента, кухня — до 22:00
# {}
# ежедневно 9:00–22:00
# {}
# ежедневно 23:00–6:00
# {}
# ежедневно 5:33–0:34
# {}
# пн-вс 7:30-22:00 (либо до последнего клиента по договоренности)
# {}
# ежедневно 5:32–0:23
# {}
# ежедневно 5:39–0:24
# {}
# ежедневно 5:35–0:34
# {}
# ежедневно 5:33–0:30
# {}
# пн–вс с 12:00 до последнего гостя
# {}
# ежедневно 7:30–23:00
# {}
# пн–ср, вс 12:00–0:00, чт–сб 12:00–6:00
# {}
# ср–вс 12:00–0:30
# {}
# ежедневно 5:38–0:33
# {}
# ежедневно 5:36–0:05
# {}
# ежедневно 5:36–0:03
# {}
# ежедневно 5:37–0:30
# {}
# ежедневно 5:42–0:27
# {}
# сб, вс 10:30–18:00
# {}
# ежедневно 9:00–19:00
# {}
# ежедневно 5:35–0:24
# {}
# ежедневно 5:38–0:24, пт, сб 1:00–3:00
# {}
# пн, вт, вс 12:00–0:00, ср, чт 12:00–2:00, пт, сб 12:00–6:00
# {'1': [1200, 200], '2': [1200, 200], '7': [1200, 200]}
# ежедневно 5:36–0:19
# {}
# ежедневно 5:38–0:23
# {}
# ежедневно 5:35–0:27
# {}
# ежедневно 5:37–0:29
# {}
# ежедневно 5:35–0:02
# {}
# ежедневно 5:40–0:08
# {}
# ежедневно 5:45–0:17
# {}
# ежедневно 5:39–0:19
# {}
# ежедневно 5:37–0:23
# {}
# ежедневно 5:35–0:05
# {}
# пн–пт 13:00–19:00
# {}
# пн–пт 8:30–22:00, сб, вс 10:00–23:00
# {}
# пн–чт 10:00–18:00, пт 15:00–18:00 (только по предварительной договоренности)
# {'1': [1500, 1800], '4': [1500, 1800]}
# ср–вс 10:00–17:00 (касса: ср–вс 10:00–16:00)
# {'3': [1000, 1600], '7': [1000, 1600]}
# ср, пт–вс 11:00–19:00, чт 12:00–20:00
# {}
# ср 13:00–21:00, чт–вс 11:00–18:00 (касса: ср 13:00–20:00, чт–вс 11:00–17:30)
# {'3': [1100, 1730], '4': [1100, 1730], '7': [1100, 1730]}
# пн-вс 11:00–19:00
# {}
# пн–чт, сб, вс 10:00–18:00, пт 10:00–17:00
# {}
# пн–пт 12:00–20:00
# {}
# ср–вс 14:00–21:00
# {}
# чт–сб 11:00–6:00, пн–ср, вс 11:00–23:00
# {}
# пн–пт 12:00–21:00, сб, вс 11:00–22:00
# {}
# пн–пт 12:00–22:00, сб, вс 11:00–22:00 (касса: пн–пт 12:00–21:00, сб, вс 11:00–21:00)
# {'1': [1100, 2100], '5': [1100, 2100], '6': [1100, 2100], '7': [1100, 2100]}
# пн–пт 7:00–0:00, сб, вс 9:00–23:00
# {}
# пн–ср, сб, вс 12:00–19:00
# {}
# с 12:00 до последнего клиента
# {}
# вт–вс 12:00–18:00
# {}
# ежедневно 10:00-22:00
# {}
# Пн-Сб: 10:00-21:00 Вс: 11:00-21:00
# {}
# пн-вс: 12:00-22:00
# {}
# касса: вт–чт 10:00–18:00, пт 15:00–19:00, сб 12:00–19:00, вс 12:00–15:00
# {'2': [1200, 1900], '4': [1200, 1900], '5': [1200, 1900]}
# вт–вс 10:00–18:00 (касса: вт–вс 10:00–17:30)
# {'2': [1000, 1730], '7': [1000, 1730]}
# сб, вс 11:00–23:00
# {}
# пн–чт, вс 10:00–22:00, пт, сб 10:00–23:00
# {}
# пн–чт, вс 12:00–23:00, пт, сб 12:00–6:00
# {}
# пн–пт 11:00–23:00
# {}
# пн–пт 12:00–6:00, сб, вс 14:00–6:00
# {}
# Посещение по предварительной договоренности.
# {}
# ср–вс 10:00–18:00, чт 10:00–20:00 (клубный день)
# {'3': [1000, 2000], '7': [1000, 2000]}
# ежедневно 11:00 - 21:00
# {}
# ежедневно 21:00–7:00
# {}
# пн–чт, вс 20:00–6:00, пт, сб 18:00–6:00
# {}
# пн–чт, вс 20:00–6:00, пт, сб 20:00–10:00
# {}
# пн–пт 8:00–21:00, сб, вс 10:00–21:00
# {}
# пн, вт, ср–вс 10:00–16:30
# {}
# пн–сб 12:00–22:00
# {}
# ежедневно 16:00–0:00
# {}
# пн–чт, вс 9:00–23:00, пт, сб 10:00–1:00
# {}
# чт 19:00–2:00, пт, сб 19:00–4:00
# {}
# пн–чт 8:00–23:00, пт 8:00–0:00, сб 9:00–1:00, вс 9:00–23:00
# {'1': [900, 100], '4': [900, 100], '5': [900, 100]}
# ежедневно 6:00–23:00
# {}
# пн–чт, вс 9:00–0:00, пт, сб 9:00–1:00
# {}
# ежедневно 11:00-21:00
# {}
# ежедневно 10:30-20:30
# {}
# пн-вск 11:00-20:00
# {}
# пн–пт 10:00–21:00, сб, вс 11:00–20:00
# {}
# пт 10:00–17:00
# {}
# пн–сб 8:30, вс 9:30
# {}
# пн–ср 10:00–18:00, чт 12:00–20:00, пт 10:00–17:00, сб 11:00–17:00
# {'1': [1000, 1700], '3': [1000, 1700], '4': [1000, 1700]}
# касса: ежедневно 11:00–15:00 16:00–19:00
# {}
# пт 10:00–16:30, пн–чт 10:00–18:00
# {}
# пн–чт, вс 10:00–17:00
# {}
# вт, чт–вс 10:00–18:00, ср 13:00–21:00
# {}
# ср 13:00–21:00, чт–сб 10:00–18:00
# {}
# пн–пт 8:00–23:00, сб, вс 9:00–23:00
# {}
# пн–чт, вс 9:00–2:00, пт, сб 9:00–6:00
# {}
# пн–пт 10:00–22:00
# {}
# пн–пт 9:00–0:00, сб, вс 10:00–0:00
# {}
# ежедневно 6:00–21:00
# {}
# пн–чт с 12:00 до последнего гостя, пт 12:00–10:00, сб 15:00–10:00
# {}
# ежедневно 17:00–4:00
# {}
# пн 12:00–3:00, вт–пт 12:00–6:00, сб, вс 15:00–6:00
# {'1': [1200, 600]}
# пн–пт 12:00–4:00, сб, вс 15:00–5:00
# {}
# ежедневно 10.00 до 20.00
# {}
# пн–чт и вс 12:00 –23:00, пт–сб: 12:00–6:00
# {}
# сб.-вс. 10-20
# {}
# пт–вс 12:30–21:00
# {}
# пн–пт 16:00–21:00, сб, вс 10:00–21:00
# {}
# ср–вс, вход по сеансам: 11:00, 13:00, 13:30, 15:30
# {}
# пн–чт, вс 12:00–22:00, пт, сб 12:00–23:00
# {}
# пн, вт, чт–вс 10:00–19:00
# {}
# ежедневно, 9:00—23:00
# {}
# ежедневно 9:00–22:00 (касса: ежедневно 9:00–17:00)
# {}
# ежедневно 10.00 до 18.00
# {}
# пн, вт, чт–вс 10:00–17:00
# {}
# вт–вс 10:00–18:00 (касса до 17:00), санитарный день — первый вторник месяца
# {}
# ежедневно с 10.00 до 18.00 (касса до 17.00), выходной — понедельник
# {}
# пн–вс с 10:00 до последнего гостя
# {}
# ежедневно 10:00–17:00
# {}
# ср–пт 10:00–17:00
# {}
# ср–вс 11:00–17:00
# {}
# ср–вс 10:00–16:00
# {}
# cр–вс 11:00–17:00
# {}
# ср–вс 10:30–17:30
# {}
# ежедневно
# {}
# ежедневно 8:00–20:00
# {}
# ежедневно с 11:00 до 20:00
# {}
# ежедневно с 11:00 до 22:00
# {}
# пн–чт, вс 12:00–1:00, пт, сб 12:00–5:00
# {}
# касса: ежедневно 14:00–20:00
# {}
# вс–чт 10:00–23:00, пт–сб круглосуточно
# {}
# пт, сб 20:00–6:00
# {}
# пн–пт 8:30–17:00
# {}
# пн–пт 8:00–22:00, сб, вс 9:00–22:00
# {}
# пн–чт, вс 12:00–0:00, пт 12:00–2:00, сб 12:00–3:00
# {'1': [1200, 200], '4': [1200, 200], '7': [1200, 200]}
# ежедневно с 11:00 до последнего клиента
# {}
# пн 19:00–21:00, ср 19:00–21:00
# {}
# ежедневно 10:30–20:00
# {}
# ежедневно, круглосуточно
# {}
# пн–сб 10:00–19:00, вс 11:00–18:00
# {}
# пн–сб 11:00–21:00, вс 12:00–20:00
# {}
# пн–сб 11:30–20:00, вс 12:00–19:00
# {}
# пн–вс 18:00–06:00
# {}
# пн–пт 8:30–23:00, сб, вс 10:00–23:00
# {}
# с 9 до 21 часа
# {}
# пн–чт, вс 12:00–0:00, пт, сб 12:00–1:00 (кухня: пн–чт, сб, вс 12:00–23:00, пт 12:00–0:00)
# {'1': [1200, 0], '4': [1200, 0], '7': [1200, 0], '5': [1200, 0], '6': [1200, 0]}
# ежедневно 8:30–21:00
# {}
# Ресторан: вс–пт 11:00–23:00, сб 11:00–06:00. Клуб: вт–сб 11:00–06:00
# {'5': [1100, 600], '7': [1100, 600]}
# сб, вс 10:30–17:00
# {}
# С 12:00 до последнего гостя
# {}
# ср–вс 14:00–20:00
# {}
# ежедневно 13:00–21:00
# {}
# ежедневно 11:30–18:00
# {}
# пн–пт 11:00–17:00
# {}
# пн–чт, вс 12:00–0:00, пт, сб 12:00–6:00
# {}
# пн–пт 10:00–20:00, сб 11:00–18:00
# {}
# пн, чт 20:00
# {}
# пн–пт 10:00–19:00, сб, вс 10:00–20:00
# {}
# ежедневно, кроме второй среды каждого месяца
# {}
# пн–пт 10:00–17:00 (вход посетителей до 16:00)
# {}
# пн–вт, чт 12:00–14:00, 15:00–16:30
# {}
# ежедневно 20:00–6:00
# {}
# пн, вс 12:00–0:00, вт–чт 12:00–2:00, пт, сб 12:00–4:00
# {'1': [1200, 200], '7': [1200, 200]}
# ежедневно 10:00–0:00
# {}
# пн–чт 12:00–23:00, пт–вс 12:00–1:00
# {}
# пн–чт 9:00–23:00, пт 9:00–1:00, сб 10:00–1:00, вс 10:00–23:00
# {'1': [1000, 100], '4': [1000, 100], '5': [1000, 100]}
# пн, вт, вс 10:00–0:00, ср–сб 10:00–1:00
# {}
# пн–пт 12:00–23:00, сб, вс 11:00–23:00
# {}
# касса: ежедневно 10:00–20:00
# {}
# пн 14:00–21:00, вт–чт, вс 11:00–21:00, пт, сб 11:00–22:00
# {'1': [1100, 2100]}
# ежедневно 10:30–17:30 (касса: ежедневно 10:30–17:00)
# {}
# касса: ежедневно 11:00–14:00 14:45–19:00
# {}
# касса: пн 13:00–18:00, вт–вс 12:00–20:00
# {}
# сб, вс 10:30,  12:00,  14:00,  16:00 , 17:30
# {}
# касса: ежедневно 10:00–17:00
# {}
# Невский пр., д. 104
# {}
# касса: ежедневно 12:00–15:00 16:00–19:00
# {}
# ежедневно 6:30
# {}
# ср–вс 11:00–18:00 (касса: ср–вс 11:00–17:15)
# {'3': [1100, 1715], '7': [1100, 1715]}
# пн–чт, вс 10:00–19:00, пт, сб 10:00–21:00
# {}
# касса: пн–пт 15:00–19:00, сб, вс 10:00–14:00 15:00–19:00
# {'1': [1000, 1400], '5': [1000, 1400]}
# вт, чт–вс 10:30–18:30, ср 12:00–20:00
# {}
# пн–ср, пт–вс 10:00–18:00 (касса: пн–ср, пт–вс 10:00–17:00)
# {'1': [1000, 1700], '3': [1000, 1700], '5': [1000, 1700], '7': [1000, 1700]}
# ежедневно в 22:00
# {}
# ежедневно 12:30–0:00
# {}
# пн–чт, вс 19:00–0:00, пт, сб 19:00–6:00
# {}
# ежедневно 5:00–1:00
# {}
# ежедневно 0:00–23:59
# {}
# ежедневно 8:15–21:00
# {}
# касса: ежедневно 11:00–14:00 15:00–18:00
# {}
# пн–пт 7:00–19:00
# {}
# ср, сб, вс 10:00–17:00
# {}
# пн–пт 8:00–20:00
# {}
# пн–пт 8:30–21:00
# {}
# сб, вс 12:00–18:00
# {}
# пн, ср, пт–вс 14:30–22:00
# {}
# пн, вт, чт–вс: объекты 10:00–17:00; экспозиции и выставочные залы 11:00–18:00
# {}
# С 10.00 до 22.00, без выходных
# {}
# вт, сб, вс 10:00–20:00, ср–пт 10:00–19:00
# {}
# пн, ср–вс 10:30–18:00 (касса: пн, ср–вс 10:30–17:00)
# {'1': [1030, 1700], '3': [1030, 1700], '7': [1030, 1700]}
# вт–пт 10:00–18:00
# {}
# чт–вс 23:59–10:00
# {}
# касса: ежедневно 11:00–14:00 15:00–19:00
# {}
# ежедневно 14:00–21:00
# {}
# касса: ежедневно 11:00–15:00 16:00–20:00
# {}
# касса: пн–сб 10:00–14:00 15:00–19:00, вс 10:00–14:00 15:00–17:00
# {'1': [1000, 1400], '6': [1000, 1400]}
# пн–чт, вс 11:00–3:00, пт, сб 11:00–6:00
# {}
# пн–пт 10:00–18:30, сб 11:00–18:30 (касса: пн–пт 10:00–18:00, сб, вс 10:00–18:00)
# {'1': [1000, 1800], '5': [1000, 1800], '6': [1000, 1800]}
# чт–пт 14:00–18:00, сб–вс 10:00–16:00 (кассы)
# {'4': [1000, 1600], '5': [1000, 1600]}
# ср, чт, вс 17:00–23:00, пт, сб 17:00–1:00
# {}
# вт–пт 10:00–17:00, сб, вс 11:00–16:00
# {}
# пн–вс 12:00–19:00
# {}
# вт, чт–вс 10:30–18:00, ср 10:30–21:00
# {}
# касса: вт–вс 15:00–19:00
# {}
# касса: ежедневно 11:00–14:00 14:30–20:00
# {}
# по будням 11:00–17:00
# {}
# касса: ср–вс 14:00–19:00
# {}
# пн–пт 9:00–17:00
# {}
# вт–вс 16:00–22:00
# {}
# вт–сб 10:00–19:00
# {}
# ежедневно 11:00–21:30
# {}
# начало спектаклей в 19:30
# {}
# вт–пт 14:00–21:00, сб 11:00–17:00
# {}
# вт–чт 11:00–20:00, пт–вс 11:00–21:00
# {}
# касса: пн–пт 12:00–15:00 15:40–21:00, сб, вс 12:00–15:00 15:40–20:00
# {'1': [1200, 1500], '5': [1200, 1500]}
# пн–пт 9:00–21:00, сб, вс 11:00–19:00
# {}
# сб, вс 11:00–19:00, пн–пт 12:00–21:00
# {}
# пн–пт 12:00–20:00, сб, вс 11:00–19:00
# {}
# пн–пт 11:00–19:00, сб 11:00–18:00
# {}
# вт–чт 15:00–20:00
# {}
# пн–пт 8:30–21:00, сб, вс 10:00–21:00
# {}
# вт–чт, сб, вс 11:00–17:00; в июле и августе музей закрыт
# {}
# кассы: 12:00–18:00
# {}
# касса: ежедневно 11:00–21:00
# {}
# пн–пт 11:00–19:00, сб 12:00–18:00
# {}
# ежедневно 15:00–22:00
# {}
# пн–пт 12:00–19:00, в другое время по предварительной договоренности
# {}
# пт, сб 22:00–2:00
# {}
# вт– вс 09:00–17:00, с мая по октябрь–без выходных
# {}
# вт, чт–вс 12:00–20:00, ср 14:00–21:00
# {}
# пн–сб 12:00–20:00
# {}
# каждую субботу в 18:00 или 19:00
# {}
# вт–сб 12:00–19:00
# {}
# вт–вс 11:00–18:00
# {}
# сб 16:00–20:00
# {}
# пн–пт 14:00–20:00, сб, вс 10:00–21:00
# {}
# пн–сб 10:00–19:00, вс 11:00–19:00
# {}
# ежедневно 9:00
# {}
# пн–пт 13:00–20:00, сб, вс 13:00–18:00
# {}
# пн–пт 12:00–21:00, сб, вс 11:00–19:00
# {}
# ежедневно 8:30–20:00
# {}
# сб 15:30–до последнего гостя
# {}
# касса работает ежедневно с 11:00 до 21:00 (перерыв на обед с 15:00 до 16:00)
# {}
# ежедневно 10:00–20:45
# {}
# пт, сб 0:00–6:00
# {}
# ежедневно 12:00–5:00
# {}
# пн–пт с 12 до последнего гостя, сб с 16:00 до последнего гостя
# {}
# ежедневно 6:30–0:00
# {}
# пн–чт, вс 22:00–6:00, пт, сб 22:00–8:00
# {}
# пн–пт 14:00–19:00, сб 11:00–15:00
# {}
# пн–чт, вс 18:00–2:00, пт, сб 18:00–4:00
# {}
# пн–пт 7:00–23:00, сб, вс 9:30–21:00
# {}
# пт–вс 18:00–6:00, пн–чт 21:00–6:00
# {}
# ежедневно 18:00–2:00
# {}
# пн 11:00–20:00, вт 13:00–20:00, ср 12:00–20:30, чт 19:00–20:30, сб 15:00–20:00, вс 9:30–18:00
# {'1': [1500, 2000], '2': [1500, 2000], '3': [1500, 2000], '4': [1500, 2000]}
# пн 10:00–17:00 17:00–22:00, вт 10:00–16:00 16:00–21:00, ср 10:00–14:00 18:00–21:00, чт 12:00–14:45 19:00–21:00, пт 11:00–14:45 18:00–22:00, сб, вс 14:00–22:00
# {'1': [1800, 2200], '2': [1800, 2200], '3': [1800, 2200], '4': [1800, 2200], '5': [1800, 2200]}
# ср–вс 19:00–6:00
# {}
# касса: чт 15:00–20:00, пт 15:00–21:00, сб 10:00–19:00, вс 10:00–17:00
# {'4': [1000, 1900], '5': [1000, 1900]}
# ежедневно 13:00–20:00
# {}
# ежедневно 22:00–6:00
# {}
# ср–сб 22:00–6:00
# {}
# пн–пт 10:00–18:00
# {}
# пн–чт, вс 14:00–23:00, пт, сб 14:00–5:00
# {}
# ресторан: вс–чт 10:00–00:00, пт–сб 10:00–06:00; клуб: пт–сб 22:00–06:00; караоке: чт–сб 20:00–04:45
# {'4': [2200, 600], '7': [2200, 600], '5': [2200, 600], '6': [2200, 600]}
# пн–ср 8:00–18:00, чт, пт 8:00–6:00, сб 18:00–7:00
# {'1': [800, 600], '3': [800, 600]}
# пн–вс 10:00–22:00 (касса)
# {}
# чт–вс 22:00–7:00
# {}
# пн–пт 10:00–17:00, сб–вс по предварительной договоренности
# {}
# пн–пт 11:00–18:00
# {}
# сб 18:15–19:30, вс 11:00–12:15, 18:15–19:30
# {'6': [1100, 1215]}
# пн, сб 10:00–18:00, вт–пт 10:00–20:00
# {}
# сб, вс 11:00–17:00
# {}
# сб 11:00–21:00, вс 12:00–21:00, пн–пт 12:00–21:00
# {'6': [1200, 2100]}
# чт 18:00–21:00
# {}
# вт–сб 10:30–18:00, вс 12:00–17:00
# {}
# Пн–Чт., Вс: с 08:30 до последнего гостя, Пт–Сб: 08:30–05.00
# {}
# пн–вс с 12 до последнего гостя
# {}
# по договоренности
# {}
# пн–сб 10:00–20:00, вс 10:00–18:00
# {}
# пн–суб 10:00–21:00  вск – 11:00–19:00
# {}
# пн, вт 11:00–22:00
# {}
# Вторник: 09:00-12:00, четверг: 18:00-20:00
# {}
# пн–вс 16:00–19:00 (запись)
# {}
# пн, ср, чт 19:00–21:00, вт, пт, сб 18:00–21:00, вс 15:00–17:30
# {'1': [1800, 2100], '3': [1800, 2100], '4': [1800, 2100]}
# вт 17:30–19:00, ср 18:00–21:00, сб 9:00–12:00
# {'2': [1800, 2100]}
# пн–пт 17:00–22:30, сб–вс 13:00–18:00 (до 20:00 по договоренности)
# {'1': [1300, 1800], '5': [1300, 1800]}
# ср 10:30–21:00, вт, чт–вс 10:30–18:00
# {}
# пн-вск 14:00–22:00
# {}
# пон–суб 12:00–20:00, вск 12:00– 18:00
# {}
# ср–вс 10:00–17:00
# {}
# пн–чт 16:00–20:00 вскр 13:00–17:00
# {}
# ср 12:00–21:00, чт–вс 12:00–18:00
# {}
# пн–пт 10:00–17:00 (только по предварительной договоренности)
# {}
# пн–пт 9:00–21:00, сб 11:00–17:00
# {}
# ежедневно 11:00–18:00
# {}
# ср 14:00–21:00, чт–вс 11:00–18:00
# {}
# пн–пт 10:00–19:00, сб 11:00–17:00
# {}
# пн–вс 10:00–20:00
# {}
# Встречи проводятся каждую третью субботу месяца в 12:00.
# {}
# вс 12:00, вс 16:00, вт 18:00, ср 19:00, ср 20:00, пт 18:00
# {}
# пн–пт 09:30–17:30, перерыв 13:00–14:00
# {}
# приём посетителей 17:00–19:00
# {}
# пн–пт 10:00–19:00, сб 11:00–16:00
# {}
# пн–пт 10:00–20:00, сб 12:00–15:00
# {}
# пн–пт 10:00–20:00
# {}
# пн–пт 14:00–20:00
# {}
# ежедневно 10:00 – 18:00, кассы до 17:00
# {}
# пн–пт 10:00–14:00 (по предварительной записи)
# {}
# пн–пт 09:30–18:00 (по предварительной договоренности)
# {}
# ежедневно 12:00–19:00
# {}
# ср, пт 12:00–18:00
# {}
# пн, ср–вс 11:00–19:00
# {}
# пн–сб 15:00–19:00
# {}
# пн–сб 10:00–20:00
# {}
# пн–пт 12:00–21:00, сб 12:00–20:00, вс 12:00–19:00
# {'1': [1200, 2000], '5': [1200, 2000]}
# ежедневно 11:30–0:15
# {}
# ежедневно 8:30–10:00 17:00–21:00
# {}
# вт, чт–вс 10:00–18:30, ср 13:00–21:00
# {}
# ежедневно 15:00–20:00
# {}
# пн–вск 12:00–21:00
# {}
# пн–вск с 11:00–21:00
# {}
# пн–чт, вс 12:00–1:00, пт, сб 12:00–3:00
# {}
# ежедневно 12:00–23:00 (кухня: ежедневно 12:00–22:30)
# {}
# пн–чт, вс 14:00–2:00, пт, сб 14:00–8:00
# {}
# пн–чт 12:00–23:00, пт 12:00–2:00, сб 16:00–2:00, вс 16:00–23:00
# {'1': [1600, 200], '4': [1600, 200], '5': [1600, 200]}
# вт, сб, вс 12:00–20:00, ср–пт 10:00–20:00
# {}
# пн–пт 12:00–19:00, сб 12:00–18:00
# {}
# ежедневно 9:30–21:30
# {}
# почасовая аренда
# {}
# вт–сб 10:00–18:00 (касса: вт–сб 10:00–17:00)
# {'2': [1000, 1700], '6': [1000, 1700]}
# вт–вс 9:00–21:00
# {}
# пн–чт 9:00–21:00
# {}
# пн–чт 12:00, пт 12:00–6:00, сб 16:00–6:00
# {}
# ежедневно 14:00–23:00
# {}
# пн–пт 10:00–20:00, сб, вс 11:00–20:00
# {}
# вт–сб 11:00–18:00
# {}
# пн–сб 10:00–15:00
# {}
# ежедневно 13:00–23:00
# {}
# ежедневно с 12:00 до 23:30
# {}
# ежедневно 11:00–22:30
# {}
# пн–пт 17:00–19:00
# {}
# пн–пт 14:00–19:00
# {}
# ежедневно с 12:00 до 24:00
# {}
# пт–вс 12:00–18:00
# {}
# ежедневно 9:30–18:00
# {}
# сб 10:00–21:00, пн–пт 15:00–21:00
# {}
# пн–пт, вс 10:00–20:00, сб 10:00–19:00
# {}
# пн–сб 9:00–20:00
# {}
# пн–сб 9:00–22:00, вс 11:00–21:00
# {}
# Понедельник-пятница: с 08:00 до 20:00; суббота-воскресенье: с 10:00 до 15:00
# {}
# пн–пт 13:00–21:00
# {}
# пн–сб 10:00–21:00
# {}
# пн–пт 8:00–19:00
# {}
# пн–сб 14:00–21:00
# {}
# пн–пт 9:00–21:00
# {}
# пн–пт 15:00–21:00
# {}
# пн–сб 11:00–21:00
# {}
# пн–пт 11:00–20:30, сб, вс 11:00–19:30
# {}
# сб 10:00–19:00, пн, вт 12:00–21:00
# {}
# пн–пт 13:00–22:00, сб 11:00–20:00
# {}
# 10:00–22:00, без выходных
# {}
# 09:00–18:00, без выходных
# {}
# 09:00–20:00, без выходных
# {}
# пн–пт 8:30–22:00, сб, вс 10:00–22:00
# {}
# ежедневно 15:00–21:00
# {}
# пн–пт 11:00–20:00
# {}
# ср 19:30–23:00
# {}
# пн–пт 12:00–22:00, сб–вс 13:00 – до последнего посетителя
# {}
# пн–чт, вс 15:00–0:00, пт, сб 15:00–6:00
# {}
# ежедневно 7:30–19:30
# {}
# пн–пт 8:30–19:30, сб 11:00–14:00
# {}
# пн, ср, пт 16:30–18:00
# {}
# пн–пт 10:00–21:00
# {}
# чт–вс 11:00–18:00, ср 14:00–21:00
# {}
# пн–пт 11:00–20:00, сб–вс 11:00–18:00
# {}
# пн–пт 9:00–21:00, сб, вс 10:00–21:00
# {}
# пн–пт 8:00–22:00, сб, вс 9:00–18:00
# {}
# ежедневно 8:00–22:00
# {}
# пн–вс круглосуточно
# {}
# пн–пт 11:00–6:00, сб, вс 10:00–6:00
# {}
# пн–пт 15:00–6:00, сб, вс 12:00–6:00
# {}
# ежедневно 11:00–6:00
# {}
# пт 18:00–23:00, сб 12:00–23:30, вс 13:00–21:00
# {'5': [1200, 2330]}
# ср–пт 15:00–23:00, сб 12:00–23:00, вс 12:00–22:00
# {'3': [1200, 2300], '5': [1200, 2300]}
# пн–чт, вс 10:30–22:00, пт, сб 11:00–4:00
# {}
# пт–вс 11:00–6:00, пн–чт 11:00–4:00
# {}
# пн–чт 17:00–2:00, пт, сб 14:00–6:00, вс 14:00–2:00
# {'1': [1400, 600], '4': [1400, 600]}
# пн–пт 10:00–20:00, вс 16:00–20:00
# {}
# пн–сб 11:00–23:00
# {}
# пн–сб 9:00–21:00
# {}
# пн, вт 10:00–22:00
# {}
# пн, вт 10:00–20:00
# {}
# Пн-Вс с 12 до 8 вечера
# {}
# пн–пт 15:00–18:00, сб, вс 11:30–19:00
# {}
# пн–сб 11:00–20:00
# {}
# пн–пт 11:00–20:00, сб 11–16:00
# {}
# Посещение музея проводится по предварительной договоренности
# {}
# вс 11:30–13:30
# {}
# пн–пт 11:00–19:00
# {}
# ср–пт 12:00–19:00, сб, вс 10:00–19:00
# {}
# пн-ср 12.00–24.00, чт 12.00–02.00, пт 12.00–06.00 сб 15.00–06.00 вс 15.00–24.00
# {}
# пн-пт- 9:00 - 20:00, сб - 10:00 - 18:00, вс - выходной день
# {}
# вт–пт 10:00–20:00, сб, вс 10:00–18:00
# {}
# пн–пт 12:00–0:00, сб, вс 14:00–0:00
# {}
# ежедневно 10:00–3:00
# {}
# пн–пт 10:00–19:00, сб 11:00–17:00, вс – выходной
# {'1': [1100, 1700], '5': [1100, 1700]}
# ежедневно 10:00–2:00
# {}
# пн–пт, вс 9:00–19:00, сб 9:00–22:00
# {}
# вт–вс 10:00–17:30
# {}
# пн–пт с 11:00 до последнего гостя, сб с 14:00 до последнего гостя, вс с 16:00 до последнего гостя
# {}
# пн–пт 09:00–00:30, сб–вс 09:00–01:45 (Зомби-лаборатория), пн–пт 09:00–00:00, сб–вс 09:00–02:30 (Шизофрения). Предварительная запись обязательна
# {'1': [900, 230], '5': [900, 230], '6': [900, 230], '7': [900, 230]}
# пн–ср, вс 12:00–0:00, чт 12:00–2:00, пт, сб 12:00–5:00
# {'1': [1200, 200], '3': [1200, 200], '7': [1200, 200]}
# пн–чт, вс 10:00–1:00, пт, сб 10:00–3:00
# {}
# ежедневно 10:00–1:00
# {}
# пн–ср, вс 8:00–1:00, чт–сб 1:00–0:00
# {}
# ежедневно 12:00–0:45
# {}
# пн–чт, вс 12:00–0:00, пт 12:00, сб 12:00–2:00
# {}
# пн–чт, вс 11:00–23:00, пт, сб 11:00–0:00 (кухня: пн–чт, вс 11:00–22:00, пт, сб 11:00–23:00)
# {'1': [1100, 2300], '4': [1100, 2300], '7': [1100, 2300], '5': [1100, 2300], '6': [1100, 2300]}
# пн–чт 12:00–02:00, пт–сб 12:00–03:00, сб 12:00–01:00
# {'1': [1200, 300], '4': [1200, 300]}
# вт–чт 12:00–1:00, пт, сб 12:00–6:00
# {}
# ежедневно 12:00–3:00
# {}
# пн–пт 11:00–0:00, сб, вс 11:00–3:00
# {}
# пн–чт 12:00–2:00, пт, сб 12:00–3:00, вс 12:00–1:00
# {'1': [1200, 300], '4': [1200, 300]}
# пн–вс 09:00–до последнего гостя
# {}
# пн–чт, вс 12:00–2:00, пт, сб 12:00–3:00
# {}
# пн–чт 15:00–2:00, пт 15:00–4:00, сб 12:00–4:00, вс 12:00–2:00
# {'1': [1200, 400], '4': [1200, 400], '5': [1200, 400]}
# пт, сб 12:00–3:00, пн–чт 12:00–2:00, вс 13:00–1:00
# {'5': [1200, 200], '6': [1200, 200]}
# ежедневно 9:00–5:00
# {}
# ежедневно 12:00–2:00
# {}
# пн–пт с 9:00 до последнего гостя (кухня до 1:00), сб–вс с 12:00 до последнего посетителя (кухня до 23:00)
# {}
# вс–чт 08:00–00:00, пт–сб 08:00–до последнего гостя
# {}
# пт, сб 12:00–2:00, пн–чт, вс 12:00–0:00
# {}
# пн–вс 12:00–до последнего гостя
# {}
# пн–чт, вс 9:00–2:00, пт, сб 9:00–3:00
# {}
# пн–вс 12:00–02:00, кухня работает до 24:00
# {}
# ежедневно 9:00–6:00
# {}
# пн–чт 12:00–02:00 (кухня до 01:00), пт–сб 12:00–03:00 (кухня до 02:00), вс 12:00–01:00 (кухня до 00:00)
# {'1': [1200, 100], '4': [1200, 100], '5': [1200, 100], '6': [1200, 100]}
# пн–пт 12:00–23:00, сб, вс 12:00–0:00
# {}
# пн–чт, вс 10:00–2:00, пт, сб 10:00–4:00
# {}
# пн–вс 13:00–23:30 (кухня работает до 23.00)
# {}
# пн–чт, вс 11:00–23:00, пт, сб 11:00–6:00
# {}
# кухня: ежедневно 11:00
# {}
# пн–вс 11:00–до последнего гостя (кухня до 23:00)
# {}
# пт, сб 12:00–1:00, пн–чт, вс 12:00–0:00
# {}
# пн–чт, вс 11:00–0:00, пт, сб 11:00–2:00
# {}
# вс 12:00–1:00, пт, сб 12:00–3:00, пн–чт 12:00–2:00
# {'7': [1200, 300]}
# пт, сб 12:00–2:00, ср, чт 12:00–0:00, пн, вт, вс 12:00–22:00
# {'5': [1200, 0], '6': [1200, 0]}
# пт, сб 20:00–6:00, пн–чт, вс 20:00–5:00
# {}
# пн–чт 12:00–01:00, пт 12:00–03:00, сб–вс 13:00–03:00, вс 13:00–01:00
# {'1': [1300, 300], '4': [1300, 300], '5': [1300, 300]}
# пн–чт, вс 11:30–1:00, пт, сб 11:30–3:00
# {}
# пн–чт, вс 11:00–23:00, пт, сб 15:00–6:00
# {}
# пт, сб 12:00–2:00, пн–чт, вс 12:00–1:00
# {}
# пн–сб 12:00–5:00, вс 12:00–2:00
# {}
# сб, вс 10:00–23:00, пн–пт 10:00–22:00
# {}
# пн–вс 12:00–23:00, кухня до 22:30
# {}
# пн–чт 12:00–0:00, пт–вс 12:00–2:00
# {}
# пт, сб 12:00–1:00, пн–чт, вс 12:00–23:00
# {}
# пн–вс 12:00 и до последнего посетителя
# {}
# пн–вс 12:00–24:00 (кухня до 23:30)
# {}
# пн–вс 12:00–до последнего посетителя
# {}
# пн–вс 16:00 до последнего гостя
# {}
# пн–пт 10:00–0:00
# {}
# пн–вс 12:00–00:00. Так же ресторан предлагает возможность проведения ночных мероприятий.
# {}
# пн–пт 10:00–23:00, сб, вс 11:00–23:00
# {}
# пн–чт, вс 11:00–0:00, пт, сб 11:00–1:00
# {}
# пн–чт, вс 20:00–10:00, пт, сб 20:00–6:00
# {}
# пн–чт, вс 11:00–4:00, пт, сб 11:00–6:00
# {}
# пн-вс 12:00–до последнего гостя
# {}
# пн–чт, вс 12:00–23:00, пт, сб 12:00–2:00
# {}
# вс–чт 13:00–01:00, пт-сб: 13:00–03:00
# {}
# ежедневно с 12:00 до последнего посетителя
# {}
# пн–чт 9:00–1:00, пт 12:00–2:00, вс 13:00–1:00, сб 13:00–2:00
# {'1': [1300, 100], '4': [1300, 100], '5': [1300, 100]}
# пн–чт 9:00–21:00, пт 9:00–23:00, вс 11:00–21:00, сб 11:00–23:00
# {'1': [1100, 2100], '4': [1100, 2100], '5': [1100, 2100]}
# пт–вс 12:00–0:30
# {}
# с 11:00 до последнего гостя
# {}
# пт, сб 12:00–3:00, пн–чт, вс 12:00–1:00
# {}
# пн–чт, вс 14:00–2:00, пт, сб 14:00–6:00
# {}
# с 12:00 до последнего гостя
# {}
# пн–пт 08:00–до последнего гостя, сб, вс 12:00–до последнего гостя.
# {}
# пн–чт 11:00–1:00, пт 11:00–3:00, сб 13:00–3:00, вс 13:00–1:00
# {'1': [1300, 300], '4': [1300, 300], '5': [1300, 300]}
# пн–пт 10:00–до последнего гостя, сб–вс 12:00–до последнего гостя
# {}
# пн–вс 11:00–до последнего гостя,  кухня до 22:30
# {}
# пн–чт, вс 7:30–2:00, пт, сб 7:30–4:00
# {}
# пн–чт 10:00–0:00, пт 10:00–1:00, сб 11:00–1:00, вс 11:00–0:00
# {'1': [1100, 100], '4': [1100, 100], '5': [1100, 100]}
# пн–вс 12:00–23:00 (кухня работает до 22:30)
# {}
# пн–чт, вс 12:00–0:00, пт, сб 11:00–1:30
# {}
# ежедневно 13:00–6:00
# {}
# пн–чт 11:00–1:00, пт 11:00–2:00, сб 13:00–2:00, вс 13:00–0:00
# {'1': [1300, 200], '4': [1300, 200], '5': [1300, 200]}
# пн–чт, вс 16:00–2:00, пт, сб 16:00–6:00
# {}
# ежедневно 7:30–1:00
# {}
# пн–вс 12:00–до последнего гостя (кухня до 23:00)
# {}
# ежедневно 12:00–23:55
# {}
# пн-вс с 12:00 до последнего гостя
# {}
# пн–чт, вс 12:00–2:00, пт, сб 12:00–5:00
# {}
# пн–вс 11:00–23:00 (кухня до 22:00)(банкеты до 02:00)
# {}
# пн–вс 11:00–01:00 (кухня с 12:00–00:00)
# {'1': [1200, 0], '7': [1200, 0]}
# ежедневно 8:00–6:00 (кухня: ежедневно 8:00–1:00)
# {}
# пн–чт, вс 12:00–1:00, пт, сб 12:00–2:30
# {}
# пн–чт 11:00–23:30, пт 11:00–1:30, сб 12:00–1:30, вс 12:00–23:30
# {'1': [1200, 130], '4': [1200, 130], '5': [1200, 130]}
# пн–вс 12:00–00:00, кухня до 23:30
# {}
# ежедневно 12:00–0:00 (кухня: ежедневно 12:00–23:00)
# {}
# пн-вс 10:00-18:00, по заказу
# {}
# ежедневно 10:00–23:30
# {}
# ежедневно 16:00–4:00
# {}
# пн–чт, вс 9:00–1:00, пт, сб 9:00–5:00
# {}
# ежедневно 13:00–1:00
# {}
# пн–чт 9:00–1:00, пт 9:00–2:00, сб 10:00–2:00, вс 10:00–1:00
# {'1': [1000, 200], '4': [1000, 200], '5': [1000, 200]}
# пн–чт, вс 8:00–1:00, пт, сб 8:00–2:00
# {}
# ежедневно 6:30–22:30
# {}
# пн–вс 12:00–24:00 (кухня работает до 23:30)
# {}
# пн–вс 10:00–до последнего гостя
# {}
# пн–вс 12:00–00:00 (кухня работает до 23:00, заказ по кухне нужно сделать не позже 22:15)
# {}
# ежедневно 17:00–8:00
# {}
# ресторан пн–вс 12:00–24:00, буфет пн–вс 11:00–23:00
# {}
# пн–чт, вс 20:00–5:00, пт, сб 20:00–6:00
# {}
# завтрак: пн–вс 7:00–10:30, ужин: пн–сб 18:00 – 23:00, Бранч: вс 13:00 – 16:30
# {}
# ежедневно 17:00–23:00
# {}
# вс–чт 11:00–23:00 (кухня работает до 22:30), пт–сб 11:00–01:00 (кухня работает до 00:30)
# {'4': [1100, 100], '7': [1100, 100]}
# пн–вс до последнего посетителя
# {}
# пн–пт 10:00–23:30, сб, вс 11:00–23:30 (кухня: пн–пт 10:00–23:00, сб, вс 11:00–23:00)
# {'1': [1100, 2300], '5': [1100, 2300], '6': [1100, 2300], '7': [1100, 2300]}
# пн–пт 13:00–2:00, сб, вс 12:00–2:00
# {}
# пн–чт 9:00–23:00, пт 9:00–2:00, сб 12:00–2:00, вс 12:00–23:00
# {'1': [1200, 200], '4': [1200, 200], '5': [1200, 200]}
# пн–вс 12:00–24:00 (кухня работает до 23:00)
# {}
# ресторан: 11:00–01:00, бистро: 11:00–23:00 , пивной ресторанчик: 11:00-23:00
# {}
# пн–вс с 12:00 до последнего посетителя
# {}
# пн–вс 08:00–24:00 (кухня до 23:00)
# {}
# пн–пт 10:00–22:00, сб, вс 10:00–23:00
# {}
# пн–чт, вс 14:00–2:00, пт, сб 14:00–5:00
# {}
# пн–пт 10:00–19:00, сб–вс только на банкеты по договоренности
# {}
# пн–вс 08:00–до последнего гостя (кухня до 23:00)
# {}
# пн–вс 11:00–до последнего гостя
# {}
# ежедневно с  12:00 до 24:00
# {}
# пн–чт 11:00–1:00, пт 11:00–2:00, сб 12:00–2:00, вс 12:00–1:00
# {'1': [1200, 200], '4': [1200, 200], '5': [1200, 200]}
# пн–чт 11:00–1:00, пт, сб 11:00–2:30
# {}
# пн–пт 9:00–23:00, сб, вс 12:00–23:00
# {}
# сб, вс 9:00–1:00, пн–пт 9:00–0:00
# {}
# пн–чт 13:00–0:00, пт 13:00–2:00, сб 12:00–2:00, вс 12:00–0:00
# {'1': [1200, 200], '4': [1200, 200], '5': [1200, 200]}
# пн–вс 11:00–24:00 (кухня до 23:00)
# {}
# пн–чт, вс 11:00–23:00, пт, сб 11:00–0:00
# {}
# пн–сб 12:00–до последнего гостя, вс 14:00–до последнего гостя
# {}
# пн–вс 12:00–24:00, кухня работает до 23.30
# {}
# вс–вт с 11:00 до последнего посетителя (кухня до 02:00), ср–чт с 12:00 до последнего посетителя (кухня до 02:00), пт–сб 11:00–06:00
# {}
# пн–чт, вс 12:00–2:00, пт, сб 11:00–3:00
# {}
# пн–вс с 07:00 до последнего гостя, кухня до 24:00
# {}
# пн–пт 12:00–23:30, сб, вс 13:00–23:30
# {}
# завтраки: пн–вс 07:30–11:00.  А-ля карт: круглосуточно без тех. перерыва. Лобби-бар: круглосуточно (после 23:00 в меню только напитки)
# {}
# пн–вс с 12:00 до последнего посетителя, кухня работает: вс–чт до 00:30, пт, сб до 01:30.
# {}
# пн–чт 09:00–23:00, пт с 09:00 до последнего гостя, сб с 13:00 до последнего гостя, вс 13:00–23:00
# {}
# пн–вс 12:00–02:00,  кухня работает до 23:30
# {}
# пн–вс 12:00–24:00, кухня до 23:00
# {}
# пн–пт с 10:00 до последнего посетителя, сб–вс с 12:00 до последнего посетителя
# {}
# пн–вс 12:00–00:00 (кухня), круглосуточно (ресторан)
# {}
# пн–пт 9:30–17:30
# {}
# пт–вс 18:00–3:00
# {}
# с 9-00 до 23-00
# {}
# пн–чт, вс 18:00–3:00, пт, сб 18:00–5:00
# {}
# чт–вт 10:00–18:00 (касса до 17:00)
# {}
# посещение только по записи
# {}
# пн–пт 10:15–01:15, сб–вс 09:00–03:45 (предварительная запись обязательна)
# {'1': [900, 345], '5': [900, 345]}
# ежедневно 10:30–4:00
# {}
# с 10:00 по будням и с 12:00 по выходным до 21:00; в дни проведения мероприятий   режим работы продлевается на неопределённое время.
# {}
# ежедневно с 10:00 до 23:00
# {}
# пт 23:00–0:00, сб 23:00–0:00
# {}
# пн–ср, вс 12:00–23:00, чт–сб 12:00–1:00
# {}
# ежедневно 10:45–23:00
# {}
# пн–пт 11:00–21:00, сб, вс 10:00–22:00
# {}
# сб, вс 10:00–22:00, пн–чт 11:00–21:00, пт 11:00–22:00
# {'6': [1100, 2100], '7': [1100, 2100]}
# пн–пт 8:00–0:00, сб, вс 10:00–0:00
# {}
# пн–пт 12:00–0:00, сб, вс 10:30–1:30
# {}
# сб 11:00–18:00, пн–пт 12:00–20:00
# {}
# пн–чт, вс 11:00–23:00, пт, сб 11:00–21:00
# {}
# пн–ср, вс 12:00–0:00, чт 12:00–1:00, пт 12:00–2:00, сб 12:00–2:00
# {'1': [1200, 200], '3': [1200, 200], '7': [1200, 200], '4': [1200, 200]}
# пн 12:00–1:00, вт–чт 12:00–2:00, пт 12:00–2:00, сб 13:00–2:00, вс 13:00–1:00
# {'1': [1300, 200], '2': [1300, 200], '4': [1300, 200], '5': [1300, 200]}
# пн 13:00–0:00, вт–чт 13:00–1:00, пт 13:00–2:00, сб 12:00–2:00, вс 12:00–0:00
# {'1': [1200, 200], '2': [1200, 200], '4': [1200, 200], '5': [1200, 200]}
# пн–пт 12:30–0:00, сб, вс 12:00–0:00
# {}
# пн–чт 12:30–0:00, пт 12:30–1:00, сб 13:00–1:00, вс 13:00–0:00
# {'1': [1300, 100], '4': [1300, 100], '5': [1300, 100]}
# пн–чт 12:30–0:00, пт 12:30–1:00, сб 12:00–1:00, вс 12:00–0:00
# {'1': [1200, 100], '4': [1200, 100], '5': [1200, 100]}
# пн–чт 12:00–0:00, пт 12:00–1:00, сб 12:30–1:00, вс 12:30–0:00
# {'1': [1230, 100], '4': [1230, 100], '5': [1230, 100]}
# пн–пт 10:00–1:30, сб, вс 10:00–2:50
# {}
# касса: ежедневно 12:00–22:30
# {}
# пн–пт 10:00–22:00, сб, вс 9:00–22:00
# {}
# пн–чт 12:00–23:00, пт, сб 12:00–1:00, вс 13:00–23:00
# {'1': [1200, 100], '4': [1200, 100]}
# пн–пт 7:00–23:00, сб, вс 9:00–20:00
# {}
# ср–пт 11:00–21:00, сб, вс 10:00–21:00
# {}
# ежедневно 10:00–23:45
# {}
# пн–чт, вс 12:00–3:00, пт, сб 12:00–6:00
# {}
# пн–чт, вс 17:00–1:00, пт, сб 17:00–4:00
# {}
# пн–пт 8:00–20:30, сб 10:00–20:30, вс 12:00–20:30
# {'1': [1000, 2030], '5': [1000, 2030]}
# ежедневно 10:30–0:00
# {}
# пн–пт 7:00–23:00, сб, вс 8:00–23:00
# {}
# пн 12:00–23:00, вт–пт, вс 12:00–0:00, сб 12:00–1:00
# {'1': [1200, 0]}
# пн–чт, вс 15:00–23:00, пт, сб 15:00–0:30
# {}
# пн–чт 16:00–1:00, пт 16:00–2:00, сб 14:00–2:00, вс 14:00–1:00
# {'1': [1400, 200], '4': [1400, 200], '5': [1400, 200]}
# ежедневно 10:30–1:30
# {}
# пн–пт 11:00–22:00, сб, вс 10:00–19:00
# {}
# ежедневно 10:00–22:30
# {}
# ср–вс 12:00–23:00
# {}
# пн–пт 14:00–20:00, сб, вс 11:00–20:00
# {}
# пн–чт, вс 13:00–0:00, пт, сб 13:00–2:00
# {}
# пн–пт 11:00–23:30, сб, вс 12:00–0:00
# {}
# пн–чт, вс 11:00–2:00, пт, сб 11:00–6:00
# {}
# ежедневно 10:00–3:30
# {}
# ежедневно 16:00–8:00
# {}
# пн–пт 15:00–2:00, сб 12:00–6:00, вс 12:00–23:00
# {'1': [1200, 600], '5': [1200, 600]}
# пн–чт, вс 11:00–1:00, пт, сб 11:00–5:00
# {}
# ежедневно 10:00–1:30
# {}
# ежедневно 13:00–22:00
# {}
# пн–чт 19:00–22:00, пт, сб 23:00–7:00
# {}
# пн–сб 10:00–22:00, вс 11:00–22:00
# {}
# пн–ср, вс 11:30–1:00, чт–сб 11:30–3:00
# {}
# пн, вт, чт, пт 11:00–21:00, сб 14:00–21:00
# {}
# ежедневно 14:00
# {}
# ежедневно 10:00–23:20
# {}
# ежедневно 10:30–22:30
# {}
# ежедневно 10:00–23:59
# {}
# пн–пт 8:00–20:00, сб, вс 9:00–20:00
# {}
# ежедневно 20:00–3:00
# {}
# пн–чт, вс 8:30–23:00, пт, сб 8:30–0:00
# {}
# пн–чт, вс 11:30–1:00, пт, сб 11:30–2:30
# {}
# пн–пт 12:00–21:00, сб, вс 11:00–21:00
# {}
# пн–чт 11:30–3:00, пт, сб 11:30–6:00, вс 11:30–3:00
# {'1': [1130, 600], '4': [1130, 600]}
# ежедневно 9:30–21:00
# {}
# пн–чт 13:00–1:00, пт 13:00–4:00, сб 12:00–4:00, вс 12:00–1:00
# {'1': [1200, 400], '4': [1200, 400], '5': [1200, 400]}
# пн–чт 10:00–1:00, пт 10:00–14:00, сб, вс 9:00–14:00
# {'1': [1000, 1400], '4': [1000, 1400]}
# пн–чт 10:00–0:00, пт 10:00–2:00, сб 12:00–2:00, вс 12:00–0:00
# {'1': [1200, 200], '4': [1200, 200], '5': [1200, 200]}
# пн–пт 12:00–0:00, сб, вс 12:00–23:00
# {}
# пн–чт, вс 14:00–23:30, пт, сб 14:00
# {}
# пн–чт 10:00–23:00, пт 10:00–0:00, сб, вс 10:00–1:00
# {'1': [1000, 0], '4': [1000, 0]}
# пн–сб 10:00–19:00
# {}
# ежедневно 15:00–6:00
# {}
# пн–пт 8:30–23:00, сб 10:00–1:00, вс 10:00–23:00
# {'1': [1000, 100], '5': [1000, 100]}
# пн–чт, вс 11:00–21:00, пт, сб 11:00–22:00
# {}
# пн–пт 16:00–2:00, сб, вс 16:00–4:00
# {}
# пн–пт 12:00–20:00, сб, вс 12:00–23:00
# {}
# ежедневно 21:00–6:00
# {}
# пн–чт 12:00–1:00, пт 12:00–3:00, сб 13:00–3:00, вс 13:00–1:00
# {'1': [1300, 300], '4': [1300, 300], '5': [1300, 300]}
# пн–ср, вс 11:00–1:00, чт–сб 11:00–3:00
# {}
# пн–чт, вс 11:00–22:00, пт, сб 11:00–23:00
# {}
# пн–пт 9:30–18:00
# {}
# пн–чт 12:00–0:00, пт 12:00–2:00, сб 13:00–2:00, вс 13:00–0:00
# {'1': [1300, 200], '4': [1300, 200], '5': [1300, 200]}
# пн–пт 11:00–22:00, сб, вс 12:00–18:30
# {}
# пн–чт, вс 14:00–23:00, пт, сб 14:00–1:00
# {}
# вт–пт 11:00–20:00, сб 11:00–19:00
# {}
# пн–сб 10:00–18:15
# {}
# кухня: ежедневно 20:00–8:00
# {}
# пн–чт 12:00–23:00, пт 12:00–6:00, сб 15:00–6:00, вс 15:00–23:00
# {'1': [1500, 600], '4': [1500, 600], '5': [1500, 600]}
# пн–пт 8:30–22:00, сб, вс 9:30–22:00
# {}
# пн–пт 12:00–23:00, сб, вс 9:00–22:00
# {}
# пн–чт 11:00–23:00, пт 11:00–1:00, сб 12:00–1:00, вс 12:00–23:00
# {'1': [1200, 100], '4': [1200, 100], '5': [1200, 100]}
# пн–сб 10:00–22:00, вс 10:00–20:00
# {}
# ежедневно 17:00–6:00
# {}
# пн–пт 9:30–22:00, сб, вс 12:00–22:00
# {}
# пн–пт 11:00–20:00, сб, вс 10:00–20:00
# {}
# пн–пт 9:00–21:00, сб, вс 11:00–20:00
# {}
# пн–ср, пт–вс 10:00–20:00
# {}
# пн–чт, вс 12:00–6:00, пт, сб 12:00–7:00
# {}
# ежедневно 12:00–23:59
# {}
# пн–чт 13:00–1:00, пт–вс 14:00–2:00
# {}
# пн–пт 15:00–23:20, сб, вс 10:00–23:20
# {}
# пн–пт 15:00–23:30, сб, вс 10:00–23:30
# {}
# ежедневно 8:30–22:30
# {}
# ежедневно 9:30–22:45
# {}
# пн–пт 15:40–23:40, сб, вс 10:20–23:40
# {}
# ежедневно 15:20–23:20
# {}
# пн–пт 15:20–23:20, сб, вс 10:00–23:20
# {}
# пн–чт 9:00–23:00, пт 9:00–2:00, сб 10:00–2:00, вс 10:00–23:00
# {'1': [1000, 200], '4': [1000, 200], '5': [1000, 200]}
# пн–чт 17:00–21:00
# {}
# ежедневно 9:00–23:30
# {}
# пн–пт, вс 12:00–23:00, сб 12:00–23:59
# {}
# пн–чт, вс 13:00–23:00, пт, сб 13:00–1:00
# {}
# пн–пт 11:00–20:00, сб, вс 14:00–18:00
# {}
# пн–чт, вс 12:00–0:00, пт, сб 12:00–5:00
# {}
# пн–чт 12:00–0:00, пт 12:00–5:00, сб 15:00–5:00, вс 15:00–0:00
# {'1': [1500, 500], '4': [1500, 500], '5': [1500, 500]}
# ежедневно 9:00–23:59
# {}
# пн–чт, вс 13:00–0:00, пт, сб 13:00–4:00
# {}
# пн–чт 11:00–2:00, пт, сб 11:00–6:00
# {}
# ср–вс 21:00–6:00
# {}
# пн–чт 11:00–22:00, пт 11:00–23:00, сб 10:00–23:00, вс 10:00–22:00
# {'1': [1000, 2300], '4': [1000, 2300], '5': [1000, 2300]}
# пн–пт 10:00–19:00, сб, вс 12:00–18:00
# {}
# вт–пт 10:00–18:00, вс 11:00–14:00
# {}
# пн–ср, вс 12:00–3:00, чт–сб 12:00–6:00
# {}
# пт, сб 12:00–0:00, вс 12:00–23:00
# {}
# пн–пт 12:00–22:00, сб, вс 11:00–21:00
# {}
# пн–сб 9:00–18:00
# {}
# пн–пт 10:00–20:00, сб, вс 11:00–19:00
# {}
# пн–сб 18:00–21:00
# {}
# пн–чт, вс 12:00–1:00, пт, сб 12:00–4:00
# {}
# ежедневно 20:00–8:00
# {}
# ежедневно 10:30–2:00 (кухня: ежедневно 10:30–2:00)
# {}
# пн–чт 10:00–23:00, пт 10:00–23:30, сб 11:00–23:30, вс 11:00–23:00
# {'1': [1100, 2330], '4': [1100, 2330], '5': [1100, 2330]}
# пн–пт 11:00–23:00, сб, вс 10:00–0:00
# {}
# пн–пт, вс 10:00–17:00
# {}
# ежедневно 7:30–22:00
# {}
# пн–чт, вс 11:00–23:00
# {}
# пн–пт 18:00–0:00, сб, вс 12:00–0:00
# {}
# пн–пт 12:00–21:00, сб, вс 10:00–20:00
# {}
# пт 18:00–21:00
# {}
# ежедневно 11:00–3:00
# {}
# вт–чт 12:00–22:00, пт, сб 12:00–0:00
# {}
# пн–чт, вс 11:00–2:00, пт, сб 11:00–16:00
# {}
# вт–чт 12:00–20:00, сб 12:00–18:00
# {}
# пн–чт 12:00–23:00, пт, сб 12:00–5:00, вс 12:00–22:00
# {'1': [1200, 500], '4': [1200, 500]}
# ежедневно 10:00–21:00 (касса: ежедневно 10:00–20:00)
# {}
# ежедневно 10:00–19:30
# {}
# ежедневно 9:30–23:45
# {}
# ежедневно 10:00–21:30
# {}
# пн–чт 9:00–23:00, пт 9:00–0:00, сб 12:00–0:00, вс 12:00–23:00
# {'1': [1200, 0], '4': [1200, 0], '5': [1200, 0]}
# пн–чт 14:00–0:00, пт–вс 12:00–2:00
# {}
# пн–пт 9:00–2:00, сб, вс 10:00–2:00
# {}
# вт–чт 11:00–2:00, пт, сб 11:00–6:00
# {}
# пн–пт 11:00–20:00, сб, вс 10:00–19:00
# {}
# пн, ср–вс 12:00–17:45
# {}
# пн–чт, вс 17:00–0:00, пт, сб 17:00–6:00
# {}
# ср, чт, вс 13:00–23:00, пт, сб 13:00–0:00
# {}
# пн–чт 8:00–0:00, пт 8:00–1:00, сб 9:30–1:00, вс 10:00–0:00
# {'1': [930, 100], '4': [930, 100], '5': [930, 100]}
# пн–чт, вс 12:00–23:00, пт, сб 12:00–23:59
# {}
# пн–чт 12:00–22:00, пт, сб 12:00–5:00, вс 12:00–23:00
# {'1': [1200, 500], '4': [1200, 500]}
# пн–чт, вс 11:00–23:00, пт, сб 11:00–2:00
# {}
# пн–пт 8:00–22:00, сб, вс 10:00–21:00
# {}
# пн–чт 12:00–23:00, пт, сб 12:00–0:00, вс 11:00–23:00
# {'1': [1200, 0], '4': [1200, 0]}
# пн–чт 17:00–0:00, пт, сб 12:00–2:00, вс 12:00–0:00
# {'1': [1200, 200], '4': [1200, 200]}
# пн–чт 12:00–0:00, пт, сб 12:00–2:00, вс 11:00–0:00
# {'1': [1200, 200], '4': [1200, 200]}
# ежедневно 18:00–1:00
# {}
# пн–чт 11:00–21:00, пт–вс 10:00–22:00
# {}
# ежедневно 8:30–22:00
# {}
# ежедневно 9:00–2:00
# {}
# пн–пт 13:30–22:00, сб, вс 11:20–20:00
# {}
# ежедневно 16:00–6:00
# {}
# пн–чт 12:00–4:00, пт–вс 12:00–6:00
# {}
# ежедневно 14:00–6:00
# {}
# пн 19:30
# {}
# пн–чт, вс 10:30–23:00, пт, сб 10:30–1:00
# {}
# пн–пт 11:00–22:00, сб, вс 11:00–19:00
# {}
# ср–вс 19:00–23:00
# {}
# ежедневно 10:00
# {}
# ежедневно 15:00
# {}
# пн–пт 12:00–21:00, сб, вс 10:00–21:00
# {}
# пн–пт 11:00–23:00, сб, вс 12:00–23:00
# {}
# пн–чт 11:00–23:00, пт 11:00–2:00, сб 13:00–2:00, вс 13:00–23:00
# {'1': [1300, 200], '4': [1300, 200], '5': [1300, 200]}
# ср, чт, вс 18:00–3:00, пт, сб 18:00–6:00
# {}
# пн–ср, вс 12:00–0:00, чт–сб 12:00–2:00
# {}
# пн–пт 17:00–1:00, сб, вс 14:00–1:00
# {}
# пн–пт 8:00–23:00, сб, вс 11:00–23:00
# {}
# сб, вс 11:00 12:10
# {}
# ежедневно 16:00–2:00
# {}
# ср, чт 16:00–1:00, пт 16:00–5:00, сб 12:00–5:00, вс 12:00–1:00
# {'3': [1200, 500], '4': [1200, 500], '5': [1200, 500]}
# ежедневно 10:30–23:00
# {}
# пн, вт 18:00–23:00, ср, чт 18:00–0:00, пт 18:00–1:00, сб 15:00–1:00, вс 15:00–0:00
# {'1': [1500, 100], '2': [1500, 100], '3': [1500, 100], '4': [1500, 100], '5': [1500, 100]}
# пн–пт 17:30–21:30, сб, вс 11:30–21:30
# {}
# ежедневно 9:50–21:50
# {}
# пн–чт 17:00–23:00, пт 15:30–23:00, сб, вс 12:30–23:00
# {'1': [1530, 2300], '4': [1530, 2300]}
# сб, вс 12:00–17:00
# {}
# пн–пт 10:00–23:20, сб, вс 10:00–0:40
# {}
# пн–пт 12:00–22:30, сб, вс 12:00–1:30
# {}
# пн–пт 10:00–23:30, сб, вс 10:00–1:00
# {}
# пт 17:00–20:00, сб, вс 12:00–21:00
# {}
# ежедневно 9:45–23:15
# {}
# ежедневно 9:30–22:50
# {}
# ежедневно 9:00–22:30
# {}
# пн, сб 10:00–1:40, вт–пт 10:00–23:30, вс 10:00–2:00
# {'1': [1000, 2330], '6': [1000, 2330]}
# пн, сб, вс 10:45–1:45, вт–пт 10:45–23:15
# {}
# ежедневно 10:00–2:15
# {}
# пн–чт 10:25–22:55, пт 10:25–2:40, сб 9:10–2:55, вс 9:10–22:40
# {'1': [910, 255], '4': [910, 255], '5': [910, 255]}
# пн–чт 17:00–23:00, пт 17:00–0:00, сб 14:00–0:00, вс 14:00–23:00
# {'1': [1400, 0], '4': [1400, 0], '5': [1400, 0]}
# пн–чт, вс 10:15–22:45, пт 10:15–2:30, сб 9:00–2:45
# {'1': [1015, 230], '4': [1015, 230], '7': [1015, 230]}
# ...
# {}
# Среда 10:00-17:00
# {}
# сб 9:00–15:00, пн, ср, пт 9:00–21:00, чт 15:00–21:00
# {'6': [900, 2100]}
# ежедневно с 9 до 19.30, в воскресные дни - с 10 до 18 час., в дни великих праздников - до 19.30
# {}
# сб, вс 11:00–18:00
# {}
# вт, ср, пт–вс 11:00–19:00, чт 12:00–21:00
# {}
# пн, вт 10:00–23:00, ср–вс 9:00–0:00
# {}
# ежедневно 11:00–14:00
# {}
# пн–пт 09:00–17:00, сб–вс 09:000–18:00
# {}
# вт–чт 10:00–18:00
# {}
# пн–пт 5:30–1:00
# {}
# пн–пт 10:00–20:00, сб, вс 12:00–18:00
# {}
# пн–чт, вс 10:00–0:00, пт, сб 10:00–4:00
# {}
# сб, вс 11:00–17:00, пн–пт 11:00–19:00
# {}
# сб 11:00–15:00, пн–чт 18:00–22:30, пт 18:30–22:00
# {'6': [1800, 2230]}
# пн–пт 8:30–19:00, сб 10:00–13:00
# {}
# 10:00–22:00 (без выходных)
# {}
# сб 12:00–17:00, пт 12:00–19:00, ср 12:00–19:00, пн 12:00–19:00, чт 13:00–20:00, вт 13:00–20:00
# {'6': [1300, 2000], '5': [1300, 2000], '3': [1300, 2000], '1': [1300, 2000]}
# сб 11:00–16:00, вт–пт 11:00–19:00
# {}
# сб 10:00–16:00, вт 10:00–17:00, пт 12:00–18:00, ср 12:00–19:00, пн 12:00–19:00
# {'6': [1200, 1900], '2': [1200, 1900], '5': [1200, 1900]}
# сб 10:00–17:00, пн–пт 11:00–19:00
# {}
# сб 10:00–16:00, пн–чт 11:00–19:00
# {}
# пн–вс 10:00–23:00
# {}
# вт–вс 10:00–21:00, пн 13:00–21:00
# {}
# сб 10:00–17:00, пн–пт 10:00–20:00
# {}
# вт, ср, пт, вс 11:00–19:00, чт, сб 12:00–21:00
# {}
# пн–пт 10:00–21:00, сб 11:00–17:00
# {}
# пн–чт 10:00–20:00, пт–вс 10:00–21:00
# {}
# пн–пт 9:00–19:00, сб, вс 10:00–14:00
# {}
# вс 12:00–18:00, пн–чт 13:00–19:00
# {}
# сб 11:00–17:00, вт–пт 11:00–19:00
# {}
# вт–пт 12:00–18:00, сб 12:00–18:00
# {}
# сб 10:00–13:30, пн–пт 10:00–20:00
# {}
# пн–пт 12:00–19:00, сб 12:00–17:00
# {}
# пн–чт 12:00–19:00, пт, сб 12:00–18:00
# {}
# вт–пт 12:00–19:00, сб 12:00–18:00
# {}
# сб 9:00–16:00, пт 9:00–17:00, пн 10:00–18:00, вт–чт 11:00–19:00
# {'6': [1000, 1800], '5': [1000, 1800]}
# вт–чт 11:00–1900, пт 11:00–18:00, сб 10:00–16:00
# {}
# вт–пт 11:00–18:00, пн 12:00–19:00
# {}
# вс 10:00–15:00, сб 10:00–18:00, пн–пт 10:00–20:00
# {'7': [1000, 1800]}
# пн–пт 9:00–21:00, сб 9:00–19:00
# {}
# пн–пт 9:00–20:00, сб, вс 9:00–15:00
# {}
# вс 12:00–16:00, чт 16:00–20:00
# {}
# вт 16:30–20:30, вс 12:15–16:45
# {}
# вс 12:00–15:00, вт 17:00–20:00
# {}
# пн, ср, пт 16:00–20:00
# {}
# 10.00–22.00 без выходных
# {}
# пн–пт 7:30–19:00, сб, вс 7:30–20:00
# {}
# сб 10:00–17:00, пт 11:00–18:00, вт–чт 11:00–19:00
# {'6': [1100, 1800]}
# сб 10:00–18:00, пн–пт 10:00–20:00
# {}
# пн 17:15–20:30
# {}
# пн, вт 8:00–21:00
# {}
# ср, сб 15:00–21:00
# {}
# касса: пн–пт 11:00–19:00
# {}
# кассы ср–пт 15:00–19:00, сб–вс 11:00–14:00
# {}
# пн–чт, вс 15:00–23:00, пт, сб 15:00–0:00
# {}
# пн–пт 12:002–3:00, сб–вс 10:0–023:00
# {}
# пн–пт 16:00–0:00, сб 14:00–0:00, вс 15:30–0:00
# {'1': [1400, 0], '5': [1400, 0]}
# пн–пт 8:30–22:00, сб, вс 10:00–18:00
# {}
# сб 9:00–15:00, пн–пт 9:00–21:00
# {}
# вт–пт 13:00–0:00, сб, вс 11:00–0:00
# {}
# пт–вс 10:00–20:00
# {}
# пн–чт 12:00–1:00, пт 12:00–5:00, сб 10:00–5:00, вс 10:00–1:00
# {'1': [1000, 500], '4': [1000, 500], '5': [1000, 500]}
# пн–пт 15:00–3:00, сб, вс 12:00–3:00
# {}
# пн–чт 16:00–2:00, пт 16:00–4:00, сб 10:00–4:00, вс 10:00–2:00
# {'1': [1000, 400], '4': [1000, 400], '5': [1000, 400]}
# пн - вс: 13:00 - 22:00
# {}
# зал постоянной экспозиции: вт-вс 11:00–19:00; выставочный зал: ср-вс 13.00–20.00
# {}
# пн 15:00–22:00, вт–вс 10:00–22:00
# {}
# ежедневно 13:00–17:00
# {}
# сб, вс 12:00–20:00
# {}
# вт, ср 12:00–18:00, пт–вс 12:00–18:00
# {}
# пн–сб 10:30–20:00
# {}
# пн–пт 12:00–23:00, сб–вс: 10:00–22:00
# {}
# пн–пт 9:00–18:00,  суб–вс — выходные дни.
# {}
# пн, чт–вс 10:00–18:00, ср 11:00–19:00 (касса: пн, чт–вс 10:00–17:00, ср 11:00–18:00)
# {'1': [1100, 1800], '4': [1100, 1800], '7': [1100, 1800], '3': [1100, 1800]}
# ежедневно: 00:00–00:00
# {}
# пн–сб 7:00–20:00, вс 6:00–20:00
# {}
# ежедневно 8:30–18:30
# {}
# отделы регистрации пн–вс 08:00–00:00
# {}
# пн–пт 12:00–5:00, сб–вс 11:00–5:00 (боулинг, бильярд, рестораны),  пн–пт 12:00–22:00, сб–вс 10:00–23:00 (детский центр)
# {'1': [1000, 2300], '5': [1000, 2300], '6': [1000, 2300], '7': [1000, 2300]}
# пн–ср 12:00–0:00, чт, пт 12:00–5:00, сб 11:00–5:00, вс 11:00–0:00
# {'1': [1100, 500], '3': [1100, 500], '4': [1100, 500], '5': [1100, 500]}
# пн–пт 12:00–05:00, сб–вс 11:00–05:00 (боулинг, бильярд, рестораны), пн–пт 12:00–23:00, сб–вс 11:00–23:00 (детский центр)
# {'1': [1100, 2300], '5': [1100, 2300], '6': [1100, 2300], '7': [1100, 2300]}
# пн–пт 14:00–5:00, сб, вс 11:00–5:00
# {}
# пн–ср 12:00–0:00, чт–сб 12:00–5:00, вс 12:00–0:00
# {'1': [1200, 500], '3': [1200, 500]}
# пн–пт 14:00–05:00, сб–вс 10:00–05:00 (боулинг, бильярд, рестораны), пн–пт 14:00–22:00, сб–вс 10:00–05:00 (детский центр)
# {'1': [1000, 500], '5': [1000, 500], '6': [1000, 500], '7': [1000, 500]}
# пн–пт 18:00–05:00, сб–вс 11:00–05:00 (боулинг, бильярд, рестораны), пн–пт 18:00–22:00, сб–вс 11:00–22:00 (детский центр)
# {'1': [1100, 2200], '5': [1100, 2200], '6': [1100, 2200], '7': [1100, 2200]}
# пн–пт 12:00–00:00, сб, вс 12:00–02:00 (до последнего посетителя)
# {'1': [1200, 200], '5': [1200, 200]}
# пн, вт 11:30–23:00
# {}
# чт-сб 18.00 и до последнего посетителя
# {}
# пн–пт 11:00–1:00, сб, вс 11:30–1:00
# {}
# пн–чт, вс 12:00–2:00, пт, сб 12:00–5:30
# {}
# чт–сб: 22:00–07:00
# {}
# пн–пт 8:00–23:00, сб, вс 10:00–0:00
# {}
# пн–чт, вс 11:30–0:00, пт, сб 11:30–5:00
# {}
# чт–вс 10:00–18:00
# {}
# пн–пт 11:00–18:00 (администрация)
# {}
# вт–пт 11:00–19:00, сб, вс 11:00–21:00
# {}
# пн–вс 09:45–23:45 (предварительная запись обязательна)
# {}
# пн–вс 11:30–23:30
# {}
# ср–пт 16:00–19:00, сб, вс 19:00–22:00
# {}
# пн–вс 11:00–24:00 (предварительная запись обязательна)
# {}
# пн–сб 11:00–19:00, чт 11:00–21:00
# {}
# пн–пт 12:00–0:00, сб, вс 11:00–1:00
# {}
# чт–вс 17:00–21:00
# {}
# вт, ср, вс 12:00–20:00, чт–сб 12:00–21:00
# {}
# пт, сб 21:00–6:00
# {}
# посещение  возможно только в дни проведения праздников и фестивалей
# {}
# пн–пт 10:00–19:00, сб, вс 10:00–17:00
# {}
# вт, ср, пт–вс 11:00–20:00, чт 11:00–22:00
# {}
# ср–вс 12:00–19:00 (посещение по предварительной записи по телефону)
# {}
# пн–вс 11:00–17:00 (только экскурсионное обслуживание – необходима предварительная договоренность)
# {}
# ср–вс 12:00–19:00, режим работы кассы ср–вс 12:00–18:30 (посещение по предварительной записи)
# {'3': [1200, 1830], '7': [1200, 1830]}
# пн–чт, вс 11:00–19:00 (касса: пн–чт, вс 11:00–18:30)
# {'1': [1100, 1830], '4': [1100, 1830], '7': [1100, 1830]}
# 1 ноября — 1 апреля ср–вс 11:00–16:00, 2 апреля — 31 октября ср–вс 11:00–17:00
# {}
# касса: вт–вс 12:00–20:00
# {}
# ср–сб 14:00–20:00, вс 12:00–18:00
# {}
# пн–пт 10:00–18:00; посещение музея возможно исключительно по предварительной договоренности
# {}
# пн–вс 10:00–17:00, экскурсии проводятся для групп по предварительной записи
# {}
# касса: ежедневно 10:00–15:00 16:00–20:00
# {}
# касса: ежедневно 9:00–22:00
# {}
# пн–ср 8:30–23:00, чт 8:30–0:00, пт 8:30–6:00, сб 10:00–6:00, вс 10:00–23:00
# {'1': [1000, 600], '3': [1000, 600], '4': [1000, 600], '5': [1000, 600]}
# по договоренности, запись на сайте компании
# {}
# касса: ежедневно 11:00–22:00
# {}
# вт–пт 11:00–19:00, сб, вс 11:00–20:00
# {}
# ср–сб 10:00–19:00, вс 10:00–18:00
# {}
# ежедневно 10:30–3:00
# {}
# пн–пт 11:00–22:00, сб, вс 12:00–20:00
# {}
# пн–вс 10:00–02:00 (обязательна предварительная бронь)
# {}
# ежедневно 9:00–2:30
# {}
# пн-чт — с 12:00 до 23:00; пт-сб — с 12:00 до 01:00; вс — с 12:00 до 22:00
# {}
# пн–чт 9:00–23:00, пт 9:00–0:30, сб 11:00–0:30, вс 11:00–23:00
# {'1': [1100, 30], '4': [1100, 30], '5': [1100, 30]}
# пн–чт 12:00–1:00, пт 12:00–6:00, сб 17:00–6:00, вс 17:00–1:00
# {'1': [1700, 600], '4': [1700, 600], '5': [1700, 600]}
# пн–вс 15:00 и до последнего клиента (после 23:00 — только по предварительной брони)
# {}
# пн–чт 14:00–2:00, пт, сб 14:00–6:00, вс 14:00–2:00
# {'1': [1400, 600], '4': [1400, 600]}
# круглосуточно (предварительная запись обязательна)
# {}
# пн–чт 12:00–23:00, пт 12:00–06:00, сб 14:00–06:00, вс – выходной
# {'1': [1400, 600], '4': [1400, 600], '5': [1400, 600]}
# пн–пт 12:30–00:30, сб–вс 10:00–03:30 (предварительная запись обязательна)
# {'1': [1000, 330], '5': [1000, 330]}
# пн, ср, чт, вс 10:00–18:00, пт, сб 10:00–21:00
# {}
# вт–пт 10:30–18:00, сб 10:30–20:00, вс 10:30–19:00
# {'2': [1030, 2000], '5': [1030, 2000]}
# ежедневно 18:00–23:00
# {}
# касса: ежедневно 10:00–20:30
# {}
# пн–пт 9:30–19:00, сб, вс 10:00–20:00 (касса: пн–пт 9:30–18:00, сб, вс 10:00–19:00)
# {'1': [1000, 1900], '5': [1000, 1900], '6': [1000, 1900], '7': [1000, 1900]}
# ежедневно 10:00–14:00 15:00–19:00
# {}
# пт, сб 18:00–6:00
# {}
# пн–чт 11:30–0:00, пт, сб 11:30–3:00
# {}
# пн–пт 9:00–21:00, сб, вс 11:00–18:00
# {}
# вт–пт 13:00–20:00
# {}
# пн–пт 12:00–20:00, сб, вс 12:00–17:00
# {}
# сб 11:45–12:45, вс 10:30–12:45
# {}
# пн–пт 10:00–6:00, сб, вс 12:00–6:00
# {}
# пн–чт, вс 12:00–0:00, пт 12:00–6:00, сб 10:00–2:00
# {'1': [1200, 600], '4': [1200, 600], '7': [1200, 600]}
# пн–пт 10:00–22:00, сб, вс 10:00–19:00
# {}
# ежедневно 9:00–0:30
# {}
# пн–чт, вс 9:30–0:30, пт, сб 9:30–5:00
# {}
# пн–пт 10:00–22:00, сб, вс 11:00–21:00
# {}
# пн–пт 9:00–21:00, сб 9:00–17:00
# {}
# пн–пт 13:00–21:00, сб, вс 12:00–22:00
# {}
# ср, пт 20:00–22:00, сб, вс 19:00–21:00
# {}
# пн–чт 8:30–23:00, пт 8:30–0:00, сб 10:00–0:00, вс 10:00–0:00
# {'1': [1000, 0], '4': [1000, 0], '5': [1000, 0]}
# пн–чт 11:00–0:00, пт 11:00–6:00, сб 12:00–6:00, вс 12:00–0:00
# {'1': [1200, 600], '4': [1200, 600], '5': [1200, 600]}
# ежедневно 9:00–8:59
# {}
# пн–пт 7:00–23:00, сб, вс 9:00–22:00
# {}
# пн–пт 9:00–20:00, сб 12:00–18:00
# {}
# пн, вт, пт–вс 11:00–20:00, ср, чт 12:00–21:00
# {}
# пн–пт 8:30–23:00, сб, вс 9:00–23:00
# {}
# пн 19:00–23:00, вт 19:00–23:00, ср 19:00–23:00, чт 19:00–23:00, пт 19:00–23:00, сб 19:00–23:00, вс 19:00–23:00
# {'1': [1900, 2300], '2': [1900, 2300], '3': [1900, 2300], '4': [1900, 2300], '5': [1900, 2300]}
# ежедневно 9:15–0:15
# {}
# ежедневно 10:15–23:05
# {}
# пн–чт 9:30–22:00, пт 9:30–23:15, сб, вс 9:30–5:54
# {'1': [930, 2315], '4': [930, 2315]}
# ежедневно 9:30–3:30
# {}
# вт–вс 10:00–20:45
# {}
# ежедневно 17:00–2:00
# {}
# пн–пт 11:00–20:00, сб, вс 11:00–21:00
# {}
# пн–пт, вс 11:30–21:00, сб 10:30–21:00
# {}
# вт, ср, сб 12:00–20:00, чт, пт 13:00–21:00, вс 11:00–19:00
# {'2': [1300, 2100], '3': [1300, 2100], '6': [1300, 2100]}
# пт 15:00–0:00, сб, вс 12:00–0:00
# {}
# пн–чт 10:00–22:00, пт–вс 10:00–23:00
# {}
# ежедневно 11:00–19:30
# {}
# ежедневно 11:45–22:00
# {}
# ежедневно 10:00–18:40
# {}
# вт–чт 13:00–23:00, пт, сб 12:00–0:00, вс 12:00–23:00
# {'2': [1200, 0], '4': [1200, 0]}
# вт 19:00–20:00
# {}
# пн–ср, вс 11:00–0:00, чт–сб 11:00–2:00
# {}
# пн–чт 11:00–23:00, пт 11:00–0:00, сб 12:00–0:00, вс 12:00–23:00
# {'1': [1200, 0], '4': [1200, 0], '5': [1200, 0]}
# ежедневно 10:30–21:30
# {}
# пн–чт 12:00–0:00, пт–вс 12:00–6:00
# {}
# пн–чт, вс 13:00–0:00, пт, сб 13:00–6:00
# {}
# пн–чт 15:00–1:00, пт–вс 16:00–6:00
# {}
# пн–чт 12:00–0:00
# {}
# пн, вт, вс 12:00–22:00
# {}
# вт 19:00–22:00, сб 12:00–19:00
# {}
# ежедневно 14:00–22:30
# {}
# пн–пт 11:00–21:00, сб, вс 11:00–19:30
# {}
# пн–чт, вс 18:00–3:00, пт, сб 18:00–6:00
# {}
# пн–пт 9:00–19:00, сб, вс 10:00–19:00
# {}
# пн, вт, чт–вс 10:00–22:00
# {}
# пн–пт 9:00–23:00, сб, вс 11:30–23:00
# {}
# пн, вс 12:00–0:00, вт–чт 12:00–1:00, пт, сб 12:00–3:00
# {'1': [1200, 100], '7': [1200, 100]}
# пн–чт, вс 9:00–0:00, пт, сб 9:00–2:00
# {}
# пн–пт 8:00–22:00, сб, вс 10:00–19:00
# {}
# ежедневно 10:00–1:15
# {}
# пн–пт 12:00–0:00, сб, вс 11:00–0:00
# {}
# пн–пт 15:00–23:00, сб, вс 10:00–23:00
# {}
# пн–пт 10:00–19:00, сб, вс 10:00–21:00
# {}
# пн–чт 12:00–0:00, пт 12:00–4:00, сб 13:30–4:00, вс 13:30–0:00
# {'1': [1330, 400], '4': [1330, 400], '5': [1330, 400]}
# пн, ср, пт 7:30–0:00, вт, чт 14:30–0:00, сб, вс 9:00–23:00
# {'1': [1430, 0], '3': [1430, 0], '5': [1430, 0]}
# пн–пт 8:00–6:00, сб, вс 11:00–6:00
# {}
# пн–чт, вс 11:30–23:59, пт, сб 11:30–2:00
# {}
# пн–пт 10:30–20:00, сб, вс 10:30–22:00
# {}
# ежедневно 11:00–7:00
# {}
# пн–чт, вс 11:30–5:00, пт, сб 11:30–6:00
# {}
# пн–чт 10:00–21:00, пт 10:00–22:00, сб, вс 9:00–23:00
# {'1': [1000, 2200], '4': [1000, 2200]}
# пн–чт, вс 11:00–0:00, пт, сб весь день
# {}
# пн–пт 12:00–1:00, сб, вс 15:00–1:00
# {}
# пн–пт 9:00–0:00, сб, вс 12:00–0:00
# {}
# вт–вс 13:00–22:00
# {}
# пн–пт 13:00–22:00, сб, вс 13:00–20:00
# {}
# пн, вс 10:00–2:00, пт, сб 10:00–3:00
# {}
# ср–пт 13:00–20:00, сб, вс 14:00–21:00
# {}
# пн–пт 13:00–23:00, сб, вс 14:00–20:00
# {}
# пн–пт 9:00–21:00, сб, вс 10:00–18:00
# {}
# пн–пт 11:00–21:00, сб 11:00–16:00
# {}
# пн–пт 9:00, сб 10:00–17:00
# {}
# пн–чт, вс 12:00–23:50, пт, сб 12:00–4:00
# {}
# ежедневно 19:00–21:00
# {}
# пн–чт 9:00–22:00, пт 9:00–23:00, сб 10:00–23:00, вс 10:00–22:00
# {'1': [1000, 2300], '4': [1000, 2300], '5': [1000, 2300]}
# пн–чт, вс 12:00–23:00, пт, сб 12:00–5:00
# {}
# пн–чт 10:00–0:00, пт–вс весь день
# {}
# ежедневно 10:00–22:00 (касса: ежедневно 10:00–21:30)
# {}
# пн–пт 11:00–20:00, сб, вс 10:00–21:00
# {}
# пн–чт 12:00–3:00, пт–вс 12:00–6:00
# {}
# пн–сб 9:30–20:00, вс 11:00–18:00
# {}
# ежедневно 14:00–2:00
# {}
# вт–вс 6:00–0:00
# {}
# пн–пт 11:00–19:00, сб, вс 11:00–20:00
# {}
# пн–чт 11:00–23:00, пт 11:00–3:00, сб 13:00–3:00, вс 13:00–23:00
# {'1': [1300, 300], '4': [1300, 300], '5': [1300, 300]}
# пн 16:00–22:00, вт–вс 10:00–22:00
# {}
# ежедневно 11:00–16:00
# {}
# пн–чт 16:00–23:00, пт 11:00–23:59, сб 0:00–23:59, вс 0:00–23:00
# {'1': [0, 2359], '4': [0, 2359], '5': [0, 2359]}
# пн–пт 8:00–0:00, сб, вс 10:00–23:00
# {}
# пн–чт 11:00–21:00, пт–вс 11:00–22:00
# {}
# ежедневно 8:30–17:00
# {}
# пн–пт 9:00–22:00, сб, вс 9:00–22:00
# {}
# пн–чт 12:00–23:59, пт 12:00–2:00, сб 14:00–2:00, вс 14:00–23:59
# {'1': [1400, 200], '4': [1400, 200], '5': [1400, 200]}
# пн–чт, вс 11:00–23:00, пт, сб 12:00–3:00
# {}
# пн–чт, вс 11:00–23:00, пт, сб 11:00–5:00
# {}
# касса: ежедневно 10:00–13:00 14:00–20:00
# {}
# пн–чт, вс 11:00–23:00, пт 11:00–2:00, сб 11:00–6:00
# {'1': [1100, 200], '4': [1100, 200], '7': [1100, 200]}
# пн–чт 9:00–23:00, пт 9:00–5:00, сб 12:00–5:00
# {'1': [900, 500], '4': [900, 500]}
# ежедневно 23:00
# {}
# ежедневно 10:30–22:00
# {}
# пн–пт 12:00–23:00, сб, вс 11:00–0:00
# {}
# вс 10:00–20:00
# {}
# пн–пт 10:00–23:00, сб 12:00–23:00
# {}
# ежедневно 0:00
# {}
# пн–ср 11:30–0:00, чт, пт 11:30–5:00, сб 14:00–5:00, вс 14:00–0:00
# {'1': [1400, 500], '3': [1400, 500], '4': [1400, 500], '5': [1400, 500]}
# пн–чт 12:00–0:00, пт, сб 12:00–6:00, вс 12:00–0:00
# {'1': [1200, 600], '4': [1200, 600]}
# пн–чт 7:45–0:00, пт–вс 7:45–2:00
# {}
# пн–чт 12:00–1:00, пт 12:00–5:00, сб 14:00–5:00, вс 14:00–1:00
# {'1': [1400, 500], '4': [1400, 500], '5': [1400, 500]}
# ежедневно 9:45–22:35
# {}
# пн–чт 16:30–20:30, пт 16:30–21:30, сб 11:30–21:30, вс 11:30–20:30
# {'1': [1130, 2130], '4': [1130, 2130], '5': [1130, 2130]}
# пн–чт 11:00–21:00, пт–вс 11:00–23:30
# {}
# ежедневно 10:30–23:30
# {}
# пн–чт 10:15–23:15, пт–вс 10:15–23:45
# {}
# пн–пт 15:30–21:30, сб, вс 11:30–21:30
# {}
# пн–чт 12:30–22:30, пт 12:30–23:45, сб, вс 10:00–2:30
# {'1': [1230, 2345], '4': [1230, 2345]}
# ежедневно 11:10–22:50
# {}
# ежедневно 11:00–22:40
# {}
# ежедневно 10:15–23:15
# {}
# пн–пт 12:00–1:30, сб, вс 10:30–3:00
# {}
# пн–чт 10:45–22:00, пт 10:45–23:15, сб, вс 10:45–4:15
# {'1': [1045, 2315], '4': [1045, 2315]}
# вт–вс 12:00–0:00
# {}
# пн–ср 9:30–0:30, чт, вс 9:30–2:00, пт, сб 9:30–4:00
# {'1': [930, 200], '3': [930, 200]}
# вт–сб 9:00–21:00, вс 9:00–20:00
# {}
# пн–пт 9:00–22:00, сб, вс 11:00–17:00
# {}
# пн–чт, вс 11:00–23:00, пт, сб 11:00
# {}
# пн–пт 9:00–23:00, сб, вс 11:00–23:00
# {}
# вт–чт 21:00–6:00, пт, сб 21:00–7:00
# {}
# ср, пт–вс 12:00–19:00, чт 14:00–21:00
# {}
# пн–пт 7:00–20:00
# {}
# пн–ср 11:00–23:00, чт–сб 12:00–5:00, вс 12:00–23:00
# {'1': [1200, 500], '3': [1200, 500]}
# ежедневно 11:30–19:30
# {}
# ежедневно 11:30–23:00
# {}
# пн–пт 7:30–22:00, сб, вс 9:30–20:00
# {}
# пн–пт 10:00–21:00, сб, вс 10:00–17:30
# {}
# пн–пт 13:00–22:00, сб, вс 11:00–22:00
# {}
# пн–пт 8:00–6:00, сб, вс 11:00–18:00
# {}
# пн–сб 15:00–22:00, вс 13:00–20:00
# {}
# вт–пт 10:00–18:00, сб, вс 10:00–19:00
# {}
# пн–чт 12:00–0:00, пт 12:00–3:00, сб 14:00–3:00, вс 14:00–0:00
# {'1': [1400, 300], '4': [1400, 300], '5': [1400, 300]}
# пн–чт, вс 10:00–22:00, пт, сб 10:00–5:30
# {}
# пн–чт 12:00–22:00, пт–вс 12:00–23:00
# {}
# пн–пт 10:00–20:30
# {}
# пн–ср, вс 12:00–0:00, чт–сб 12:00–3:00
# {}
# пн–пт 9:30–1:30, сб, вс 9:30–4:00
# {}
# сб, вс 12:00–13:30
# {}
# ежедневно 8:30–0:00
# {}
# пн, вс 12:00–0:00, вт–сб 12:00–2:00
# {}
# пн–чт 11:00–0:00, пт, сб 12:00–0:00, вс 10:00–23:00
# {'1': [1200, 0], '4': [1200, 0]}
# пн–пт 7:00–22:00, сб, вс 10:00–19:30
# {}
# пн–чт, вс 8:00–0:00, пт, сб 9:00–2:00
# {}
# ежедневно 18:00–0:00
# {}
# вт–чт, вс 10:00–22:00, пт, сб 10:00–23:00
# {}
# пн–пт 12:00–23:30, сб, вс 10:00–23:30
# {}
# пн–чт, сб, вс 10:00–23:00, пт 10:00–0:00
# {}
# пн–чт, вс 12:00–0:00, пт 12:00–4:00, сб 12:00–2:00
# {'1': [1200, 400], '4': [1200, 400], '7': [1200, 400]}
# ежедневно 7:50–20:00
# {}
# ежедневно 6:00–1:00
# {}
# пн–чт 8:00–23:00, пт, сб 9:00–0:00, вс 9:00–23:00
# {'1': [900, 0], '4': [900, 0]}
# пн–пт 12:00–20:00, сб, вс 12:00–21:00
# {}
